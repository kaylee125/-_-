# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import string
import glob
import os
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from pandas import DataFrame

# %% [markdown]
# # 데이터 그냥 확인절차

# %%
df1 = pd.read_csv("/Users/leesh970930/Desktop/data_team/요리.csv", delimiter=",")
df1.insert(1, 'keyword', '요리', allow_duplicates=True)
df1.head()
df1.to_csv("/Users/leesh970930/Desktop/data_team/요리.csv")

df2 = pd.read_csv("/Users/leesh970930/Desktop/data_team/공예.csv", delimiter=",")
df2.insert(1, 'keyword', '공예', allow_duplicates=True)
df2.to_csv("/Users/leesh970930/Desktop/data_team/공예.csv")



df3 = pd.read_csv("/Users/leesh970930/Desktop/data_team/드로잉.csv", delimiter=",")
df3.insert(1, 'keyword', '드로잉', allow_duplicates=True)
df3.to_csv("/Users/leesh970930/Desktop/data_team/드로잉.csv")


df4 = pd.read_csv("/Users/leesh970930/Desktop/data_team/디지털드로잉.csv", delimiter=",")
df4.insert(1, 'keyword', '디지털드로잉', allow_duplicates=True)
df4.to_csv("/Users/leesh970930/Desktop/data_team/디지털드로잉.csv")


df5 = pd.read_csv("/Users/leesh970930/Desktop/data_team/베이킹.csv", delimiter=",")
df5.insert(1, 'keyword', '베이킹', allow_duplicates=True)
df5.to_csv("/Users/leesh970930/Desktop/data_team/베이킹.csv")

df6 = pd.read_csv("/Users/leesh970930/Desktop/data_team/외국어.csv", delimiter=",")
df6.insert(1, 'keyword', '외국어', allow_duplicates=True)
df6.to_csv("/Users/leesh970930/Desktop/data_team/외국어.csv")


df7 = pd.read_csv("/Users/leesh970930/Desktop/data_team/운동.csv", delimiter=",")
df7.insert(1, 'keyword', '운동', allow_duplicates=True)
df7.to_csv("/Users/leesh970930/Desktop/data_team/운동.csv")

df8 = pd.read_csv("/Users/leesh970930/Desktop/data_team/라이프.csv", delimiter=",")
df8.insert(1, 'keyword', '라이프', allow_duplicates=True)
df8.to_csv("/Users/leesh970930/Desktop/data_team/라이프.csv")

df9 = pd.read_csv("/Users/leesh970930/Desktop/data_team/음악.csv", delimiter=",")
df9.insert(1, 'keyword', '음악', allow_duplicates=True)
df9.to_csv("/Users/leesh970930/Desktop/data_team/음악.csv")

# %%
input_file=r'/Users/leesh970930/Desktop/data_team'
output_file=r'/Users/leesh970930/Desktop/data_team/result.csv'
allfile=glob.glob(os.path.join(input_file,'*'))

all_data=[]
for file in allfile:
    df=pd.read_csv(file)
    all_data.append(df)
    
dataCombine = pd.concat(all_data, axis=0, ignore_index=True) # concat함수를 이용해서 리스트의 내용을 병합
# axis=0은 수직으로 병합함. axis=1은 수평. ignore_index=True는 인데스 값이 기존 순서를 무시하고 순서대로 정렬되도록 한다.
dataCombine.to_csv(output_file, index=False) # to_csv함수로 저장한다. 인데스를 빼려면 False로 설정

# %%
dataCombine1.head()
df.drop_duplicates(['title'], keep = False)
dataCombine1.to_csv("/Users/leesh970930/Desktop/data_team/dataCombine2.csv")

# %%
allfile
# Out:
# ['/Users/leesh970930/Desktop/data_team/음악.csv',
#  '/Users/leesh970930/Desktop/data_team/운동.csv',
#  '/Users/leesh970930/Desktop/data_team/베이킹.csv',
#  '/Users/leesh970930/Desktop/data_team/요리.csv',
#  '/Users/leesh970930/Desktop/data_team/드로잉.csv',
#  '/Users/leesh970930/Desktop/data_team/디지털드로잉.csv',
#  '/Users/leesh970930/Desktop/data_team/라이프.csv',
#  '/Users/leesh970930/Desktop/data_team/공예.csv',
#  '/Users/leesh970930/Desktop/data_team/외국어.csv',
#  '/Users/leesh970930/Desktop/data_team/result.csv']

# %%
list(dataCombine1["title"][:])
# Out:
# ['적재(정재원) - The Door [음악/노래/추천/공유]',
#  '음악작업용 외장하드 2테라, 내장SSD랑 속도 차이 거의 없을 무',
#  '미디작곡학원 나만의 음악을 만들고 싶다면',
#  '실용음악 선택이 미래를 좌우!',
#  '[음악교육신문] 피아니스트 이정아',
#  '캐릭터라이선싱페어2021에서 만난 음악교육 애니메이션 고둥둥심포니',
#  '[책] 상페의 음악 / 당신은 무엇을 동경하십니까?',
#  '[유아음악] 세계적인 유아음악 프로그램 "킨더뮤직(Kindermusik)" ',
#  '[BDCABU]재즈 역사상 가장 뛰어난 보컬 빌리 홀리데이의 음악!',
#  '실용음악학과 서울권 진학을 알아본다면',
#  'LP 레코드로 한국대중음악을 즐기기',
#  '소란(SORAN) - 내꺼라면 [음악/노래/추천/공유]',
#  '[음악장비]묵직한 세츄레이션의 Acme Audio Opticom XLA-500  Series Tube Compressor',
#  '실용음악학과 현실적인 활동과 취업방향 잡고싶다면!',
#  'EMI 시네마 클래식 - 영화로 즐기는 클래식 음악',
#  '[음악교육신문] 「피아노 석세스 올인원」 출간 (예솔출판사)',
#  '[2022 살롱드파주X그레이스제이피아노] 음악캠프 (플룻/피아노/성악)',
#  '보컬레슨 추천 - 음악 전문 온라인 교육 플레이샵 ',
#  '실용음악 비전공자로 성공하는 방법',
#  '[킨더뮤직] 영유아에게 백색소음보다 음악이 더 좋은 이유?',
#  '서울예대 실용음악과 2022 수시 1차 4명 합격',
#  '롤링 스톤 매거진(선정) 역대 위대한 음악 500(개정판) TOP 10 ',
#  '10CM(십센치) - 어제 너는 나를 버렸어 [음악/노래/추천/공유]',
#  '[음악장비]깔끔한 니브 색채의 원조 AMS NEVE 1073 LB Mic Preamp 500 시리즈 마이크 프리앰프',
#  '음악에서 무엇을 들어 낼 것인가 - 애런 코플랜드',
#  '[음악교육신문] 한세대학교 일반대학원 음악과장 유영재 교수',
#  '바흐(J.S.Bach) - The #1 Bach Album, 서양음악의 아버지',
#  '[음악교육과 대학원] 상담 및 문의',
#  '[BDCABU]20세기 최고의 팝가수  프랭크 시나트라의음악!',
#  '제주시피아노연습실&음악연습실 ',
#  '(유아음악) 킨더뮤직이 사회정서 발달에 주는 영향',
#  '익숙한 음악임에도, 현타가 몰려오게 할 기타(커버) ⑬ 메탈리카 "Master of Puppets" ',
#  '실용작곡, 2022 명문 실용음악대학 수시 최종 합격생 소개!!',
#  '10월에 듣는 깊은 록 음악) 마그마 - 잊혀진 사랑',
#  '유튜브(Youtube) 배경음악 제작ㅣ인트로, 아웃트로, 중간 화면전환 브금 효과음 사운드(Feat. 국악기)',
#  '[음악교육신문] 정하림 귀국 비올라 독주회',
#  '돌싱글즈2 5회 캠핑카데이트 노래 BGM 배경음악',
#  "네이버 이달의 블로그 '음악' 부문 선정, 3년 연속!!!",
#  '[BD MUSIC]래그타임 피아노의 선구자!  젤리 롤 모턴의 음악',
#  '[우리명소] 밤이 아름다운 신포동 음악카페거리',
#  '(유아음악) 킨더뮤직이 창의력 발달에 주는 영향',
#  '(❤️중등음악임용/피아노스토리) 전국의 모든 중등음악임용 응시 수험생 여러분들 꼭 시험 잘보세요~기도할께요!',
#  '홍대 실용음악과 수시 실용작곡 합격생 배출!!',
#  '히키(Hickee) - Hello (쇼윈도 : 여왕의 집 Vol.1) [음악/노래/추천/공유]',
#  '[음악교육신문] 피아니스트 이양숙',
#  '슬기로운 산촌생활 8회 노래 BGM 배경음악',
#  '[BD MUSIC]프랑스 대중 음악계의 대부, 세르주 갱스부르의 음악!',
#  '[음악도화지] 크리스마스 데코북 증정 EVENT',
#  '(❤️중등음악임용/피아노스토리) 2차실기 레슨 대면 및 비대면 선예약 언제나 가능 하세요! ',
#  '서울예대 실용음악과 2022 수시 최종합격 2명 ',
#  '[음악교육신문] 서울신학대학교 교회음악과 강수정 교수',
#  '[음악교육신문] 한세대학교 예술대학원 피아노교수학과',
#  '[음악교육신문] Georgia Central University',
#  '[음악교육신문] 피아니스트 김현정 글로리아',
#  '[음악교육신문] 스타인웨이 교육파트너, 스텝(STEP) 강사 모집',
#  '[음악교육신문] 플루티스트 한예지 귀국 독주회',
#  '[음악교육신문] 제1회 창원 국제 음악·무용 콩쿠르 / 페스티벌',
#  '[음악교육신문] 색소포니스트 루카스',
#  '[음악교육신문] 작곡가 박성미',
#  '[음악교육신문] 피아니스트 이영신',
#  '[음악교육신문] 한국피아노학회',
#  '[음악교육신문] 한국피아노교수법학회',
#  '[음악교육신문]709호 <커버스토리> 영신여자고등학교 음악중점학급',
#  '[음악교육신문] 석세스 뮤직',
#  '[음악교육신문] 710호 <커버스토리> 트롬보니스트 김재한',
#  '[12월 19일] 음악교육신문 초청 차세대 아티스트 콘서트 Ⅳ',
#  '[음악교육신문] 피아니스트 박해진',
#  '[음악교육신문] 제1회 미국 캔자스 음악대학 동문음악회',
#  '[음악교육신문] 삼육대학교 문화예술대학 음악학과 임봉순 학과장',
#  '[음악교육신문] 예화 피아노 입시평가회',
#  '[음악교육신문] 서혜영 피아노 독주회',
#  '[음악교육신문] 제17회 충남 전국청소년 기악경연대회',
#  '[음악교육신문] 피아니스트 박은희',
#  '[음악교육신문] 성신여자대학교 기악과 안미현 교수',
#  '[12월 18일] 음악교육신문 초청 차세대 아티스트 콘서트Ⅲ',
#  "[굿인터내셔널 용산CGV점 소식]매혹적이고 환상적인 음악! Michel Legrand – Peau D'Ane OST",
#  '[굿인터내셔널 용산CGV점 소식]프랑스 최고의 샹소니에! 조르주 브라상의 음악!',
#  "[킨더뮤직] 자장가음악 | Quiet Time | 자기조절능력 | Calm Down | We're on the Homeward Trail",
#  'Restart - 기분 좋은 뉴에이지 피아노 음악',
#  '대를 이은 오디오 마니아 이야기, 음악이냐 소리냐?',
#  '[조은 음악 신문사 콩쿠르 입상을 축하합니다] 🙂',
#  '슬기로운 산촌생활 6회 뉴클리어 반점 정선점 노래 BGM 배경음악',
#  "[BDCABU]재즈계의 제임스 딘 '쳇 베이커'의 스윙음악!",
#  '[공지] [송사비의 클래식 음악야화] 겨울 한정판 에디션',
#  '기획자 추천 시리즈 [이대로 놓치기 아까운 음악]1📌',
#  '그 겨울, 함께했던 따사로운 음악',
#  '같피연17기 1130 화, 비가 내리니 음악만 듣고파',
#  '2021부천 국제애니메이션 페스티벌 상영 일정ㅣ배경 음악 작곡 편곡 및 효과음 제작에 참여했습니다 :)',
#  '우주히피 - 맘대로 해 [음악/노래/추천/공유]',
#  '[10월 3일] 카메라타 안티콰 서울이 전하는 바로크 음악 이야기 XVII',
#  '[음악교육신문] 2021 바로크음악제',
#  '새로 나온 음악들, 요즘 들은 음악들 (6)',
#  '[11월 17일] 제1회 미국 캔자스 음악대학 동문음악회',
#  '롭 핼포드(주다스 프리스트)가 선택한 최고의 음악 10 (롤링스톤 매거진 역대 음악 500 투표에서)',
#  'MADONNA(마돈나) : 뭘 좀 아는 누나의 음악',
#  '클래식시디,음악시디 삽니다',
#  "[굿인터내셔널 용산CGV점 소식]'A Charlie Brown Christmas' 엄마와 아이 태교음악",
#  '[음악교육신문] 한국피아노듀오협회 제18회 스페셜콘서트',
#  '[2022학년도 수시] 홍익대학교 실용음악과 재즈피아노 1차 합격',
#  '[소리사전] 무무와 탈춤의 반주음악, 허튼타령',
#  '애쉬 아일랜드 ASH ISLAND - Play (Prod. by TOIL) (구글플레이 광고 음악) ',
#  '[BD MUSIC]재즈 피아노의 시인으로 불리는 빌 에반스의 음악',
#  '계원예고 입시 음악과 - 클래식 작곡, 실용음악 ',
#  '[음악교육신문]<PIANO>피아니스트 이태리',
#  '팻 메시니 음악의 개인적 최애 포맷 Side-Eye',
#  '[음악교육신문]<RECITAL>세종대학교 음악과 이기정 교수',
#  '[음악교육신문]<YOUNG ARTIST>영산양재홀',
#  '[음악교육신문] 숙명여대 문화예술대학원 피아노교수학전공 이주혜 교수',
#  '[음악교육신문]<모집>고양예술고등학교',
#  '(공유) 음악이 있는 풍경 - <마음을 감동시키는 플루트 음악 / 편안한 플루트 기악 / 헤븐리>',
#  '(❤️광주 피아노스토리 음악학원) 중등임용·교육대학원 입시 강사진',
#  '아일랜드 & 바스크 음악',
#  '미디입시 언택트시대에 가장 인기있는 실용음악 전공',
#  '[음악교육신문]<입학>대원여자고등학교 음악중점학교',
#  '[BGM] 병원에서 흘러 나오던 그 음악 | 심신안정을 위한 힐링 PLAYLIST',
#  '돌싱글즈2 6회 최종선택 노래 BGM 배경음악',
#  '[음악교육신문] 제25회 국민일보 한세대학교 음악콩쿠르',
#  '[굿인터내셔널 용산CGV점 소식]크리스마스 파티에 어울리는 산타 스윙 음악!',
#  '[음악교육신문]<STRING>첼리스트 이경미',
#  '[굿인터내셔널 용산CGV점 소식] 음악과 함께 미리크리스마스 준비! #2탄 ',
#  '[굿인터내셔널 용산CGV점 소식]음악과 함께 미리크리스마스 준비! #1탄',
#  '[음악교육신문] 한음예술교육기획 이아름 대표',
#  '오디오 기기가 아닌 음악을 들으세요?',
#  "'쇼, 음악을 말하다'를 읽고",
#  '[음악교육신문]플루티스트 강초롱',
#  '[음악교육신문]<종합>코스모스악기',
#  '새로 나온 음악들, 요즘 들은 음악들 (7)',
#  '[음악교육신문] <ORCHESTRA> 아이카우(i-CAU) 필하모닉 오케스트라 신동열 지휘자',
#  '[음악교육신문]<ENSEMBLE> 음감아트',
#  '[음악교육신문]<PIANO> 한국리스트협회 제44회 정기연주회',
#  '(27일) 쇼!음악중심 748회 라인업, 1위 후보 아이유 에스파 트와이스 몬스타엑스',
#  '한올(Han All) - 좋았을텐데 [음악/노래/추천/공유]',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 93',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 94',
#  "트와이스, 원어스 '쇼음악중심' 746회 라인업 1위 후보 더보이즈·아이유·에스파",
#  '슬기로운 산촌생활 1회 노래 BGM 배경음악',
#  '부평아트센터에서 열리는 음악과 동화의 만남, <피노키오의 모험>',
#  "최철기 감독 × 이동준 음악감독  뮤지컬 '심청': 한국 대표 컨텐츠를 모아 새롭게 버무렸다 @국립중앙박물관 극장용 11.20,21",
#  '[음악교육신문] 박태희교수의 해설이 있는 알레그로피아노교육협회 정기연주회',
#  '[을지로] 예약제 운영/ 술과 음악🕯 : 서울 인현골방',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 92',
#  '제39회 서울시립대학교 음악학과 정기연주회,서울시립대학교 대강당',
#  '11월수요음악특강 <호두까기인형> 정관지음피아노🎵',
#  '미디작곡레슨: 테크노 장르의 음악을 만드는 노하우 테크닉 배우기!',
#  '곽푸른하늘 - 나는 니가 필요해 [음악/노래/추천/공유]',
#  '언리얼+VR] 배경음악 넣기',
#  '홍대실용음악학원 입시 준비중이라면',
#  '전자과의 전자 음악 찬양글',
#  '라라라_음악 이야기_정재형',
#  '경기도 남양주 학교음악선생님이 선택한 중고야마하피아노 설명과 구입 이야기 입니다',
#  '해드셋과 수면제와 음악',
#  '가평 음악역에서 펼쳐지는 미디어파사드와 가수들의 공연',
#  '김사월 - 접속 [음악/노래/추천/공유]',
#  '음악감상용 오디오 구입할 때 초보입문자의 필독서 [하이엔드 오디오 가이드]',
#  '공간음악 - 음악 악기 연습, 성악연습에 제격',
#  '[굿인터내셔널 용산CGV점 소식]최고의 크리스마스음악!REMEMBERING CHRISTMAS',
#  '2021.11.26 림실용음악학원 목요예배 [강동구 찬양예배 기도모임]',
#  '[파주/일산/고양/김포 피아노 입시 및 전공레슨] 조은음악신문사 준대상 입상을 축하합니다! ',
#  '[음악교육신문]첼리스트 박슬기',
#  '최정윤 - 어리석은 마음 [음악/노래/추천/공유]',
#  '세종(나성동) 영국왕립음악 티칭. 야마하그랜드피아노C3.',
#  '(유아음악)킨더뮤직 압구정 직영센터에서 체험 수업 해보세요!',
#  '[음악교육신문] <CONCOURS> 강원도음악협회 이상수 회장',
#  '[문플리] 나를 영화 주인공으로 만들어 주는 인디음악 모음',
#  '선을 넘는 평화축제! 선을 넘는 음악축제! 2021 통일로가요',
#  '바퀴 달린 집3 2회 열기구 누룽지백숙 노래 BGM 배경음악',
#  '롤링 스톤 매거진(선정) 역대 위대한 음악 500(개정판) 100위 ~ 11위',
#  '음악심리상담사자격증 미래 밝은 전문 직종!',
#  '실용음악학과 디제이 플래시핑거 특강 개최',
#  '피아노레슨 작곡레슨부터 다양한 온라인 음악교육 PLAY SHOP ',
#  '광주실용음악학원 다양한 과정을 한번에!',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 91',
#  '뮤직카우 음악저작권 투자, 금보다 높은 수익률 논문 발표',
#  '[경주시장 주낙영] 경주시, <경북음악창작소> 개소식',
#  '(공유) 편안한 음악 - <André Gagnon - Comme au premier jour(첫날처럼)>',
#  'PHOENIX(피닉스) : 매년 더 좋아지는 음악',
#  '내 몸으로 완성하는 음악, 바디퍼커션을 아시나요?',
#  '도시어부3 25회 완도 방어 부시리 노래 BGM 배경음악',
#  'COLDPLAY(콜드플레이) : 21세기 음악의 선두주자',
#  '일본 센조쿠 음악 대학교, 대학원 입시 후기 & 합격 보장 교육',
#  '강남성인피아노 강남실용음악학원 여기로!',
#  '나 혼자 산다 422회 2022 달력 비둘기 아줌마 노래 BGM 배경음악',
#  '화상영어 음악에 대한 이야기',
#  '플레이송스홈과 함께 진짜놀이 음악놀이프로젝트',
#  '바퀴 달린 집3 4회 김광규 신승환 노래 BGM 배경음악',
#  '가평음악놀이터 4살아이랑 갈만한곳',
#  '오리지널 <고스트버스터즈> 1,2편 음악으로 복습하기',
#  'NCT 127·박지훈 등 쇼!음악중심 744회 라인업, 1위 후보 세븐틴VS아이유',
#  '아이폰 노래 찾기 무설치로 알아보는 음악인식 방법',
#  '상페의 음악',
#  '[교육기관 강사파견] 2022년 유아 음악수업은 킨더뮤직!  ',
#  '[중등음악임용 응용반주 독학하기] 양손악보 - Piano Score',
#  '윤이상국제음악콩쿠르 (2021년 바이올린 부문)가 열리다:통영국제음악당10월31일~11월7일',
#  'a.g.cook의 컴퓨터 전자 음악',
#  '[LP] 김정호 음악세계 - 님 / 이름모를 소녀',
#  '[음악교육신문] <FLUTE> 플루티스트 하지현',
#  '음악검색 네이버 그린닷으로 간단하게 찾는법',
#  '[공지] [비온뒤_공연소식] 김문주 가야금 전통음악 독주회 <평조회상>',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 90',
#  '조동진 4 / 음악은 흐르고(1990) 서울음반',
#  '[심리테스트] 지금 나에게 필요한 음악은?🎼',
#  '[BD MUSIC]Ray Charles (레이 찰스)의 음악!',
#  '다섯(Dasutt) - 점심시간 [음악/노래/추천/공유]',
#  '[굿인터내셔널 용산CGV점 소식]아름다운 유럽 WEIHNACHT (크리스마스) 음악!',
#  '슬기로운 산촌생활 4회 노래 BGM 배경음악',
#  '[소리사전] 왕실의 평화와 건강을 기렸던 궁중음악, 함녕지곡',
#  '[음악교육신문] <ENSEMBLE> 코리안바로크소사이어티',
#  '서울특별시 교사 힐링연수/영화음악부터 클래식음악까지 <시선이 머문 음악>',
#  '슬기로운 산촌생활 7회 정문성 설거지배 제기차기 노래 BGM 배경음악',
#  '홍대 연남동 음악 작업 및 사무실 임대',
#  '리지 헤일(여성 록 보컬리스트)의 유명한 팝 음악을 거친 음색으로 깔끔하게 커버 - I Will Always Love You(휘트니 휴스턴)',
#  '[신림 우드스탁 Vinyl 음악 감상회] #10. Rare Groove',
#  '의정부 음악도서관 2021년 12월 뮤직볼륨업 선곡들을 감상해 보세요.',
#  '카누 너티카라멜라떼 노래 CF BGM 광고음악',
#  '[음악교육신문] 동의대학교 일반대학원 통합예술치료전공 김소형 교수',
#  '[음악교육신문] <PIANO> 피아니스트 이은혜',
#  '구해줘 홈즈 133회 서울 강북 3인가구 자연 친화적인 집 노래 BGM 배경음악',
#  "'음악 혐오'를 읽다가",
#  '오늘부터 무해하게 1회 죽도 공효진 이천희 전혜진 노래 BGM 배경음악',
#  '경북 경주시, ‘경북음악창작소’ 개소',
#  '[신림 우드스탁 Vinyl 음악 감상회] #11. Yacht Rock',
#  '골반 틀어짐 교정 2분 운동 Leg Circle',
#  '바디웨이트 맨몸 운동 애니멀 플로우 인스트럭터 레벨 2 Animal Flow Instructor level2 ',
#  '재활 필라테스 | 등척성 운동으로 재활을 시작하는 이유 ',
#  '허리에 좋은 운동 시도해보기',
#  '사계절 내내 건강을 유지하는 실내운동',
#  '등운동 루틴 기구 [시티드 로우를 다양하게]',
#  '무릎 통증, 휜다리(오다리, X다리) 교정 및 수술 치료, 운동, 근육 마사지',
#  '구디 헬스장 케이블을 이용한 상체운동을 소개할게요',
#  '서울대입구역PT 실종된 힙을 되찾는 운동!',
#  '다이어트 똑똑하게 하자! 기초대사량 그리고 운동,식단 편식하지말아야 하는이유!',
#  ' 운동이 유방암 환자 케모 브레인 막는다',
#  '케겔운동 효과 조루개선에 도움이 될까?',
#  '스쿼트 자세 여자 남자 다이어트운동 효과 ',
#  '소도구 필라테스 | 미니볼을 이용한 전신 운동',
#  '오십견 운동 따라하며 예방하기',
#  '만성 목, 어깨, 발목 통증  운동 솔루션',
#  '하체운동 파워레그프레스 운동효과 [어떻게 사용해야 가장 좋을까요?]',
#  '운동전 커피가 지방제거를 증가시키나?',
#  '암 예방을 위한 꾸준한 운동',
#  '홍대 헬스장 여성에게도 필수인 등운동!',
#  '운동하기 전에 마시는 아이스 아메리카노 건강에 이상은 없는걸까?',
#  '홈트레이닝 매트운동 : 바닥만 있으면OK 확실한 운동효과 루틴 _ 힙운동 전신운동 ',
#  ' 코로나19 백신 접종 후 운동을 해도 괜찮을까?',
#  '남자 여자 하체운동 햄스트링 Toned 1분 홈트  뒷벅지 만들기 ',
#  '다이어트 초보의 흔한 망테크 : 먹는 건 못 줄이겠고...운동만으로 뺄까?',
#  '목디스크에 좋은 운동, 주의해야 할 점이?',
#  '한님쌤 필라테스 | 복근 운동 시 고관절 앞쪽만 느껴진다면? ',
#  '복부를 자극하는 외복사근 운동 3가지',
#  '봉선동 운동재활 체형 개선 PT  비포 애프터',
#  '2021년 11. 26.(금) 철인 운동일지: 사이클 롤러 훈련 2회, 무룡산 산행',
#  '3분 요가 : 밧다 코나아사나 - 고관절 가동성에 좋은 운동',
#  '신림 헬스장 고강도 복근 운동을 알려드려요!',
#  '유산소운동 효과 와 근손실 이유 : 유산소 근력 순서 바로 이거에요!!',
#  '원레그 데드리프트 자세 효과 맨몸운동 종류',
#  '운동 전 식사로 운동 효과를 높여주세요',
#  '허리 스트레칭 기구 간편한 허리 운동으로 추천',
#  '(광주 서구 / 오월길 도보여행 #5) 걸어서 만나보는 5.18 광주민주화운동의 성지 여행. 오월길 <광천 시민아파트, 광천동 성당, 들불야학 옛터>',
#  '한님쌤 건강 정보 | 골다공증, 골절 예방 운동',
#  '복직근이개 운동 따라하며 몸상태 되찾기',
#  '엉덩이 중둔근 운동 프로그레션 이렇게 해보세요!',
#  '백신맞고 10일만에 운동하니까 거의 몸이',
#  '신림PT 가슴라인을 완성하는 운동을 소개합니다~',
#  '오늘도 나와의 싸움에서 이기기 운동은 가산역 크로스핏 에이머에서!',
#  '만성통증 재활운동 피드백',
#  '여자 근력운동 다리 Shaping 하체비만 전신운동',
#  '여자 힙업운동 엉덩이살빼기 : 짧고 굵은 확실한 힙업효과',
#  '겨울 실내운동, 트레드밀 뛰기',
#  '신사동pt 15분 코어운동 강력한 코어근육을 만들어보자!',
#  '한님쌤 건강정보 | 폐경기 여성들의 운동에 대해',
#  '하체 근력운동 건강을 위해서 필수에요',
#  '2021년 11. 29.(월) 철인 운동일지: 휴식 및 회복하는 날',
#  '이지현 육아 등운동 제발 좀 그만해 이러다 다 죽어',
#  '신림 헬스 상체라인을 만드는 운동을 알려드려요',
#  '한주의 마지막도 에이머에서! 가산역 크로스핏 에이머에서 운동해요',
#  '여자 힙업운동 남자 엉덩이 근육운동 Glute Shaping',
#  '코어운동 허리에 좋은 강화운동',
#  '팔굽혀펴기 효과 가슴쳐짐운동 푸시업 자세',
#  '엉덩이살빼기 여자 힙업운동 세퍼레이션 근육 만들기',
#  '남자 여자 복근운동 심플한 뱃살빼는법 시티드 & 리버스 크런치',
#  '플랭크 자세 코어운동 효과 건강한 다이어트 운동',
#  '남자 여자 뱃살 빼는 운동 홈트 기초 가이드(크런치 레그레이즈 러시안 트위스트)',
#  '크로스 런지자세 curtsy 효과 허벅지살 빼는 운동',
#  '복근운동 루틴 따라하며 운동하기',
#  '거북목 교정기 없어도가능한 : 거북목 교정 운동 스트레칭 같이해요!',
#  '비복근운동 부은 하체를 풀어줘요',
#  '엉덩이 힙업 운동 이렇게 해봐요',
#  '유산소운동 꼭 해야하는이유와 유산소 와 무산소 차이 ',
#  '하체운동 허벅지근육운동 이지만 앞툭튀 걱정 없이~',
#  '임산부 필라테스 산후 운동으로 좋은 동작',
#  '재활 필라테스 | ACL 재활 시의 OKC, CKC 운동에 대해',
#  '옆구리살빼는운동 해본사람이 알려드려요 !!',
#  '하체운동 을 꼭 해야만 하는 이유 팩폭!',
#  '한님쌤 필라테스 | 둔근 강화, 힙업 운동 총정리',
#  '필라테스 토닝볼 활용한 어깨운동',
#  '대둔근 운동 힙업을 위해서 필수에요',
#  '허벅지 안쪽살 빼기  확실한효과 2가지운동',
#  '광명 헬스 탄력적인 가슴을 완성하는 운동!',
#  '홈짐 힙업운동 ! 추천루틴 브이스쿼트 열일기록',
#  '추워진 날씨에 건강지키기! 운동은 가산역 크로스핏 에이머에서!',
#  '홈트레이닝 으로 허벅지 승마살 동시에! : 허벅지 안쪽살 빼기 + 승마살 운동 ',
#  '즐거운 에이머! 크로스핏 에이머에서 함께 운동해요~~',
#  '빡세게 운동하고 싶다면 크로스핏 에이머! 가산역 크로스핏 에이머로오세요~~',
#  '골반 스트레칭 & 고관절 스트레칭 : 하체운동전 꼭 하세요!',
#  '복근운동 과 유산소 전신 운동 동시에! 같이하실분!!',
#  '추위이기러 에이머로 오세요! 가산역 크로스핏에이머에서 함께 운동해요',
#  '2021년 12. 2.(목) 철인 운동일지: 사이클 르몽드 트레이너, 집 대청소/부울경 트레일런 송년회 연기',
#  '2021년 11. 27.(토) 철인 운동일지: 회복하는 날(태화강변 걷기, 재현이랑 수영)',
#  '건강지킴이 에이머! 가산역 크로스핏 에이머에서 운동해요!!',
#  '헬스장 가서 어떤운동부터 해야할까? 여자 헬스 루틴 이렇게!!',
#  '신사역pt 등운동 루틴 효과적으로 등근육 강화시키는 운동법',
#  '오늘 정말 운동가기 싫었',
#  '헬헬 이제 다시 운동을 시작할 수 있다',
#  '[강서구 주짓수&킥복싱] 체력, 면역력 운동으로 키워보아요!',
#  '서로 할일하자라는 현우진 선생의 메세지를 전두엽에 각인시키고 운동 갔다옴',
#  '허리근력 강화운동 집에서 해봐요',
#  '승마살 운동 함께 따라해봐요',
#  '스파인코렉터 활용한 운동 동작 세가지',
#  '11월 저와 운동+수다 하실래요? : 신세계 강남점 원데이클래스 ',
#  '여자 복근운동 3가지 동작으로 코어를 단단하게',
#  '신사pt 전신운동 추천 하체운동과 상체운동을 동시에!',
#  "운동하신다면 3만원 받아가세요! - '1타3만'체육쿠폰 신청 안내",
#  '[공지] 스쿼트 자세 하체 근력운동 diet 효과',
#  '허벅지 안쪽살 빼기 운동 와이드 스쿼트 & 이너싸이 머신 ',
#  '허리디스크에 좋은 운동, 맥켄지 운동법 따라 하기',
#  '중둔근 운동 매트위에서 해보기',
#  '등살빼는운동 등근육 care 남자 여자 홈트레이닝',
#  '요즘 운동식단은 cu 편의점 The 건강식단 도시락으로!!',
#  '전방십자인대파열 운동 중 발생하므로',
#  '쇼그렌증후군 근력강화를 위한 저항운동 효과는',
#  '다이어트 운동 or 식단 뭐가 더 중요할까?!',
#  '2021년 11. 22.(월) 철인 운동일지: 매봉재 산행, 학생들과 함께 타바타운동',
#  '대상자에게 맞는 운동이 우선시되어야 함',
#  '오른쪽 어깨 통증 원인 회전근개파열 전거근통증 완화 방법 극상근운동 ',
#  '허리에 좋은 운동 누워서 따라해보기',
#  '밸런스 운동 : 코어운동 과 복근운동 을 동시에 ',
#  "대구PT '유산소운동의 효과를 최상으로~~런닝머신 잘타기'",
#  '신사역피티 남자 어깨운동 추천 덤벨운동 끝판왕!!',
#  '서울대입구 헬스장 코어랑 등운동 함께해요^^',
#  '척추협착증 증상 및 운동방법',
#  '굽은등 교정운동 같이 따라해봐요',
#  '여자 상체운동 (등살 겨드랑이살빼기 코어 강화) 3종류',
#  '<광교피티 어썸핏> 바이킹프레스를 이용한 운동',
#  '홈트로 해보는 등과 가슴 운동',
#  '2021년 12. 1.(수) 철인 운동일지: 생활 속 운동(사이클 르몽드 트레이너, 무룡산 일몰 산행, 타바타운동(어깨+데드리프트)), 진장회수산센터에서',
#  '여자 복근운동 (요가 자세)',
#  '질타이트닝을 돕는 여성케겔운동기구',
#  '집에서 할수있는 운동 등근육 자극하기',
#  '매력적인 여자 팔근육 키우는법 3가지 운동',
#  ' 대한민국 초등학생들아~ 우유랑 운동하자♬ 11월 SNS이벤트',
#  '운동 후 근육통 푸는 법(폼롤러를 통한 가슴, 등, 허벅지, 햄스트링, 종아리 이완, 근육 통증)',
#  '코어운동 허리강화운동 우리가 꼭 해야하는 필수운동',
#  '이수역 헬스장 1석2조의 운동을 배워보기!',
#  '평발교정운동 쉬운 세가지 동작',
#  '척추측만증 운동 따라하면 좋답니다',
#  '탄현역 헬스장 운동초보도 즐겁게 힙운동 하는법!',
#  '방이동 필라테스 전문적인 강사진과 즐겁게 운동해요!',
#  '어깨 통증 : 어깨 회전근개파열 증상 및 재활, 운동, 수술 치료 병원',
#  '허리 코어운동 집에서 따라해요',
#  '필라테스 아크바렐 운동 세가지 동작',
#  '경산 운동 효과 있는 체온다이어트 찜질 카페',
#  '보수볼 운동 따라하며 밸런스 잡아가기',
#  '복근운동 집에서 해보기',
#  '시간절약형 운동 프로그램 : 3/7 세트법',
#  '11월 3일은 무슨 날? 학생독립운동 기념일!',
#  '<광교pt 어썸핏>두툼한 갑빠를 만들기위한 가슴운동',
#  '다이어트한의원 한약 운동중독 후기!',
#  '운동 근황 - 베넥2, 일본정치, 뉴발 이에로v6 세일',
#  '팔운동 어떻게 해야할까요?[탄탄한 팔을 만들기 위해서]',
#  '2021년 11. 15.(월) 철인 운동일지: 박상진호수공원 걷기, 치맥',
#  '왼쪽 오른쪽 팔저림 및 팔통증, 흉곽출구증후군 증상 및 치료 운동, 스트레칭',
#  '홈트레이닝 기구 없이 폼롤러로 자극 200% 힙업운동 코어운동',
#  '마들렌 만들기 초보 홈베이킹',
#  '스콘만들기! 베이킹초보도 성공보장~ 크랜베리 스콘 만드는법',
#  '홈베이킹 위즈웰 제빵기로 홈메이드식빵 우유식빵 만들기',
#  '제스프리 그린키위 과일디저트 두 가지 만들기!간단한 홈베이킹 ',
#  '[공지] [22년 1월 평일/주말] 비건베이킹전문가 2급 자격증반 모집 @로비건채식요리학원',
#  '누네띠네 스콘 만들기 과자보다 맛있죠(홈베이킹)',
#  '이탈리아식 마카롱 만들기 겉바속쫀 아마레티 쿠키 (아몬드가루 베이킹)',
#  '홈베이킹 얼그레이 식빵 밀크티잼으로 시작하는 오후',
#  '쌀식빵 만들기 건강하고 더욱 맛있는 쌀가루베이킹 홈메이드 발효빵',
#  '마들렌 만들기 발로나 초콜릿 더해 세상 맛있는 홈베이킹 ',
#  '시나몬롤 만들기 호떡믹스로 뚝딱 초보 홈베이킹',
#  '마들렌만들기 아이들간식 티푸드 홈베이킹 ',
#  '초간단 홈베이킹 바나나케이크 에어프라이어로 슝~',
#  '전기 밥솥 카스테라 만들기 노오븐 베이킹',
#  '노오븐 베이킹 아침빵으로 좋은 피타브레드 만들기',
#  '크림치즈빵 만들기 발효빵 홈베이킹',
#  '촉촉한 초코칩쿠키 만들기 간단한 홈베이킹 초코쿠키 레시피 ',
#  '옥수수 치즈 생크림 스콘만들기 노버터 에어프라이어 스콘 홈베이킹 ',
#  '[홈베이킹] 쌀 슈크림 만들기💛',
#  '생크림 스콘 만들기 노버터 초간단 홈베이킹 응용버전까지',
#  '제스프리 그린키위 주스 만들기 크로와상 생지 활용 후렌치파이 홈베이킹',
#  '믹스만큼 쉬운 홈베이킹 바나나빵 스타벅스 바나나브레드 ',
#  '겨울 간식 홈베이킹 새로나온 백설 초코츄러스맛호떡믹스 ',
#  '바스크 치즈케이크 만들기 선물하기 좋은 쉽고 근사한 홈베이킹',
#  '마들렌만들기  아이들 간식 홈베이킹 오븐요리 ',
#  '대추 마들렌만들기 홈베이킹 레시피',
#  '초코 브라우니 만들기 간단 베이킹 재료',
#  '홈베이킹 무화과사브레 만드는법',
#  '홈메이드식빵 만들기 홈베이킹 소보로 우유식빵 위즈웰 제빵기 추천',
#  '[펌킨스파이스 쿠키]향긋하고 부드러운 맛있는 쿠키 / 가을 베이킹! ',
#  '고구마요리, 다이어트 고구마빵 놀랍게도 노버터 노오븐 베이킹!',
#  '[홈베이킹] 쌀 맘모스빵 만들기🐘',
#  '파운드케이크 만들기 홈베이킹 생크림 활용 요리',
#  '노오븐베이킹, 암브로시 마스카포네치즈로 티라미수 만들기',
#  '[수업후기]구움과자창업정규반 1회차수업/스무크베이킹스튜디오',
#  '계란과자 만들기 시판보다 맛있는 엄마표 계란 쿠키만들기! 초간단 베이킹 재료~',
#  '생크림 스콘만들기 플레인 스콘 초코칩 더해 맛있게 쉬운 홈베이킹',
#  '올리브 치아바타 만들기 무반죽 초보 홈베이킹',
#  '리얼 감자빵 만들기 깨찰빵믹스 활용한 간단 홈베이킹 감자요리',
#  '우유 식빵만들기 홈베이킹레시피',
#  '대전베이킹클래스 향긋한 휘낭시에 도전!',
#  '그릭요거트로 레몬 파운드케이크 만들기(홈베이킹.ver) ',
#  '초코칩 생크림스콘 만들기 노버터 베이킹 에어프라이어 홈베이킹',
#  '[베이킹] 위즈웰gl42 - 갈레트 브루통',
#  '[홈베이킹] 노밀가루 쌀 빼빼로 만들기🍫',
#  '홈베이킹, 겉바속촉 초콜릿 쿠키, 아메리칸 쿠키 만들기 ♬',
#  '[공지] [22년 1월 평일/주말] [공지] 채식요리지도사(비건베이킹 포함)2급 자격증 @로비건채식요리학원',
#  '[프리오더] 12월 #안서리베이킹랩 #파블로바 #마쿠아즈 #달고나 #프리오더',
#  '플레인 스콘만들기 이 맛은 못참지! 커피 부르는 홈베이킹~',
#  '초코칩쿠키 만들기 아이들 간식 추천 홈베이킹 레시피',
#  '바질 스콘 만들기 향긋함이 입안에 가득한 홈베이킹 ',
#  '마들렌 만들기 간단한 홈베이킹',
#  '초코 머핀만들기 아이간식 홈베이킹 에어프라이어 ',
#  '백종원 사과파이 에어프라이어 식빵 요리 홈베이킹 애플파이 만들기',
#  '바스크 치즈케이크 만들기 홈베이킹 ',
#  '그릭요거트 팬케이크 만들기 어남선생 홈베이킹 레시피',
#  '마들렌 만들기 홈베이킹 상콤상콤함이 듬뿍 청귤마들렌',
#  '[홈베이킹] 쌀 브라우니 쿠키 만들기🍫',
#  '유기농 블루베리, 간단하게 홈베이킹 블루베리머핀 만들기 ♪',
#  '비앤씨마켓 할로윈 베이킹 펌킨파이 만들기',
#  '간단 홈베이킹요리 시리얼바 만들기 발로나 지바라 초콜릿 ',
#  '[비건베이킹전문가 1급] 3회차 주중반 수업후기 (치아바타, 앙버터, GF 스노우볼쿠키)',
#  '스콘만들기  홈베이킹 오븐 생크림 요리 만드는법 ',
#  '생크림 스콘만들기 겉바속촉 홀딱 반하는 노버터 홈베이킹! 초간단 베이킹 재료 ',
#  '홈베이킹 얼그레이 파운드케이크 만들기',
#  '[비건베이킹전문가 1급] 1회차 주중반 수업후기 (커스터드 슈, 야채크래커)',
#  '노버터 생크림 스콘만들기 햄치즈 스콘 레시피 홈베이킹',
#  '초보 홈베이킹 초코 머핀 만들기',
#  '[올해 마지막]신청 가능 클래스 안내 (비건,베이킹,주스)',
#  '홈베이킹 만들기 쉽지만 고퀄의 브라우니 ',
#  '홈베이킹 유행따라 대파치즈스콘 만들기 ',
#  '리얼 홈베이킹 클래스 토요반 3주차-베이글 4종과 스콘',
#  '홈베이킹 크랜베리마카다미아스콘 만들기!',
#  '리얼 홈베이킹 클래스 토요반 5주차-할라 브레드와 호두 파이, 아몬드 타르트',
#  '[비건베이킹전문가 1급] 4회차 주중반 수업후기 (글루텐프리 시나몬롤스콘&다쿠아즈)',
#  '모엘로 쇼콜라, 판드젠 케이크 / 개인 수업, 베이킹 클래스',
#  '초콜릿 케이크 만들기 쌀베이킹',
#  '쉬운 할로윈베이킹,디저트/미라 마들렌만들기',
#  '르뱅쿠키 만들기 쿠키만들기 촉촉한 에어프라이어베이킹',
#  '부드러운 달콤함♥ 딸기연유케이크 만들기 원데이클래스 후기 [크리스마스 베이킹] 수원,동탄,영통,광교,용인,분당 로엔느',
#  '베이킹 핸드믹서기 휘핑기 드레텍 HM-706',
#  '나주시 쌀베이킹 자격증반 세번째시간🙌🏻',
#  '쌀베이킹자격증반 네번째시간 글루텐프리 쌀디저트 만들기🙌🏻',
#  '리얼 홈베이킹 클래스 목요반 7주차-크로아상과 비스퀴 롤 케이크',
#  '리얼 홈베이킹 클래스 목요반 4주차-핫도그 번과 리얼 퍼지 브라우니와 블론디',
#  '리얼 홈베이킹 클래스 목요반 5주차-할라 브레드와 호두 파이와 아몬드 타르트',
#  '홈베이킹 원데이 클래스-핫도그번과 비스켓과 스콘',
#  '리얼 홈베이킹 클래스 목요반 6주차-모닝번즈와 시나몬 롤, 소세지빵, 클래식 파운드 케이크',
#  '[비건베이킹전문가 1급] 2회차 주중반 수업후기 (밤만주, 상투과자)',
#  '#비건갸또 #비건베이킹클래스 #비건케이크클래스',
#  '#백화점출강 #비건베이킹클래스',
#  '[12월 3주차]비건베이킹/요리 원데이클래스(콘치즈쿠키,캐비지롤)',
#  '리얼 홈베이킹 클래스 목요반 3주차-베이글 4종과 스콘',
#  '#비건베이킹클래스 #비건케이크클래스 #비건갸또 #비건베이킹출강',
#  '리얼 홈베이킹 클래스 토요반 4주차-핫도그번과 퍼지 브라우니와 블론디',
#  '[베이킹수업후기]2021.11.24(수) 딸기프레지에/휘낭시에',
#  '천연발효빵 만들기 - 단호박 식빵 <베이킹스타트- 천연발효빵을만들다>',
#  '#비건베이킹클래스',
#  '초간단 홈베이킹 다이어트 빵 만들기! 다이어트 음식으로 좋은 견과류 키토빵',
#  '막걸리 술빵 만들기 노오븐 홈베이킹 막걸리빵 레시피',
#  '홈베이킹, 에어프라이어 비스킷 만들기 KFC 추억의 맛',
#  '베이킹 초보를 위한 버터크림 플라워케이크 기초과정',
#  '홈베이킹_잼 쿠키 만들기(쨈쿠키)',
#  '[12월1주차 비건베이킹 원데이클래스] 레밍턴케이크,고구마빵',
#  '리얼 홈베이킹 클래스 토요반 2주차-포카치아 2종과 드롭 쿠키 4종',
#  '비건베이킹 비건 초코 가나슈 케이크 레시피 :)',
#  '홈베이킹 위즈웰 제빵기 파운드케이크 만들기',
#  '책으로 배우는 홈베이킹 <동명양과자점의 아메리칸쿠키 레시피>, 영진닷컴 ',
#  '위즈웰제빵기 홈베이킹 우유식빵 만들기',
#  '홈베이킹, 동명양과자점 아메리칸쿠키레시피, 쿠키만들기 ♬',
#  '베이킹 초보의 도전~ 버터크림 플라워케이크 자격증과정',
#  '[공지] 12월 원데이 베이킹 수업 공지 + 크리스마스 케이크 만들기 + 한민이의 마크로비오틱 + 부산 광안리 비건 베이킹 클래스 ',
#  '홈베이킹 기록 오발틀 휘낭시에 만들기',
#  '건포도 식빵 만들기 발효빵 홈베이킹 식빵간식',
#  '에어프라이어 스콘만들기 결이 다른 대파치즈 스콘 홈베이킹',
#  '리얼 홈베이킹 클래스 토요반 1주차-식빵 2종과 마들렌 4종',
#  '리얼 홈베이킹 클래스 목요반 2주차-포카치아 2종과 드롭 쿠키 4종',
#  '초콜릿 케이크 만들기 발로나 초콜릿 활용 홈베이킹 초코케이크',
#  '달고나 만드는법 꿀팁 암앤해머 베이킹소다 ',
#  '초간단 홈베이킹 달콤한 사과조림이 가득 크럼블 애플파이 ',
#  '[부산] 비건베이킹전문가 3~4주차 review, 식사빵도 어렵지 않아요!',
#  '홈베이킹_ 초코 막대과자 만들기(빼빼로 만들기)',
#  '인핏 주방저울, 홈카페, 홈베이킹 & 요리 필수템',
#  '홈베이킹 키친에이드 푸프로 생크림 스콘 만들기 ',
#  '#비건베이킹클래스',
#  '리얼 홈베이킹 클래스 목요반 1주차-식빵 2종과 마들렌 4종',
#  '홈베이킹 밤스콘 만들기Chestnut scone!',
#  '[홈베이킹] 얼그레이 쌀카스테라 만들기🧡',
#  '쌀다쿠아즈 다쿠아즈 창업 베이킹 클래스! 제주도에서 찾아주신 수강생분과 함께:)',
#  '빛가람동 쌀베이킹 자격증반 두번째 수업 후기',
#  '[찹쌀 빼빼로] 농민의 날에 먹는 빼빼로 만들기 feat. 베이킹 몬스터즈 5기',
#  '#비건베이킹클래스',
#  '머핀만들기  어린이 간식 컵케이크  키즈 베이킹 즐거워!',
#  '당근으로 하는 베이킹 , 당근요리, 당근맛있게 먹는법',
#  '[수업후기] 기본쿠키3종 :: 중학생과 함께하는 베이킹~',
#  '[공지] ♥킵미스위트♥ 2021년 12월 키즈베이킹 안내',
#  '초코머핀 만들기 홈베이킹 바나나초코머핀 간단한 디저트 만들기',
#  '[비건베이킹전문가 1급] 2회차 주중반 수업후기 (밤만주, 상투과자)',
#  '#비건베이킹클래스',
#  '단호박갸또 만들기 할로윈베이킹',
#  '호두파이 만들기 호두타르트 홈베이킹 오븐 구움과자',
#  '• 베이킹책추천, 정직한 제빵소 윤연중 쉐프의 [어니스트브레드]로 홈베이킹, 팔미에만들기 •',
#  '[비건베이킹전문가 1급] 4회차 주중반 수업후기 (글루텐프리 시나몬롤스콘&다쿠아즈)',
#  '홈베이킹 녹차크랜베리주름식빵만들기!',
#  '스메그 반죽기로 홈베이킹 파운드케이크 만들기',
#  '로헨 에어프라이어로 베이킹 스콘 만들기',
#  '아이들간식 친구들 선물 열심히 베이킹하고 혼밥하고 장보고 세로토닌 만끽하고 저녁으로 참치전 돼지고기고추장구이 만보걷기 키토제닉 즐거운 주말되세요~♡',
#  '[비건베이킹전문가 1급] 3회차 주중반 수업후기 (치아바타, 앙버터, GF 스노우볼쿠키)',
#  '나주직장인 쌀베이킹자격증반 귀한 일요일 수업 후기 :-)',
#  '[비건베이킹전문가 2급] 4회차 주중반 수업후기 (비건티라미수, 맥주빵)',
#  '[부산] 11월 비건베이킹전문가 주말반 개강안내 (마감)',
#  '홈베이킹 에어프라이어 무화과 쿠키만들기(냉동쿠키)',
#  '쌀베이킹클래스   『쌀휘낭시에만들기』',
#  '새로피엔엘ㅡ크리스마스 베이킹포장소품들',
#  '쌀베이킹정규 4회',
#  '[비건베이킹전문가 1급] 5회차 수업후기 (파이 마스터)',
#  '[부산] 비건베이킹 1주차 review, 글루텐프리 비건빵 이렇게 맛있었다니!',
#  '홈베이킹_고구마 휘낭시에(피낭시에) 만들기',
#  '코코아와 아몬드 넣은 쌀베이킹 쿠키 만들기',
#  '미니오븐 홈베이킹 입문자가 쓰기좋은 드롱기 아이코나빈티지오븐',
#  '[베이킹] 위즈웰gl42 - 도토리마들렌',
#  '마들렌 만드는법! 스메그 오븐으로 (그릴스팀 컨벡션) 베이킹하기',
#  '[비건베이킹전문가 2급] 6회차 주중반 수업후기 (얼그레이 사브레, 호두타르트)',
#  '인천 베이킹재료 파는곳 관교동 렛츠베이킹 ',
#  '그릭요거트 브라우니 만들기 쉽고 맛있는 홈베이킹',
#  '간단한 홈베이킹 쇼트브레드 쿠키',
#  '#비건베이킹클래스',
#  '#비건베이킹클래스 #비건케이크',
#  '#비건베이킹클래스',
#  '황치즈 파운드케이크 만들기 :: 홈베이킹',
#  '[비건베이킹전문가 2급] 5회차 주말반 수업후기 (비건치즈케이크, 블루베리크럼블)',
#  '구움과자 수업 카페 디저트 마들렌 6종 클래스! 남양주시, 서울 베이킹 원데이 클래스',
#  '드롱기 아이코나 미니오븐 주말 홈베이킹! 계란빵 만들기',
#  '[케이크대회대상]월드쉐프컬리너리컵코리아,케이크심사위원,카페디저트마스터심사위원,한국조리문화협회,이엘베이킹대상,대전케이크,이엘베이킹,이엘베이킹스튜디오☆',
#  '베이킹스타트 - 천연발효빵 치즈 감자 치아바타 & 사과 햄 샌드위치',
#  '[홈베이킹] 쌀 체크쿠키 만들기🏁',
#  '에어프라이어 요리, 수플레 팬케이크 쉽게 만들기!(노오븐베이킹)',
#  '출강 단체 베이킹수업',
#  '베이킹 클래스_마들렌 + 아메리칸 쿠키 4종 / 구움과자 창업, 카페 디저트 클래스',
#  '쉬운 베이킹 코코넛로쉐 레시피',
#  '비건베이킹 2급 스케치...',
#  '사과 팬케이크 만들기 🍎 사과 디저트, 저탄고지 베이킹',
#  '[라라맘앤김쌤 공방] 라라맘앤김쌤 베이킹 클래스 / 사워도우 (천연발효빵)',
#  '홈베이킹 레몬 제스트 & 파운드 케이크 만들기  아이싱 + 구겔호프틀',
#  '#비건베이킹클래스',
#  '[비건베이킹전문가 2급] 5회차 주중반 수업후기 (비건치즈케이크, 블루베리크럼블)',
#  '사워도우 초코칩 쿠키 만들기 :: 버리는 발효종 베이킹',
#  '에어프라이어베이킹 육쪽 마늘빵 만들기 크림치즈빵 소스 간단한 에어프라이어 요리',
#  '[홈베이킹] 쿠크다스 식감! 쌀 랑그드샤 만들기',
#  '프러포즈 케이크 직접 만드시는 수강생님의 수업사진! 일산 디자인케이크 원데이클래스 [항아케이크 베이킹공방]',
#  '[수업후기] 모카번과 우유식빵 만들기 :) -마전동 마산동 베이킹클래스-',
#  '로푸드 지도자 과정 중 비건베이킹 메뉴@',
#  '베이킹 초보 창업클래스, 버터크림 플라워클래스',
#  '[베이킹] 위즈웰gl42 - 베이킹박스(알밤케이크,도토리마들렌,고르곤졸라휘낭시에,올리브앤초비휘낭시에,건과일파운드,얼그레이파운드,코코넛초코칩쿠키)',
#  '홍합밥 만드는 법 12월 제철음식 홍합살 요리',
#  '귤잼 만들기 새콤달콤한 귤요리',
#  '홍합탕 만드는 법 홍합요리 집에서 소주안주 추천 ',
#  '홍합탕 만드는 법 시원한 국물 팁은 이것~홍합 손질 요리 ',
#  '소고기 안심 스테이크 요리 건강하고 맛있게 굽는법 ',
#  '톳밥 만들기, 톳나물밥 맛과 영양을 다잡은 톳요리!',
#  '굴전만들기 눅눅하지 않게 굴전만드는법 제철 굴요리 굴씻기',
#  '사태 김치찜 맛있게 만드는 법 : 돼지고기사태요리 / 묵은지요리 /김치요리',
#  '모과차 만들기 따뜻한 차 로 드시기에 좋은 모과 요리 ',
#  '꽁치통조림 조림 요리 꽁치 무조림 만드는 법',
#  '알탕 끓이는법 명란 요리 얼큰한 국물요리',
#  '오늘의요리] 반건조오징어 & 미나리무침',
#  '백종원 순두부찌개 끓이는법 간단 순두부찌개 양념장 요리',
#  '베이컨 버섯 크림 리조또 만들기 부드러운 이탈리아 요리',
#  '계란죽 끓이는법 야채 참치죽 끓이는법 고소한 계란요리',
#  '백종원 두부조림 양념장 만들기 정말 간단한 두부요리 팁 밑반찬 딱이죠~',
#  '맛있는 당근 요리 당근라페 만들기 ! ',
#  '백종원 두부조림 양념장 만들기 손쉬운 자취생 간단요리',
#  '참치 김치찌개 맛있게 끓이는법 참치캔 요리',
#  '어묵탕 오뎅탕 끓이는법 리얼 캠핑요리 간식 꼬치어묵탕 레시피 육수 간장소스',
#  '굴무침 만들기 겨울 제철 반찬 굴요리! 무요리?',
#  '백종원 순두부찌개 끓이는법 양념 순삭하는 순두부 요리 ',
#  '간장무조림 만드는 법, 손이 가는 무요리',
#  '배추된장국 바지락을 넣어 감칠맛나는 된장국 배추요리',
#  '명란젓 무침 손쉬운 명란젓 요리 명란젓 먹는법',
#  '김치 만두전골 레시피 냉동만두 요리 얼큰한 김치전골 끓이는법',
#  '간장 어묵볶음 레시피 오뎅볶음 아이들 반찬 요리',
#  '부추무침 만드는법 백종원 부추겉절이 레시피 부추요리',
#  '폭탄 계란찜 만들기 실패없이 촉촉 부드러운 계란찜 뚝배기 레시피! 간단한 계란요리 팁 ',
#  '쪽파무침 고추장 양념 새콤달콤 쪽파 요리 데치기',
#  '12월 제철 농산물 양배추요리로 양배추롤 만들기~ ',
#  '무청시래기나물볶음 만드는법 시래기 된장지짐 이 겨울 좋은요리입니다. ',
#  '초간단 계란국 끓이는법 달걀국 레시피로 간단한 아침국 요리',
#  '전복죽 끓이는법 겨울 보양 전복요리 전복내장죽',
#  '맑은 감자국 끓이는법 포근하고 맛있는 계란감자국 감자요리',
#  '명란 계란탕 만들기 계란국 끓이는법 아침식사대용 명란요리',
#  '굴물회 굴초무침 쉬운 굴요리',
#  '고사리나물볶음 부드러운 고사리볶음 고사리요리',
#  '초간단 어묵국 끓이는법 뜨끈한 국물요리 오뎅국 레시피',
#  '백종원 감자짜글이 고추장찌개 캔참치 요리 ',
#  '무 요리 색다르게 즐기는 무전 만들기',
#  '고추장 감자조림 만드는 법 엄지척 매운감자조림 정석 감자 요리 이겁니다. ',
#  '맑은 순두부찌개 끓이는법 국물이 예술 명란순두부찌개 요리',
#  '표고버섯볶음 만드는법 파프리카 넣고 맛있게 표고버섯요리',
#  '고구마스프 만들기 달콤한 고구마수프 만드는 법 삶은 고구마 요리',
#  '자취생 요리 3분짜장 초간단 짜장면 만들기',
#  '백종원 두부조림 양념장 만들기 끝내주는 간단한 두부요리',
#  '굴전 만들기 감칠맛 뿜뿜 꿀맛나는 굴요리',
#  '연두부 샐러드 먹는법 다이어트 요리 오리엔탈드레싱 만들기 ',
#  '시래기나물볶음 맛있는 시래기요리',
#  '들깨 버섯 순두부찌개 끓이는 법 / 버섯요리 /들깨가루요리 /순두부요리',
#  '두부탕수육 만드는 법 탕수육소스만들기 간단한 에어프라이어 두부요리',
#  '스테이크 맛있게 굽는법 질 좋은 소고기 요리 ',
#  '맑은 오징어무국 요리 깔끔하게 맛있는 아기 오징어국 만드는 법 ',
#  '집에서 낙지탕탕이 연포탕 산낙지 요리 칼국수 낙지죽',
#  '마 넣은 명란젓 무침 만드는법 명란젓 양념 명란요리',
#  '배추전 만드는법 리얼 경상도 토박이의 알배기배추전 요리',
#  '돼지고기전 돼지고기 육전 만드는법 남은 수육 요리',
#  '전자레인지 깻잎지 찜 깻잎 양념장 팁 간단 요리 ',
#  '굴국 끓이는법 무굴국 만들기 육수 없이도 최고! 굴요리 해장 음식 추천',
#  '백종원 오징어볶음 레시피 요리 불맛 나는 오징어볶음 양념 ',
#  '봄동 겉절이 고소한 봄동무침 요리 봄 배추겉절이 만드는 법 ',
#  '표고버섯볶음 간단하게 만드는 반찬 표고버섯요리',
#  '새송이버섯볶음 굴소스 간장만! 새송이버섯요리 버섯종류 반찬메뉴',
#  '바지락술찜 바지락 요리 해감부터 보관법 집에서 소주안주 추천',
#  '백종원 두부조림 양념장 만들기 밥도둑 두부요리 엄지척~!',
#  '백종원 김치볶음밥 레시피 무조건 맛있는 참치 김치볶음밥 만들기 집에서 간단한 캔참치 요리 ',
#  '봄동 겉절이 만드는 법 맛있다고 난리난 봄동무침 요리! 배추겉절이 만드는 법 5분컷 ',
#  '고구마라떼 만들기 쉽게 고구마 찌는법 고구마 요리',
#  '시금치 된장국 끓이는법 만드는법 제철 시금치요리로 시금치국 시금치 데치기',
#  '고구마샐러드 만드는 법 치즈 넣어 맛있는 고구마요리',
#  '황태 콩나물국 끓이는법 국물이 진짜 끝내주는 해장 음식 콩나물국 레시피 요리',
#  '시금치무침 나물 달큰한 국민반찬 제대로 시금치 데치기 요리 팁(비빔밥재료) ',
#  '배추전 만드는법 고소하고 맛있는 알배기배추전 요리',
#  '양배추 새송이버섯 볶음 요리 레시피 깔끔한 양배추볶음 ',
#  '팽이버섯 베이컨말이 팽이버섯 요리 간단한 반찬',
#  '들기름 김치볶음 묵은지들기름볶음 요리 구수한 볶음김치 만드는법',
#  '바삭바삭 황태채볶음 만드는 법 : 황태채요리 /밑반찬',
#  '지금은 솥밥시대, 만능요리 가마솥으로!',
#  '김전 만들기 쉬운 묵은김요리',
#  '고구마라떼 만들기 고구마 찌는법 전자레인지로! 삶은 고구마 요리',
#  '아보카도 요리모음, 아보카도 맛있게 먹는법!!!',
#  '세발나물 무침 만드는 법 세발나물요리',
#  '훈제오리 부추무침 레시피 오리훈제 요리',
#  '계란 두부부침 양념장 만드는 법 세상 맛있고 간단한 두부전 요리 팁 ',
#  '일본식 고등어구이 산뜻한 고등어 요리',
#  '소불고기 황금레시피 국물 자작 소고기전골 요리 납작당면 추가 ~!',
#  '삼겹살조림 에어프라이어 구운 통삼겹살요리',
#  '부추겉절이 만드는법 5분컷 부추무침 레시피 부추요리!',
#  '아삭하고 달달한 무 요리 모음, 한창 맛있는 무~~!',
#  '황태국 북어국 끓이는법 국물 션한 콩나물황태해장국 요리 북어계란국',
#  '당근덮밥 당근 요리 추천 한 그릇 덮밥',
#  '빨간 콩나물무침 레시피 콩나물반찬 중에 제일 좋아하는 콩나물요리',
#  '두부짜글이 쉽고 맛있게 만드는법 얼큰칼칼  부드러운 두부요리',
#  '스팸마요덮밥 간단한 점심메뉴 추천 스팸요리',
#  '돼지고기동그랑땡 매콤하게 만들어요 돼지고기 요리',
#  '간단한 한끼~또띠아 토스트 만드는법 또띠아요리',
#  '스팸요리 스팸 약고추장 애호박비빔밥 간단한 점심메뉴',
#  '간단한 에어프라이어 식빵피자 만들기 식빵 요리 홈브런치',
#  '12월 제철 팥 요리, 팥삶는법 & 찐빵 만들기',
#  '꼬막무침 매콤 꼬막양념장 요리 꼬막 삶는법과 해감까지',
#  '냉동 자숙 문어요리 초간단 문어버터구이',
#  '새송이버섯볶음 만드는 법 간단한 새송이버섯요리 버섯종류',
#  '파래무침 만드는 법 파래요리 무우파래무침',
#  '배추 넣은 당근샐러드 당근 요리',
#  '백종원 제육볶음 레시피 실패없는 쌈도둑 고추장 대패 제육볶음 양념장! 인기만점 대패삼겹살 요리 ',
#  '굴무침만들기 초간단 굴무생채 만드는법 굴 세척부터 굴요리 밥반찬 레시피!',
#  '에어프라이어 군고구마 시간 꿀뚝뚝 비법은? 에어프라이어 고구마 요리 고구마 보관방법',
#  '팽이버섯전 만드는법, 팽이버섯 세척 손질은 이렇게! 다이어트요리',
#  '몬테크리스토 샌드위치 만들기 ! 에어프라이어 요리~ ',
#  '미역줄기볶음 만드는 법 간단한 밑반찬 만들기 종류 미역줄거리볶음 요리 비법!',
#  '연어 파피요트 분위기 나는 홈파티 음식 생연어 연어요리',
#  '무청시래기 나물 볶음 부드럽고 구수한 나물반찬 무청시래기요리',
#  '베이컨숙주볶음 숙주 요리',
#  '단호박 찌는법 달콤 맛있는 단호박 샐러드 요리 까지~',
#  ' 초간단 순두부계란찜 만드는법 국대신 찌개대신 먹기 좋은 레시피  순두부요리 계란요리',
#  '옥수수범벅 만들기 쫀득하고 달콤한 건강간식 찰옥수수요리',
#  '치즈계란찜 만들기 전자렌지로 만드는 초간단 자취 요리',
#  '늙은호박죽 만들기 호박죽 늙은호박요리 꿀팁 더해 더 맛있게',
#  '식빵 요리 크루통 만들기 두가지 방법으로',
#  '크로크무슈 만들기 홈 브런치 메뉴 모짜렐라치즈 요리',
#  '백종원 무우파래무침 만드는법 파래요리 초무침',
#  '소세지야채볶음 굴소스 맛보장 아기 비엔나 소세지 볶음 요리 팁 쏘야볶음 레시피 ',
#  '토마토 계란볶음 요리 간단하고 든든한 저탄고지 식단 토달볶',
#  '알배기 배추전 만드는법 엄마 꿀팁 제대로 부친 레시피 배추 요리 이겁니다.',
#  '순두부 열라면 요리 라면 맛있게 끓이는법 얼큰 칼칼한 맛!',
#  '꼬치 어묵탕 끓이는법  오뎅국 레시피 따끈한 국물요리',
#  '시금치된장국 만드는 법 달큰 세상 맛있는 아기 시금치국 요리 된장국 끓이는법 ',
#  '중화풍 양배추 샐러드 12월 제철 농산물로 만든 요리 ',
#  '참나물무침 겉절이양념으로 즐기는 단감요리',
#  '고등어무조림 양념 매콤하게 고등어 조림 요리 오늘 저녁메뉴 추천',
#  '참치 비빔밥 만드는법 도시락의 추억 레시피 참치캔요리',
#  ' 톳나물무침 톳두부무침! 톳요리 이렇게 해드세요 ',
#  '새우감바스 만들기 감바스 알 아히요 두부면 파스타 요리 먹는법',
#  '시금치된장국 만드는 법 시금치국 시금치요리 ',
#  '김무침 만드는법~ 묵은김요리',
#  '간장 두부조림 만드는법 아이들반찬 으로 좋은 밑반찬 두부요리 ',
#  '팽이버섯전 크래미 넣고 더 맛있게 팽이 크래미전 팽이버섯요리',
#  '김치콩나물국 끓이는법 겨울 국 요리 개운하고 시원해~ ',
#  '파계란볶음밥 만들기 초간단 간장 계란 볶음밥 자취생요리',
#  '고추참치 비빔밥 덮밥 만드는법 자취생 혼밥 요리',
#  '백종원 콩불 레시피 콩나물불고기 대패삼겹살 요리',
#  '쫀득한 연근조림 만드는 법 끝까지 쫀득쫀득 팁 맛있는 일주일 밑반찬 연근요리 ',
#  '순두부 그라탕 만들기 치즈 듬뿍 순두부 요리',
#  '탱글탱글 맛있는 굴전 만들기 포기할수 없는 맛~ 제철 굴요리',
#  '뱅쇼 만드는법 환절기 감기 잡는 뱅쇼 재료 레드와인 요리 ',
#  '꽈리고추조림 만드는 법 /꽈리고추요리',
#  '시금치된장국 달달하고 구수한 국 요리 시금치 요리 ',
#  '에어프라이어 고구마굽기 사르르 녹는 허니버터고구마 요리',
#  '명란 두부찌개 끓이는법 속이 시원한 맑은찌개 명란요리 두부요리 국물요리',
#  '깻잎 두부전 두부부침 간단한 두부요리 깻잎전',
#  '고소하고 깔끔한 초간단요리 새우 오일파스타 만드는법',
#  '쫀득한 우엉조림 만드는법 팁은 이것 맛보장 김밥재료 우엉조림 우엉채조림 요리 팁 ',
#  '냉동 닭가슴살 요리! 다이어트 식단, 맛있는 완자탕 만드는 법 ~ ',
#  '바지락 칼국수 레시피 탱글하고 쫄깃한 손칼국수 반죽 만드는법 면요리 바지락요리',
#  '부라타치즈 단감샐러드 with 참간초드레싱 / 단감요리',
#  '배추덮밥에 잘 어울리는 배추 볶음 요리 ',
#  '쿠참 스팀 에어프라이어  웨지감자 에어프라이어 감자요리 간단한간식 만드는법으로 좋아요. ',
#  '고민 필요 없는 일주일 다이어트 식단! 훈제오리 요리 다이어트 도시락 만들기',
#  '새콤달콤 오이무침 황금레시피 아삭 입맛 확 살려주는 5분컷 즉석 오이무침 요리 팁 ',
#  '양파무침 아삭매콤새콤 생채 양파 요리',
#  '굴전 만들기 만드는법 탱글함이 좋은 굴요리 겨울 별미~ 막걸리 안주 ',
#  '시금치된장국 만드는 법 아침국물요리 만들기 ',
#  '백종원 길거리토스트 만들기 햄치즈토스트 든든한 식빵요리',
#  '굴밥 만드는법  굴 요리 버섯 무 밥 양념장 만들기 12월 제철 음식',
#  '감자스프 만들기 감자 요리 부드러운 브런치 만들기',
#  '순두부 요리 순두부찌개 끓이는법 양념도 간단해요',
#  '고구마 샐러드 만들기, 찐 고구마 요리',
#  '에어프라이어 요리 황태채 황태구이 핵맛 맥주안주 인정!',
#  '도토리묵무침, 몸속에 쌓인 중금속 해독과 배출에 좋은 도토리묵요리!',
#  '허닭 닭가슴살 어묵 핫바를 활용한 어묵탕 요리',
#  '돼지고기 삼겹살 김치찜 씻은 묵은지찜 요리',
#  '갓김치담그는법 제철에 담아먹는 갓 요리 갓김치',
#  '숙주나물무침 요리 향긋함 더해 두배로 맛있는 숙주나물데치기 팁 초간단 반찬거리 ',
#  '숙주나물무침 요리 아삭하게 숙주나물 데치기 나물반찬 만들기',
#  '참나물무침 만드는 법 겉절이 양념으로 생생하게 참나물 요리',
#  '파김치 담그는법 양념 10분컷 맛있다고 난리난 나만의 쪽파김치 담그는법 요리 ',
#  '백종원 대패삼겹살 덮밥 대패삼겹살 요리 간단! 한그릇 요리',
#  '애호박요리 간단한 밑반찬 만들기 애호박구이',
#  '순두부 양념장 만들기 고소하고 부드러운 순두부 요리',
#  '콩나물볶음 만드는 법 무침보다 간단한 맛있는 콩나물 요리',
#  '간단한 베이컨 샌드위치 만들기 아침식사 메뉴 베이컨요리',
#  '가지요리 비엔나 소세지 돌돌 오늘 저녁메뉴 추천하는 홈파티 음식',
#  '백종원 굴전 홍콩식 굴전만들기 맛있는 굴요리 ',
#  '초간단 백종원 라볶이 만들기, 라면요리',
#  '베이컨 숙주볶음 숙주요리 간단한 밑반찬 만들기 ',
#  '대패삼겹살요리 김치랑 볶았어요~원팬요리',
#  '진미채버터구이 만들기. 혼술안주로 좋은 진미채요리.',
#  '감자조림 만드는 법 밥도둑 감자요리 매운 고추장 감자조림 ',
#  '느타리버섯요리 느타리버섯무침 간단 흑임자 드레싱 만들기',
#  '닭가슴살 요리 인도커리 버터치킨 카레 맛있게 만드는법',
#  '라이스페이퍼 튀김 요리 김말이 만들기 아이들간식',
#  '고구마맛탕 만들기 / 고구마요리 /고구마빠스',
#  '홍시스무디 만들기 달콤한 홍시요리',
#  '막걸리 안주 참나물요리 고소한 참나물전 만들기',
#  '팥밥 만드는 법 팥요리12월 제철음식 농산물 대표곡식',
#  '스팸마요덮밥 만들기 맛있는 스팸요리 소스 레시피 간단한 저녁메뉴',
#  '고구마샐러드 만드는 법 고구마 전자레인지 꿀맛 고구마요리 ',
#  '아보카도 샐러드 홈 파티 요리 샐러드소스 만드는 법',
#  '숙주나물무침 크래미 숙주 요리 쉽게 만드는 반찬',
#  '삼겹살 요리 간단버젼 동파육 만들기 레시피',
#  '알배추 샐러드 아삭아삭 겉절이 보다 쉬운 배추 요리',
#  '토마토 카프레제 샐러드 요리 카프리제 발사믹식초 소스 만들기',
#  '묵은지찜 씻은 묵은지지짐 간단한 요리',
#  '마카로니 샐러드 만들기 마카로니 요리 삶기 삶는법',
#  '무 굴국 만드는 법 굴국 끓이는법 굴 요리',
#  '전기밥솥 굴밥 만드는법 무 굴밥 겨울 굴 요리',
#  '감자전 만들기 쫀득쫀득 반죽 1분컷 팁 감자전 믹서기 레시피! 간단한 감자 요리 ',
#  '샐러드같은 쌈채겉절이  산뜻하고 고소한맛까지 좋은 쌈채요리',
#  '닭갈비 만들기  레시피 양념장 만드는법 까지! 손님초대요리',
#  '국간장 두부조림 만드는 법 / 두부요리 ',
#  '에어프라이어 고구마 말랭이 만드는법 고구마요리 간식',
#  '[채식요리지도사 2급] 2회차 수업후기(코티지파이, 참치맛샐러드, 초코칩쿠키 등)',
#  '캔참치 요리 참치전 만드는법 깻잎 추가~ 막걸리 안주',
#  '에어프라이어 라면땅 만들기 간단한 라면요리',
#  '참치김치찌개 맛있게 끓이는법 캔참치 요리',
#  '전기압력밥솥 굴밥 만드는법 제철 굴요리 ',
#  '11월 제철음식 굴국 끓이는법 시원한 맛이 좋은 굴요리',
#  '콘옥수수전 요리 _ 비 오는 날 음식으로 달콤한 옥수수전 부치기',
#  '점심메뉴 추천 한그릇요리 소세지 볶음밥',
#  '굴전 만들기 탱글탱글 고소한 굴 요리 세척 씻는법 꿀팁~',
#  '무우 파래무침 만드는 법 비린내 제로 팁 새콤달콤 반찬만들기 파래요리 ',
#  '초간단 계란국 끓이는법 따뜻한 아침국 계란 요리',
#  '드로잉 액정타블렛 장은테크로 그림그리기 취미 스타트',
#  '[Fun! Fun! 펀딩] 전통의 아름다움이 그대로! 비단부채 드로잉 키트',
#  '북한산 카페 선운각 어반스케치 (펜 드로잉 일러스트 마카 스케치 그림)',
#  '대구디지털드로잉학원 취업 향한 발판!',
#  '[스페인맥주] 마오우 세션 아이피에이, 캔맥주 드로잉',
#  'Oil Pastel로 노릇노릇 토스트 굽기 [오일 파스텔로 그리는 카페 드로잉]',
#  '[디지털드로잉] 프로크리에이트 수채화 화분 속 식물 그리기',
#  '화실그리다 드로잉 클래스-수강생 작품',
#  '창의수업/실드로잉/일산아동미술학원/대화동미술학원/일산미술학원/풍동미술학원/',
#  '[부산인물드로잉]부산펜드로잉클래스, 부산일러스트클래스 _부산취미미술,부산직장인미술',
#  '디지털 드로잉과 피아노',
#  '요즘 그림고 있는 것들 / 펜드로잉, 외주작업, 수채화 일러스트 ⛄️✨🌿',
#  '펜 드로잉으로 표현한 덴마크의 가구 디자인',
#  '펜 드로잉 - 창틀 위에 앉은 고양이 일러스트',
#  '오랜만에 아이패드로 디지털 드로잉 연습',
#  '[집그리기/수채일러스트] 펜드로잉, 다니엘스미스물감, 캔손폰테네',
#  '오일 파스텔로 그리는 카페 드로잉_보니룸의 오일 파스텔 클래스',
#  '[디지털드로잉] 프로크리에이트 드로잉 책 보며 이것저것 그려보기2',
#  '프리즈마 색연필 드로잉',
#  '《갤러리아×쾨닉 서울》드로잉 워크샵을 진행했어요.-소통하는 그림연구소',
#  '[라이프가드닝위크-드로잉기록] 김계선밴드',
#  '펜드로잉 - 캐나다 옐로나이프 감성숙소를 그리다 ',
#  '홍제동 카페 아이텐티티커피랩 일러스트 펜 드로잉 & 마카 채색 과정 ',
#  '생활스케치 펜그림/기초 드로잉',
#  '빼빼로데이 일러스트 그리기 디지털드로잉 음식그림 11월 아트웍 만들기',
#  '[매일그림한장] 주말일상, 인물드로잉, 손오공, 유동골뱅이 밀키트',
#  "즐거웠던 '배성규 작가님의 아이패드 드로잉 원데이 클래스'",
#  '<오일 파스텔로 그리는 카페 드로잉> 출간 기념 작가 인터뷰 & 드로잉 시연',
#  '[디지털드로잉] 온라인 수업 듣고 따라 그려보는 아이패드 드로잉',
#  '한국근대문학관_드로잉뉴딜프로젝트(~10/9)',
#  '마포구 당인리발전소 (서울화력발전소) 펜 드로잉 손그림 일러스트 ',
#  '[공지] 크리스마스 미니 드로잉 이벤트! ',
#  '이색데이트 소마 드로잉카페 세종새롬점 액션페인팅 신나요!',
#  '[라인드로잉] 색연필로 얼굴 그리기, 양손드로잉',
#  '드로잉 펜그림/김선이그림방',
#  '오일 파스텔로 빈티지 카페 소품 그리기 [오일 파스텔로 그리는 카페 드로잉]',
#  '[디지털드로잉] 아티스트 Oamul Lu의 그림 모작 _ Lantern Festival',
#  '강남역 펜 드로잉 수업 23기 모집 (5주 과정)',
#  '[캔맥주/맥주그림] 마오우 클래시카 캔맥주 드로잉, (+ 일상드로잉)',
#  '펜 드로잉 X 마카 스케치 일러스트 - 쏘리에스프레소바 광화문 서촌 카페',
#  '[디지털드로잉] 남편의 여행 그림선물 _ 남사로 습지',
#  '[수채일러스트] 인물드로잉, 매일 그림 그리기',
#  '코픽 마카 드로잉 연습 (일러스트 채색 인테리어 스케치)',
#  '[독일맥주/세계맥주] 길데 필스너 캔맥주 드로잉',
#  '[아이패드드로잉] 클래스유의 디지털드로잉 인강',
#  '[캠핑맥주/캔맥주] 노르디스크 캠핑맥주, 캔맥주 드로잉',
#  '손쉽게 색칠해보는 마카 드로잉 스케치 일러스트 (코픽 마커 발색 기본구성)',
#  '[일상드로잉] 수채일러스트, 캔트지에 쉬민케 고체물감',
#  '[디지털드로잉] 정물 그리기 4 _ 전화기',
#  '서울 취미 미술 그림 동호회 아트노마드 종로 을지로 모임 후기 (아이패드 디지털 드로잉 일러스트)',
#  '동네 마실 카페 드로잉 어반스케치 (코픽 일러스트 마카 스케치)',
#  '[인물크로키] 색연필드로잉, 얼굴그리기, 인물화',
#  '펜 드로잉 & 마카 스케치 일러스트 - 북한산 419 카페거리 몽브루에서 ',
#  '[인물드로잉] 어렵다 얼굴 그리기, 인물크로키',
#  '펜화 & 마카 드로잉으로 담은 광주 남한산성 카페 들 (일러스트 스케치 과정)',
#  '[펜드로잉] 잡화점',
#  '[얼굴그리기] 매일 한장, 색연필 인물 드로잉',
#  '[인물그리기] 색연필드로잉, 인물크로키',
#  '[디지털드로잉] 아티스트 Oamul Lu의 그림 모작 _ January',
#  '[그림기록/인물] 얼굴그리기, 인물드로잉, 크로키',
#  '[디지털드로잉] 가을풍경',
#  '[디지털드로잉] 프로크리에이트 레트로웨이브 풍경',
#  '[인물드로잉] 인물크로키, 코이노어 매직 색연필 드로잉',
#  '펜 드로잉 & 마카 스케치 채색 과정 (이태원 더 버뮤다 일러스트 기초 손그림)',
#  '[크로키/인물화] 라인드로잉, 얼굴그리기',
#  '아트노마드 을지로 모임 후기 (서울 드로잉 일러스트 그림 동호회 취미미술) ',
#  '[크로키/인물화] 색연필로 얼굴 그리기, 라인드로잉',
#  '[디지털 드로잉] 프로크리에이트 할로윈 잭오랜턴 호박등',
#  '[취미/그림그리기] 코이노어 매직 색연필 인물드로잉',
#  '[디지털드로잉] 프로크리에이트 _ 호수 위 나무 풍경',
#  '[편의점맥주] 스퀴즈브루어리 말표 청포도에일, 캔맥주드로잉',
#  '[선물/드로잉북] 아르쉬 양장북, 수제양장북',
#  '[인물크로키] 양손드로잉, 얼굴그리기, 색연필 인물화',
#  '[디지털드로잉] 정물 그리기 3 _ 음료수잔',
#  '[자화상] 연필드로잉, 왼손드로잉, 인물그리기',
#  '[디지털드로잉] 꽃을 든 소녀',
#  '[주말/일상] 매일그리기, 왼손드로잉, 크로키',
#  '[연필인물화] 라인드로잉, 인물크로키',
#  '10,11월 아이패드드로잉 수강생작품',
#  '트리방울 디지털드로잉 일러스트 그리기로 12월 공부주간계획표 양식 편집디자인 2021',
#  '일요일의 색연필 드로잉',
#  '[디지털 드로잉] 장미',
#  '[양손드로잉] 왼손으로 그림 그리기, 인물드로잉',
#  '[디지털드로잉] 어반스케치 _ 서촌재',
#  '[디지털드로잉] 탁자위 소품',
#  '[도서출판 이종 X 카카오 메이커스] 드로잉 취미 키트 OPEN!!!',
#  '잉크드로잉- 에코라인 잉크',
#  '액정타블렛 추천 와콤 신티크프로16 디지털 드로잉 후기',
#  '러빙핸즈에서 재능나눔 패턴아트와 디지털드로잉까지 ',
#  '색연필 인물드로잉',
#  '합정 드로잉카페 이색데이트 하기 좋은 보이드블랭킷 ',
#  '[수채일러스트]불타는 하늘, 일몰 풍경 드로잉',
#  '[디지털드로잉] 정물 그리기 2 _ 식물그리기',
#  '[일상드로잉] 대학로 연극, 협상 1948 관람 후',
#  '[수채일러스트] 가을하늘, 동네풍경 드로잉',
#  '[인물크로키] 매일 인물 드로잉, 색연필드로잉',
#  '화분그리기 / 색연필/ 색연필드로잉',
#  '[거제속눈썹펌] 드로잉튜드(Drawingtude);고현속눈썹펌',
#  '[얼굴그리기] 인물드로잉, 색연필드로잉, 매일그리기',
#  '인체드로잉',
#  '오일 파스텔 그림 그릴 때 필요한 재료와 특징, 사용법 알아보기 [ 오일 파스텔로 그리는 카페 드로잉]',
#  '21년 12월호 드로잉 어텐션이 발간 되었습니다',
#  '색연필 드로잉 두번째',
#  '[펜드로잉] 오늘도 나무를 그리다 _ 41~45',
#  '2022. FAS 겨울 특강- 인체드로잉 - 강산하 강사',
#  '무선 펜타블렛 와콤 인튜어스 프로로 디지털드로잉 일러스트 그리기',
#  '교회 성탄 행사  / 라인드로잉 & 캘리그라피 ',
#  '미대입시 Q&A1편 - 드로잉기본재료와 디자인입시 채색기본재료 소개!',
#  '이지드로잉노트 드로잉패드 1060plus 수업용판서패드로 사용할때 좋다좋아',
#  '1일1드로잉_날다_질문그림_생각그림',
#  '노란 은행잎 일러스트 그리기 디지털드로잉 10월 가을 아트웍 만들기',
#  '아이패드 드로잉으로 스티커와 엽서 굿즈만들기 with 쿨쿨스튜디오',
#  '간만에 그려보는 펜 드로잉 - 엄마의 여행 사진 그려보기',
#  '[펜드로잉] 목포 얼음창고',
#  '크리스마스장난감 추천 : 핑크퐁 아기상어 드로잉패드 ',
#  "[공지] 도서출판 이종 X 카카오 메이커스 '앤드류 루미스의 빈티지 드로잉 취미 키트'",
#  '웹툰학과 캐릭터 디지털 드로잉 특강수업 진행',
#  '색연필드로잉 인물화 손그림그리기',
#  '아이패드 드로잉 ) 불광동커피공방 그리고 요가젠은평',
#  '크리스마스장난감추천 아기상어올리와 윌리엄 드로잉패드 !',
#  '건대 맛집 | 피자가 맛있는 드로잉레시피(메뉴, 피자추천)',
#  '읏, ,츄워 , , (셀프사진관, 인물 드로잉, 살모닝) ',
#  '부평 이색 데이트 즐기기 좋은 드로잉카페, <NRFP>',
#  '핑크퐁 아기상어 스마트 드로잉패드 크리스마스장난감추천!',
#  '목화 포레스트 오일파스텔 드로잉 ♡제이갤러리 겨울 취미미술 원데이클래스 ',
#  '1일1드로잉 _아이돛_따뜻한 포옹그림_항해',
#  '[공지] [we draw 11월 그린님 모집] 오일 파스텔로 그리는 카페 드로잉',
#  '[드로잉] 펜드로잉, 마카드로잉, 오일파스텔 일러스트, 아이패드 드로잉 ✍🏻',
#  '여행드로잉 엽서 아트인라이프, 으린이의 색칠놀이, 정대리의 취미생활',
#  '11월의 색연필 드로잉',
#  '스튜디오8 디자인문구 드로잉노트로 컬러테라피',
#  '[부산/체험] 드로잉카페 - 오늘, 그림 한장',
#  '가을 멜로 인생영화추천 그녀her 호아킨피닉스 명작 띵작그림 드로잉후기',
#  '1일1드로잉 _이벤트준비_만화카페',
#  '[매일드로잉] 21.11.13 가을타입 ',
#  '<일산만화학원/일산미술학원> 얼굴 드로잉 - 기초편',
#  '해바라기 그림그리기 : 순서만 알면 쉬운 꽃 드로잉',
#  '[디지털드로잉]토분 속 아름다운 꽃 2',
#  '[디지털 드로잉] 수채화 가을 나뭇잎외',
#  '[오일파스텔 드로잉] 작가 그림 따라그리기 _ 풍경화',
#  '스튜디오8 컬러테라피 드로잉노트 추천!',
#  '[오일파스텔 드로잉] 아몬드와 서양배',
#  '스튜디오8 컬러테라피 디자인문구 / 프리미엄 드로잉노트',
#  '프로크리에이트 드로잉 _ 등대 Red Light house',
#  '펜 드로잉 - 아버지와 고양이 (일러스트 펜화 손그림 인물화 스케치) ',
#  '취미미술 (기초 여행스케치, 어반스케치,일상드로잉, 펜드로잉) 신청해요🎨🖌🖋',
#  '화려한 샹들리에와 함께 분당 브런치를 정자역 카페드로잉에서 먹었어요',
#  '[디지털드로잉] 미완성 겨울 풍경',
#  '크리스마스장난감추천 핑크퐁 아기상어 스마트 드로잉패드',
#  '겨울엔 이만한 취미생활이 또 없지🤭 인체드로잉의 시간 + Line of Action',
#  '12월 <시네마드로잉클래스> 모집합니다 ',
#  '<1일 1드로잉> 10쇄 기념, 스테들러와 콜라보 이벤트!!! ',
#  '세종시 일상 | 소마드로잉 카페 새롬점에서 나만의 액자 만들기 체험',
#  '크리스마스장난감추천 핑크퐁 아기상어 스마트 드로잉패드',
#  '[노트폴리오 이야기] 아이패드 드로잉 2기 어떠셨어요?(+수업모습/후기/수강생 작품)',
#  '펜드로잉 나무와 집 풍경드로잉 어반스케치',
#  '크리스마스 조카장난감선물로 핑크퐁 아기상어 스마트 드로잉패드 추천해요!',
#  '가수  헨리 팬아트 그려보기 / 아이패드 드로잉 / 색연필질감내기',
#  '[아이패드드로잉] 아방의 그림수업 _ 1. 지하철 앞에서',
#  '[인물화/드로잉] 색연필 드로잉, 인물크로키',
#  '스튜디오8 디자인문구 드로잉노트 민트',
#  ' 여행스케치 / 여행드로잉 엽서 아트인라이프로 즐거운 취미생활~~',
#  '매력터지는 펜화드로잉',
#  '[크로키] 색연필드로잉, 인물 그리기',
#  '벨벳표지 힐링템! 스튜디오8 디자인문구 드로잉노트',
#  '[아이패드드로잉] 감상주점 김작가의 이중생활 _ 이작가',
#  '드로잉 풍경수채화 돌담이 있는 정문 마을 대문',
#  '[인물크로키]연필드로잉, 얼굴그리기',
#  '[공지] [현대백화점 문화센터] 아이패드 드로잉 강의합니다! :)',
#  '[공지] [강의모집] 아이패드 프로크리에이트 라인드로잉 특강 5기 모집합니다♡',
#  '세종 드로잉카페에서 아이들과 미술체험_소마드로잉 새롬점',
#  '실크스크린 첫 시간, 멋진 드로잉을 프린팅!',
#  '[아이패드드로잉] 아방의 그림수업 _ 9. 피렌체를 걷다가 외...책 완료',
#  'KNDA대한천연디자인협회 비누자격증반 ; 투톤마블비누,삼색드로잉비누',
#  '[세종] 드로잉카페 소마드로잉카페 세종새롬점 이색 데이트 완전 추천!!',
#  '일러스트학원 드로잉 기초부터 응용까지!',
#  '[왼손드로잉] 얼굴그리기, 인물크로키',
#  '드로잉)13기 - 19 오토바이',
#  '디지털드로잉학원 초보자도 쉽게 배워요',
#  '액정타블렛 추천 와콤 신티크프로16 디지털 드로잉 후기',
#  '액정타블렛 와콤 신티크프로 16 사용기 - 필기부터 디지털드로잉까지 자유롭게',
#  '디지털드로잉 지원 펜타블렛 추천, 와콤 인튜어스 CTL-6100WL 사용기',
#  '대구디지털드로잉학원 취업 향한 발판!',
#  '무선 펜타블렛 와콤 인튜어스 프로로 디지털드로잉 일러스트 그리기',
#  '펜 타블렛 와콤 인튜어스 프로로 디지털 드로잉 해보자.',
#  '액정타블렛 와콤 신티크 프로 16 리뷰 및 디지털드로잉 후기',
#  '[공지] 와콤 태블릿 CTL-6100WL 디지털 드로잉 입문자 필수템',
#  '파블로 아트센터 디지털 드로잉클래스, 온라인 미술 미술 교육 봉봉.',
#  '[디지털드로잉] 정물 그리기 2 _ 식물그리기',
#  '디지털 드로잉 5세 온라인 아동 미술 교육 파블로아트센터',
#  '분당아트웍학원 디지털드로잉으로 입시미술 준비하기',
#  '디지털드로잉 펜 타블렛 추천 와콤 인튜어스 CTL-6100WL 후기',
#  '파블로아트센터; 디지털드로잉 원데이클래스 후기',
#  '그림그리기 어플 추천: 클립 스튜디오 EX로 디지털드로잉',
#  '온라인 아동 미술교육 봉봉 앨리스달튼 디지털 드로잉 원데이 클래스 @파블로아트센터 ',
#  '와콤 인튜어스 프로 : 디지털드로잉을 위한 펜타블렛',
#  '부드러운 느낌의 그림 그리기 /수채화 그림 / 여자사람그리기 /아이패드 /드로잉 / 디지털드로잉',
#  '파블로아트센터 "앨리스 달튼브라운 - 빛이 머무는 자리" 디지털 드로잉 수업 후기',
#  '액정타블렛 추천, 와콤 신티크22 디지털 드로잉부터 사진 편집까지 가능한 입문용 타블렛',
#  '이하미술공방 디지털 드로잉 초급자 클래스',
#  '[디지털드로잉] 프로크리에이트 수채화 화분 속 식물 그리기',
#  '디지털드로잉 전성시대, 그림그리기 어플은 <클립스튜디오페인트>로!',
#  '온라인 아동 미술 교육 파블로아트센터 앨리스 달튼 디지털 드로잉 원데이 클래스',
#  '오랜만에 아이패드로 디지털 드로잉 연습',
#  '서울 취미 미술 그림 동호회 아트노마드 종로 을지로 모임 후기 (아이패드 디지털 드로잉 일러스트)',
#  '디지털 드로잉과 피아노',
#  '파블로아트센터 디지털드로잉 원데이클래스 체험으로 아이와 유화 페인팅',
#  '부산디지털드로잉학원 ! 손끝에서부터 시작하기 !',
#  '빼빼로데이 일러스트 그리기 디지털드로잉 음식그림 11월 아트웍 만들기',
#  '파블로아트센터 디지털드로잉 미술도 첨단세상',
#  '러빙핸즈에서 재능나눔 패턴아트와 디지털드로잉까지 ',
#  ...]

# %%
df2 = dataCombine1[::3]  #3번째 지나면 1개씩 뽑기 (0, 3, 6...)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2790 entries, 0 to 8367
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             2790 non-null   int64
#  1   Unnamed: 0.1      1116 non-null   float64
#  2   keyword           1116 non-null   object
#  3   Unnamed: 0.1.1    632 non-null    float64
#  4   keyword.1         632 non-null    object
#  5   title             2790 non-null   object
#  6   nickname          2790 non-null   object
#  7   datetime          2790 non-null   object
#  8   Unnamed: 0.1.1.1  74 non-null     float64
#  9   keyword.1.1       74 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 218.1+ KB

# %% [markdown]
# # 데이터 전처리 (url,숫자,영어,#,특수문자제거, 정규화 )

# %%
df = pd.read_csv("/Users/leesh970930/Desktop/data_team/dataCombine1.csv", delimiter=",")

# %%
data = df.drop(columns=['Unnamed: 0'], axis=1)

# %%
data.head()
# Out:
#    index  Unnamed: 0.1 keyword  Unnamed: 0.1.1 keyword.1  \
# 0      0           0.0      음악             0.0        음악
# 1      1           1.0      음악             1.0        음악
# 2      2           2.0      음악             2.0        음악
# 3      3           3.0      음악             3.0        음악
# 4      4           4.0      음악             4.0        음악
#
#                                   title            nickname  \
# 0      적재(정재원) - The Door [음악/노래/추천/공유]                  양양
# 1  음악작업용 외장하드 2테라, 내장SSD랑 속도 차이 거의 없을 무              MosicA
# 2                미디작곡학원 나만의 음악을 만들고 싶다면  조감자\n(stella_lucy)
# 3                      실용음악 선택이 미래를 좌우!                  용뇽
# 4                    [음악교육신문] 피아니스트 이정아              음악교육신문
#
#               datetime  Unnamed: 0.1.1.1 keyword.1.1
# 0   2021. 12. 1. 14:17               NaN         NaN
# 1   2021. 9. 21. 19:00               NaN         NaN
# 2  2021. 11. 30. 14:04               NaN         NaN
# 3   2021. 12. 2. 11:13               NaN         NaN
# 4  2021. 11. 12. 13:57               NaN         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8370 entries, 0 to 8369
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             8370 non-null   int64
#  1   Unnamed: 0.1      3348 non-null   float64
#  2   keyword           3348 non-null   object
#  3   Unnamed: 0.1.1    1897 non-null   float64
#  4   keyword.1         1897 non-null   object
#  5   title             8370 non-null   object
#  6   nickname          8370 non-null   object
#  7   datetime          8370 non-null   object
#  8   Unnamed: 0.1.1.1  223 non-null    float64
#  9   keyword.1.1       223 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 654.0+ KB

# %%
#conents에 해당하는 부분만 'docs'라는 리스트로 만듦

docs = list(data['title'])

# %%
docs
# Out:
# ['적재(정재원) - The Door [음악/노래/추천/공유]',
#  '음악작업용 외장하드 2테라, 내장SSD랑 속도 차이 거의 없을 무',
#  '미디작곡학원 나만의 음악을 만들고 싶다면',
#  '실용음악 선택이 미래를 좌우!',
#  '[음악교육신문] 피아니스트 이정아',
#  '캐릭터라이선싱페어2021에서 만난 음악교육 애니메이션 고둥둥심포니',
#  '[책] 상페의 음악 / 당신은 무엇을 동경하십니까?',
#  '[유아음악] 세계적인 유아음악 프로그램 "킨더뮤직(Kindermusik)" ',
#  '[BDCABU]재즈 역사상 가장 뛰어난 보컬 빌리 홀리데이의 음악!',
#  '실용음악학과 서울권 진학을 알아본다면',
#  'LP 레코드로 한국대중음악을 즐기기',
#  '소란(SORAN) - 내꺼라면 [음악/노래/추천/공유]',
#  '[음악장비]묵직한 세츄레이션의 Acme Audio Opticom XLA-500  Series Tube Compressor',
#  '실용음악학과 현실적인 활동과 취업방향 잡고싶다면!',
#  'EMI 시네마 클래식 - 영화로 즐기는 클래식 음악',
#  '[음악교육신문] 「피아노 석세스 올인원」 출간 (예솔출판사)',
#  '[2022 살롱드파주X그레이스제이피아노] 음악캠프 (플룻/피아노/성악)',
#  '보컬레슨 추천 - 음악 전문 온라인 교육 플레이샵 ',
#  '실용음악 비전공자로 성공하는 방법',
#  '[킨더뮤직] 영유아에게 백색소음보다 음악이 더 좋은 이유?',
#  '서울예대 실용음악과 2022 수시 1차 4명 합격',
#  '롤링 스톤 매거진(선정) 역대 위대한 음악 500(개정판) TOP 10 ',
#  '10CM(십센치) - 어제 너는 나를 버렸어 [음악/노래/추천/공유]',
#  '[음악장비]깔끔한 니브 색채의 원조 AMS NEVE 1073 LB Mic Preamp 500 시리즈 마이크 프리앰프',
#  '음악에서 무엇을 들어 낼 것인가 - 애런 코플랜드',
#  '[음악교육신문] 한세대학교 일반대학원 음악과장 유영재 교수',
#  '바흐(J.S.Bach) - The #1 Bach Album, 서양음악의 아버지',
#  '[음악교육과 대학원] 상담 및 문의',
#  '[BDCABU]20세기 최고의 팝가수  프랭크 시나트라의음악!',
#  '제주시피아노연습실&음악연습실 ',
#  '(유아음악) 킨더뮤직이 사회정서 발달에 주는 영향',
#  '익숙한 음악임에도, 현타가 몰려오게 할 기타(커버) ⑬ 메탈리카 "Master of Puppets" ',
#  '실용작곡, 2022 명문 실용음악대학 수시 최종 합격생 소개!!',
#  '10월에 듣는 깊은 록 음악) 마그마 - 잊혀진 사랑',
#  '유튜브(Youtube) 배경음악 제작ㅣ인트로, 아웃트로, 중간 화면전환 브금 효과음 사운드(Feat. 국악기)',
#  '[음악교육신문] 정하림 귀국 비올라 독주회',
#  '돌싱글즈2 5회 캠핑카데이트 노래 BGM 배경음악',
#  "네이버 이달의 블로그 '음악' 부문 선정, 3년 연속!!!",
#  '[BD MUSIC]래그타임 피아노의 선구자!  젤리 롤 모턴의 음악',
#  '[우리명소] 밤이 아름다운 신포동 음악카페거리',
#  '(유아음악) 킨더뮤직이 창의력 발달에 주는 영향',
#  '(❤️중등음악임용/피아노스토리) 전국의 모든 중등음악임용 응시 수험생 여러분들 꼭 시험 잘보세요~기도할께요!',
#  '홍대 실용음악과 수시 실용작곡 합격생 배출!!',
#  '히키(Hickee) - Hello (쇼윈도 : 여왕의 집 Vol.1) [음악/노래/추천/공유]',
#  '[음악교육신문] 피아니스트 이양숙',
#  '슬기로운 산촌생활 8회 노래 BGM 배경음악',
#  '[BD MUSIC]프랑스 대중 음악계의 대부, 세르주 갱스부르의 음악!',
#  '[음악도화지] 크리스마스 데코북 증정 EVENT',
#  '(❤️중등음악임용/피아노스토리) 2차실기 레슨 대면 및 비대면 선예약 언제나 가능 하세요! ',
#  '서울예대 실용음악과 2022 수시 최종합격 2명 ',
#  '[음악교육신문] 서울신학대학교 교회음악과 강수정 교수',
#  '[음악교육신문] 한세대학교 예술대학원 피아노교수학과',
#  '[음악교육신문] Georgia Central University',
#  '[음악교육신문] 피아니스트 김현정 글로리아',
#  '[음악교육신문] 스타인웨이 교육파트너, 스텝(STEP) 강사 모집',
#  '[음악교육신문] 플루티스트 한예지 귀국 독주회',
#  '[음악교육신문] 제1회 창원 국제 음악·무용 콩쿠르 / 페스티벌',
#  '[음악교육신문] 색소포니스트 루카스',
#  '[음악교육신문] 작곡가 박성미',
#  '[음악교육신문] 피아니스트 이영신',
#  '[음악교육신문] 한국피아노학회',
#  '[음악교육신문] 한국피아노교수법학회',
#  '[음악교육신문]709호 <커버스토리> 영신여자고등학교 음악중점학급',
#  '[음악교육신문] 석세스 뮤직',
#  '[음악교육신문] 710호 <커버스토리> 트롬보니스트 김재한',
#  '[12월 19일] 음악교육신문 초청 차세대 아티스트 콘서트 Ⅳ',
#  '[음악교육신문] 피아니스트 박해진',
#  '[음악교육신문] 제1회 미국 캔자스 음악대학 동문음악회',
#  '[음악교육신문] 삼육대학교 문화예술대학 음악학과 임봉순 학과장',
#  '[음악교육신문] 예화 피아노 입시평가회',
#  '[음악교육신문] 서혜영 피아노 독주회',
#  '[음악교육신문] 제17회 충남 전국청소년 기악경연대회',
#  '[음악교육신문] 피아니스트 박은희',
#  '[음악교육신문] 성신여자대학교 기악과 안미현 교수',
#  '[12월 18일] 음악교육신문 초청 차세대 아티스트 콘서트Ⅲ',
#  "[굿인터내셔널 용산CGV점 소식]매혹적이고 환상적인 음악! Michel Legrand – Peau D'Ane OST",
#  '[굿인터내셔널 용산CGV점 소식]프랑스 최고의 샹소니에! 조르주 브라상의 음악!',
#  "[킨더뮤직] 자장가음악 | Quiet Time | 자기조절능력 | Calm Down | We're on the Homeward Trail",
#  'Restart - 기분 좋은 뉴에이지 피아노 음악',
#  '대를 이은 오디오 마니아 이야기, 음악이냐 소리냐?',
#  '[조은 음악 신문사 콩쿠르 입상을 축하합니다] 🙂',
#  '슬기로운 산촌생활 6회 뉴클리어 반점 정선점 노래 BGM 배경음악',
#  "[BDCABU]재즈계의 제임스 딘 '쳇 베이커'의 스윙음악!",
#  '[공지] [송사비의 클래식 음악야화] 겨울 한정판 에디션',
#  '기획자 추천 시리즈 [이대로 놓치기 아까운 음악]1📌',
#  '그 겨울, 함께했던 따사로운 음악',
#  '같피연17기 1130 화, 비가 내리니 음악만 듣고파',
#  '2021부천 국제애니메이션 페스티벌 상영 일정ㅣ배경 음악 작곡 편곡 및 효과음 제작에 참여했습니다 :)',
#  '우주히피 - 맘대로 해 [음악/노래/추천/공유]',
#  '[10월 3일] 카메라타 안티콰 서울이 전하는 바로크 음악 이야기 XVII',
#  '[음악교육신문] 2021 바로크음악제',
#  '새로 나온 음악들, 요즘 들은 음악들 (6)',
#  '[11월 17일] 제1회 미국 캔자스 음악대학 동문음악회',
#  '롭 핼포드(주다스 프리스트)가 선택한 최고의 음악 10 (롤링스톤 매거진 역대 음악 500 투표에서)',
#  'MADONNA(마돈나) : 뭘 좀 아는 누나의 음악',
#  '클래식시디,음악시디 삽니다',
#  "[굿인터내셔널 용산CGV점 소식]'A Charlie Brown Christmas' 엄마와 아이 태교음악",
#  '[음악교육신문] 한국피아노듀오협회 제18회 스페셜콘서트',
#  '[2022학년도 수시] 홍익대학교 실용음악과 재즈피아노 1차 합격',
#  '[소리사전] 무무와 탈춤의 반주음악, 허튼타령',
#  '애쉬 아일랜드 ASH ISLAND - Play (Prod. by TOIL) (구글플레이 광고 음악) ',
#  '[BD MUSIC]재즈 피아노의 시인으로 불리는 빌 에반스의 음악',
#  '계원예고 입시 음악과 - 클래식 작곡, 실용음악 ',
#  '[음악교육신문]<PIANO>피아니스트 이태리',
#  '팻 메시니 음악의 개인적 최애 포맷 Side-Eye',
#  '[음악교육신문]<RECITAL>세종대학교 음악과 이기정 교수',
#  '[음악교육신문]<YOUNG ARTIST>영산양재홀',
#  '[음악교육신문] 숙명여대 문화예술대학원 피아노교수학전공 이주혜 교수',
#  '[음악교육신문]<모집>고양예술고등학교',
#  '(공유) 음악이 있는 풍경 - <마음을 감동시키는 플루트 음악 / 편안한 플루트 기악 / 헤븐리>',
#  '(❤️광주 피아노스토리 음악학원) 중등임용·교육대학원 입시 강사진',
#  '아일랜드 & 바스크 음악',
#  '미디입시 언택트시대에 가장 인기있는 실용음악 전공',
#  '[음악교육신문]<입학>대원여자고등학교 음악중점학교',
#  '[BGM] 병원에서 흘러 나오던 그 음악 | 심신안정을 위한 힐링 PLAYLIST',
#  '돌싱글즈2 6회 최종선택 노래 BGM 배경음악',
#  '[음악교육신문] 제25회 국민일보 한세대학교 음악콩쿠르',
#  '[굿인터내셔널 용산CGV점 소식]크리스마스 파티에 어울리는 산타 스윙 음악!',
#  '[음악교육신문]<STRING>첼리스트 이경미',
#  '[굿인터내셔널 용산CGV점 소식] 음악과 함께 미리크리스마스 준비! #2탄 ',
#  '[굿인터내셔널 용산CGV점 소식]음악과 함께 미리크리스마스 준비! #1탄',
#  '[음악교육신문] 한음예술교육기획 이아름 대표',
#  '오디오 기기가 아닌 음악을 들으세요?',
#  "'쇼, 음악을 말하다'를 읽고",
#  '[음악교육신문]플루티스트 강초롱',
#  '[음악교육신문]<종합>코스모스악기',
#  '새로 나온 음악들, 요즘 들은 음악들 (7)',
#  '[음악교육신문] <ORCHESTRA> 아이카우(i-CAU) 필하모닉 오케스트라 신동열 지휘자',
#  '[음악교육신문]<ENSEMBLE> 음감아트',
#  '[음악교육신문]<PIANO> 한국리스트협회 제44회 정기연주회',
#  '(27일) 쇼!음악중심 748회 라인업, 1위 후보 아이유 에스파 트와이스 몬스타엑스',
#  '한올(Han All) - 좋았을텐데 [음악/노래/추천/공유]',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 93',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 94',
#  "트와이스, 원어스 '쇼음악중심' 746회 라인업 1위 후보 더보이즈·아이유·에스파",
#  '슬기로운 산촌생활 1회 노래 BGM 배경음악',
#  '부평아트센터에서 열리는 음악과 동화의 만남, <피노키오의 모험>',
#  "최철기 감독 × 이동준 음악감독  뮤지컬 '심청': 한국 대표 컨텐츠를 모아 새롭게 버무렸다 @국립중앙박물관 극장용 11.20,21",
#  '[음악교육신문] 박태희교수의 해설이 있는 알레그로피아노교육협회 정기연주회',
#  '[을지로] 예약제 운영/ 술과 음악🕯 : 서울 인현골방',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 92',
#  '제39회 서울시립대학교 음악학과 정기연주회,서울시립대학교 대강당',
#  '11월수요음악특강 <호두까기인형> 정관지음피아노🎵',
#  '미디작곡레슨: 테크노 장르의 음악을 만드는 노하우 테크닉 배우기!',
#  '곽푸른하늘 - 나는 니가 필요해 [음악/노래/추천/공유]',
#  '언리얼+VR] 배경음악 넣기',
#  '홍대실용음악학원 입시 준비중이라면',
#  '전자과의 전자 음악 찬양글',
#  '라라라_음악 이야기_정재형',
#  '경기도 남양주 학교음악선생님이 선택한 중고야마하피아노 설명과 구입 이야기 입니다',
#  '해드셋과 수면제와 음악',
#  '가평 음악역에서 펼쳐지는 미디어파사드와 가수들의 공연',
#  '김사월 - 접속 [음악/노래/추천/공유]',
#  '음악감상용 오디오 구입할 때 초보입문자의 필독서 [하이엔드 오디오 가이드]',
#  '공간음악 - 음악 악기 연습, 성악연습에 제격',
#  '[굿인터내셔널 용산CGV점 소식]최고의 크리스마스음악!REMEMBERING CHRISTMAS',
#  '2021.11.26 림실용음악학원 목요예배 [강동구 찬양예배 기도모임]',
#  '[파주/일산/고양/김포 피아노 입시 및 전공레슨] 조은음악신문사 준대상 입상을 축하합니다! ',
#  '[음악교육신문]첼리스트 박슬기',
#  '최정윤 - 어리석은 마음 [음악/노래/추천/공유]',
#  '세종(나성동) 영국왕립음악 티칭. 야마하그랜드피아노C3.',
#  '(유아음악)킨더뮤직 압구정 직영센터에서 체험 수업 해보세요!',
#  '[음악교육신문] <CONCOURS> 강원도음악협회 이상수 회장',
#  '[문플리] 나를 영화 주인공으로 만들어 주는 인디음악 모음',
#  '선을 넘는 평화축제! 선을 넘는 음악축제! 2021 통일로가요',
#  '바퀴 달린 집3 2회 열기구 누룽지백숙 노래 BGM 배경음악',
#  '롤링 스톤 매거진(선정) 역대 위대한 음악 500(개정판) 100위 ~ 11위',
#  '음악심리상담사자격증 미래 밝은 전문 직종!',
#  '실용음악학과 디제이 플래시핑거 특강 개최',
#  '피아노레슨 작곡레슨부터 다양한 온라인 음악교육 PLAY SHOP ',
#  '광주실용음악학원 다양한 과정을 한번에!',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 91',
#  '뮤직카우 음악저작권 투자, 금보다 높은 수익률 논문 발표',
#  '[경주시장 주낙영] 경주시, <경북음악창작소> 개소식',
#  '(공유) 편안한 음악 - <André Gagnon - Comme au premier jour(첫날처럼)>',
#  'PHOENIX(피닉스) : 매년 더 좋아지는 음악',
#  '내 몸으로 완성하는 음악, 바디퍼커션을 아시나요?',
#  '도시어부3 25회 완도 방어 부시리 노래 BGM 배경음악',
#  'COLDPLAY(콜드플레이) : 21세기 음악의 선두주자',
#  '일본 센조쿠 음악 대학교, 대학원 입시 후기 & 합격 보장 교육',
#  '강남성인피아노 강남실용음악학원 여기로!',
#  '나 혼자 산다 422회 2022 달력 비둘기 아줌마 노래 BGM 배경음악',
#  '화상영어 음악에 대한 이야기',
#  '플레이송스홈과 함께 진짜놀이 음악놀이프로젝트',
#  '바퀴 달린 집3 4회 김광규 신승환 노래 BGM 배경음악',
#  '가평음악놀이터 4살아이랑 갈만한곳',
#  '오리지널 <고스트버스터즈> 1,2편 음악으로 복습하기',
#  'NCT 127·박지훈 등 쇼!음악중심 744회 라인업, 1위 후보 세븐틴VS아이유',
#  '아이폰 노래 찾기 무설치로 알아보는 음악인식 방법',
#  '상페의 음악',
#  '[교육기관 강사파견] 2022년 유아 음악수업은 킨더뮤직!  ',
#  '[중등음악임용 응용반주 독학하기] 양손악보 - Piano Score',
#  '윤이상국제음악콩쿠르 (2021년 바이올린 부문)가 열리다:통영국제음악당10월31일~11월7일',
#  'a.g.cook의 컴퓨터 전자 음악',
#  '[LP] 김정호 음악세계 - 님 / 이름모를 소녀',
#  '[음악교육신문] <FLUTE> 플루티스트 하지현',
#  '음악검색 네이버 그린닷으로 간단하게 찾는법',
#  '[공지] [비온뒤_공연소식] 김문주 가야금 전통음악 독주회 <평조회상>',
#  '어쿠스틱레인 (오르골자장가) - 오르골 자장가가 들려주는 태교음악 90',
#  '조동진 4 / 음악은 흐르고(1990) 서울음반',
#  '[심리테스트] 지금 나에게 필요한 음악은?🎼',
#  '[BD MUSIC]Ray Charles (레이 찰스)의 음악!',
#  '다섯(Dasutt) - 점심시간 [음악/노래/추천/공유]',
#  '[굿인터내셔널 용산CGV점 소식]아름다운 유럽 WEIHNACHT (크리스마스) 음악!',
#  '슬기로운 산촌생활 4회 노래 BGM 배경음악',
#  '[소리사전] 왕실의 평화와 건강을 기렸던 궁중음악, 함녕지곡',
#  '[음악교육신문] <ENSEMBLE> 코리안바로크소사이어티',
#  '서울특별시 교사 힐링연수/영화음악부터 클래식음악까지 <시선이 머문 음악>',
#  '슬기로운 산촌생활 7회 정문성 설거지배 제기차기 노래 BGM 배경음악',
#  '홍대 연남동 음악 작업 및 사무실 임대',
#  '리지 헤일(여성 록 보컬리스트)의 유명한 팝 음악을 거친 음색으로 깔끔하게 커버 - I Will Always Love You(휘트니 휴스턴)',
#  '[신림 우드스탁 Vinyl 음악 감상회] #10. Rare Groove',
#  '의정부 음악도서관 2021년 12월 뮤직볼륨업 선곡들을 감상해 보세요.',
#  '카누 너티카라멜라떼 노래 CF BGM 광고음악',
#  '[음악교육신문] 동의대학교 일반대학원 통합예술치료전공 김소형 교수',
#  '[음악교육신문] <PIANO> 피아니스트 이은혜',
#  '구해줘 홈즈 133회 서울 강북 3인가구 자연 친화적인 집 노래 BGM 배경음악',
#  "'음악 혐오'를 읽다가",
#  '오늘부터 무해하게 1회 죽도 공효진 이천희 전혜진 노래 BGM 배경음악',
#  '경북 경주시, ‘경북음악창작소’ 개소',
#  '[신림 우드스탁 Vinyl 음악 감상회] #11. Yacht Rock',
#  '골반 틀어짐 교정 2분 운동 Leg Circle',
#  '바디웨이트 맨몸 운동 애니멀 플로우 인스트럭터 레벨 2 Animal Flow Instructor level2 ',
#  '재활 필라테스 | 등척성 운동으로 재활을 시작하는 이유 ',
#  '허리에 좋은 운동 시도해보기',
#  '사계절 내내 건강을 유지하는 실내운동',
#  '등운동 루틴 기구 [시티드 로우를 다양하게]',
#  '무릎 통증, 휜다리(오다리, X다리) 교정 및 수술 치료, 운동, 근육 마사지',
#  '구디 헬스장 케이블을 이용한 상체운동을 소개할게요',
#  '서울대입구역PT 실종된 힙을 되찾는 운동!',
#  '다이어트 똑똑하게 하자! 기초대사량 그리고 운동,식단 편식하지말아야 하는이유!',
#  ' 운동이 유방암 환자 케모 브레인 막는다',
#  '케겔운동 효과 조루개선에 도움이 될까?',
#  '스쿼트 자세 여자 남자 다이어트운동 효과 ',
#  '소도구 필라테스 | 미니볼을 이용한 전신 운동',
#  '오십견 운동 따라하며 예방하기',
#  '만성 목, 어깨, 발목 통증  운동 솔루션',
#  '하체운동 파워레그프레스 운동효과 [어떻게 사용해야 가장 좋을까요?]',
#  '운동전 커피가 지방제거를 증가시키나?',
#  '암 예방을 위한 꾸준한 운동',
#  '홍대 헬스장 여성에게도 필수인 등운동!',
#  '운동하기 전에 마시는 아이스 아메리카노 건강에 이상은 없는걸까?',
#  '홈트레이닝 매트운동 : 바닥만 있으면OK 확실한 운동효과 루틴 _ 힙운동 전신운동 ',
#  ' 코로나19 백신 접종 후 운동을 해도 괜찮을까?',
#  '남자 여자 하체운동 햄스트링 Toned 1분 홈트  뒷벅지 만들기 ',
#  '다이어트 초보의 흔한 망테크 : 먹는 건 못 줄이겠고...운동만으로 뺄까?',
#  '목디스크에 좋은 운동, 주의해야 할 점이?',
#  '한님쌤 필라테스 | 복근 운동 시 고관절 앞쪽만 느껴진다면? ',
#  '복부를 자극하는 외복사근 운동 3가지',
#  '봉선동 운동재활 체형 개선 PT  비포 애프터',
#  '2021년 11. 26.(금) 철인 운동일지: 사이클 롤러 훈련 2회, 무룡산 산행',
#  '3분 요가 : 밧다 코나아사나 - 고관절 가동성에 좋은 운동',
#  '신림 헬스장 고강도 복근 운동을 알려드려요!',
#  '유산소운동 효과 와 근손실 이유 : 유산소 근력 순서 바로 이거에요!!',
#  '원레그 데드리프트 자세 효과 맨몸운동 종류',
#  '운동 전 식사로 운동 효과를 높여주세요',
#  '허리 스트레칭 기구 간편한 허리 운동으로 추천',
#  '(광주 서구 / 오월길 도보여행 #5) 걸어서 만나보는 5.18 광주민주화운동의 성지 여행. 오월길 <광천 시민아파트, 광천동 성당, 들불야학 옛터>',
#  '한님쌤 건강 정보 | 골다공증, 골절 예방 운동',
#  '복직근이개 운동 따라하며 몸상태 되찾기',
#  '엉덩이 중둔근 운동 프로그레션 이렇게 해보세요!',
#  '백신맞고 10일만에 운동하니까 거의 몸이',
#  '신림PT 가슴라인을 완성하는 운동을 소개합니다~',
#  '오늘도 나와의 싸움에서 이기기 운동은 가산역 크로스핏 에이머에서!',
#  '만성통증 재활운동 피드백',
#  '여자 근력운동 다리 Shaping 하체비만 전신운동',
#  '여자 힙업운동 엉덩이살빼기 : 짧고 굵은 확실한 힙업효과',
#  '겨울 실내운동, 트레드밀 뛰기',
#  '신사동pt 15분 코어운동 강력한 코어근육을 만들어보자!',
#  '한님쌤 건강정보 | 폐경기 여성들의 운동에 대해',
#  '하체 근력운동 건강을 위해서 필수에요',
#  '2021년 11. 29.(월) 철인 운동일지: 휴식 및 회복하는 날',
#  '이지현 육아 등운동 제발 좀 그만해 이러다 다 죽어',
#  '신림 헬스 상체라인을 만드는 운동을 알려드려요',
#  '한주의 마지막도 에이머에서! 가산역 크로스핏 에이머에서 운동해요',
#  '여자 힙업운동 남자 엉덩이 근육운동 Glute Shaping',
#  '코어운동 허리에 좋은 강화운동',
#  '팔굽혀펴기 효과 가슴쳐짐운동 푸시업 자세',
#  '엉덩이살빼기 여자 힙업운동 세퍼레이션 근육 만들기',
#  '남자 여자 복근운동 심플한 뱃살빼는법 시티드 & 리버스 크런치',
#  '플랭크 자세 코어운동 효과 건강한 다이어트 운동',
#  '남자 여자 뱃살 빼는 운동 홈트 기초 가이드(크런치 레그레이즈 러시안 트위스트)',
#  '크로스 런지자세 curtsy 효과 허벅지살 빼는 운동',
#  '복근운동 루틴 따라하며 운동하기',
#  '거북목 교정기 없어도가능한 : 거북목 교정 운동 스트레칭 같이해요!',
#  '비복근운동 부은 하체를 풀어줘요',
#  '엉덩이 힙업 운동 이렇게 해봐요',
#  '유산소운동 꼭 해야하는이유와 유산소 와 무산소 차이 ',
#  '하체운동 허벅지근육운동 이지만 앞툭튀 걱정 없이~',
#  '임산부 필라테스 산후 운동으로 좋은 동작',
#  '재활 필라테스 | ACL 재활 시의 OKC, CKC 운동에 대해',
#  '옆구리살빼는운동 해본사람이 알려드려요 !!',
#  '하체운동 을 꼭 해야만 하는 이유 팩폭!',
#  '한님쌤 필라테스 | 둔근 강화, 힙업 운동 총정리',
#  '필라테스 토닝볼 활용한 어깨운동',
#  '대둔근 운동 힙업을 위해서 필수에요',
#  '허벅지 안쪽살 빼기  확실한효과 2가지운동',
#  '광명 헬스 탄력적인 가슴을 완성하는 운동!',
#  '홈짐 힙업운동 ! 추천루틴 브이스쿼트 열일기록',
#  '추워진 날씨에 건강지키기! 운동은 가산역 크로스핏 에이머에서!',
#  '홈트레이닝 으로 허벅지 승마살 동시에! : 허벅지 안쪽살 빼기 + 승마살 운동 ',
#  '즐거운 에이머! 크로스핏 에이머에서 함께 운동해요~~',
#  '빡세게 운동하고 싶다면 크로스핏 에이머! 가산역 크로스핏 에이머로오세요~~',
#  '골반 스트레칭 & 고관절 스트레칭 : 하체운동전 꼭 하세요!',
#  '복근운동 과 유산소 전신 운동 동시에! 같이하실분!!',
#  '추위이기러 에이머로 오세요! 가산역 크로스핏에이머에서 함께 운동해요',
#  '2021년 12. 2.(목) 철인 운동일지: 사이클 르몽드 트레이너, 집 대청소/부울경 트레일런 송년회 연기',
#  '2021년 11. 27.(토) 철인 운동일지: 회복하는 날(태화강변 걷기, 재현이랑 수영)',
#  '건강지킴이 에이머! 가산역 크로스핏 에이머에서 운동해요!!',
#  '헬스장 가서 어떤운동부터 해야할까? 여자 헬스 루틴 이렇게!!',
#  '신사역pt 등운동 루틴 효과적으로 등근육 강화시키는 운동법',
#  '오늘 정말 운동가기 싫었',
#  '헬헬 이제 다시 운동을 시작할 수 있다',
#  '[강서구 주짓수&킥복싱] 체력, 면역력 운동으로 키워보아요!',
#  '서로 할일하자라는 현우진 선생의 메세지를 전두엽에 각인시키고 운동 갔다옴',
#  '허리근력 강화운동 집에서 해봐요',
#  '승마살 운동 함께 따라해봐요',
#  '스파인코렉터 활용한 운동 동작 세가지',
#  '11월 저와 운동+수다 하실래요? : 신세계 강남점 원데이클래스 ',
#  '여자 복근운동 3가지 동작으로 코어를 단단하게',
#  '신사pt 전신운동 추천 하체운동과 상체운동을 동시에!',
#  "운동하신다면 3만원 받아가세요! - '1타3만'체육쿠폰 신청 안내",
#  '[공지] 스쿼트 자세 하체 근력운동 diet 효과',
#  '허벅지 안쪽살 빼기 운동 와이드 스쿼트 & 이너싸이 머신 ',
#  '허리디스크에 좋은 운동, 맥켄지 운동법 따라 하기',
#  '중둔근 운동 매트위에서 해보기',
#  '등살빼는운동 등근육 care 남자 여자 홈트레이닝',
#  '요즘 운동식단은 cu 편의점 The 건강식단 도시락으로!!',
#  '전방십자인대파열 운동 중 발생하므로',
#  '쇼그렌증후군 근력강화를 위한 저항운동 효과는',
#  '다이어트 운동 or 식단 뭐가 더 중요할까?!',
#  '2021년 11. 22.(월) 철인 운동일지: 매봉재 산행, 학생들과 함께 타바타운동',
#  '대상자에게 맞는 운동이 우선시되어야 함',
#  '오른쪽 어깨 통증 원인 회전근개파열 전거근통증 완화 방법 극상근운동 ',
#  '허리에 좋은 운동 누워서 따라해보기',
#  '밸런스 운동 : 코어운동 과 복근운동 을 동시에 ',
#  "대구PT '유산소운동의 효과를 최상으로~~런닝머신 잘타기'",
#  '신사역피티 남자 어깨운동 추천 덤벨운동 끝판왕!!',
#  '서울대입구 헬스장 코어랑 등운동 함께해요^^',
#  '척추협착증 증상 및 운동방법',
#  '굽은등 교정운동 같이 따라해봐요',
#  '여자 상체운동 (등살 겨드랑이살빼기 코어 강화) 3종류',
#  '<광교피티 어썸핏> 바이킹프레스를 이용한 운동',
#  '홈트로 해보는 등과 가슴 운동',
#  '2021년 12. 1.(수) 철인 운동일지: 생활 속 운동(사이클 르몽드 트레이너, 무룡산 일몰 산행, 타바타운동(어깨+데드리프트)), 진장회수산센터에서',
#  '여자 복근운동 (요가 자세)',
#  '질타이트닝을 돕는 여성케겔운동기구',
#  '집에서 할수있는 운동 등근육 자극하기',
#  '매력적인 여자 팔근육 키우는법 3가지 운동',
#  ' 대한민국 초등학생들아~ 우유랑 운동하자♬ 11월 SNS이벤트',
#  '운동 후 근육통 푸는 법(폼롤러를 통한 가슴, 등, 허벅지, 햄스트링, 종아리 이완, 근육 통증)',
#  '코어운동 허리강화운동 우리가 꼭 해야하는 필수운동',
#  '이수역 헬스장 1석2조의 운동을 배워보기!',
#  '평발교정운동 쉬운 세가지 동작',
#  '척추측만증 운동 따라하면 좋답니다',
#  '탄현역 헬스장 운동초보도 즐겁게 힙운동 하는법!',
#  '방이동 필라테스 전문적인 강사진과 즐겁게 운동해요!',
#  '어깨 통증 : 어깨 회전근개파열 증상 및 재활, 운동, 수술 치료 병원',
#  '허리 코어운동 집에서 따라해요',
#  '필라테스 아크바렐 운동 세가지 동작',
#  '경산 운동 효과 있는 체온다이어트 찜질 카페',
#  '보수볼 운동 따라하며 밸런스 잡아가기',
#  '복근운동 집에서 해보기',
#  '시간절약형 운동 프로그램 : 3/7 세트법',
#  '11월 3일은 무슨 날? 학생독립운동 기념일!',
#  '<광교pt 어썸핏>두툼한 갑빠를 만들기위한 가슴운동',
#  '다이어트한의원 한약 운동중독 후기!',
#  '운동 근황 - 베넥2, 일본정치, 뉴발 이에로v6 세일',
#  '팔운동 어떻게 해야할까요?[탄탄한 팔을 만들기 위해서]',
#  '2021년 11. 15.(월) 철인 운동일지: 박상진호수공원 걷기, 치맥',
#  '왼쪽 오른쪽 팔저림 및 팔통증, 흉곽출구증후군 증상 및 치료 운동, 스트레칭',
#  '홈트레이닝 기구 없이 폼롤러로 자극 200% 힙업운동 코어운동',
#  '마들렌 만들기 초보 홈베이킹',
#  '스콘만들기! 베이킹초보도 성공보장~ 크랜베리 스콘 만드는법',
#  '홈베이킹 위즈웰 제빵기로 홈메이드식빵 우유식빵 만들기',
#  '제스프리 그린키위 과일디저트 두 가지 만들기!간단한 홈베이킹 ',
#  '[공지] [22년 1월 평일/주말] 비건베이킹전문가 2급 자격증반 모집 @로비건채식요리학원',
#  '누네띠네 스콘 만들기 과자보다 맛있죠(홈베이킹)',
#  '이탈리아식 마카롱 만들기 겉바속쫀 아마레티 쿠키 (아몬드가루 베이킹)',
#  '홈베이킹 얼그레이 식빵 밀크티잼으로 시작하는 오후',
#  '쌀식빵 만들기 건강하고 더욱 맛있는 쌀가루베이킹 홈메이드 발효빵',
#  '마들렌 만들기 발로나 초콜릿 더해 세상 맛있는 홈베이킹 ',
#  '시나몬롤 만들기 호떡믹스로 뚝딱 초보 홈베이킹',
#  '마들렌만들기 아이들간식 티푸드 홈베이킹 ',
#  '초간단 홈베이킹 바나나케이크 에어프라이어로 슝~',
#  '전기 밥솥 카스테라 만들기 노오븐 베이킹',
#  '노오븐 베이킹 아침빵으로 좋은 피타브레드 만들기',
#  '크림치즈빵 만들기 발효빵 홈베이킹',
#  '촉촉한 초코칩쿠키 만들기 간단한 홈베이킹 초코쿠키 레시피 ',
#  '옥수수 치즈 생크림 스콘만들기 노버터 에어프라이어 스콘 홈베이킹 ',
#  '[홈베이킹] 쌀 슈크림 만들기💛',
#  '생크림 스콘 만들기 노버터 초간단 홈베이킹 응용버전까지',
#  '제스프리 그린키위 주스 만들기 크로와상 생지 활용 후렌치파이 홈베이킹',
#  '믹스만큼 쉬운 홈베이킹 바나나빵 스타벅스 바나나브레드 ',
#  '겨울 간식 홈베이킹 새로나온 백설 초코츄러스맛호떡믹스 ',
#  '바스크 치즈케이크 만들기 선물하기 좋은 쉽고 근사한 홈베이킹',
#  '마들렌만들기  아이들 간식 홈베이킹 오븐요리 ',
#  '대추 마들렌만들기 홈베이킹 레시피',
#  '초코 브라우니 만들기 간단 베이킹 재료',
#  '홈베이킹 무화과사브레 만드는법',
#  '홈메이드식빵 만들기 홈베이킹 소보로 우유식빵 위즈웰 제빵기 추천',
#  '[펌킨스파이스 쿠키]향긋하고 부드러운 맛있는 쿠키 / 가을 베이킹! ',
#  '고구마요리, 다이어트 고구마빵 놀랍게도 노버터 노오븐 베이킹!',
#  '[홈베이킹] 쌀 맘모스빵 만들기🐘',
#  '파운드케이크 만들기 홈베이킹 생크림 활용 요리',
#  '노오븐베이킹, 암브로시 마스카포네치즈로 티라미수 만들기',
#  '[수업후기]구움과자창업정규반 1회차수업/스무크베이킹스튜디오',
#  '계란과자 만들기 시판보다 맛있는 엄마표 계란 쿠키만들기! 초간단 베이킹 재료~',
#  '생크림 스콘만들기 플레인 스콘 초코칩 더해 맛있게 쉬운 홈베이킹',
#  '올리브 치아바타 만들기 무반죽 초보 홈베이킹',
#  '리얼 감자빵 만들기 깨찰빵믹스 활용한 간단 홈베이킹 감자요리',
#  '우유 식빵만들기 홈베이킹레시피',
#  '대전베이킹클래스 향긋한 휘낭시에 도전!',
#  '그릭요거트로 레몬 파운드케이크 만들기(홈베이킹.ver) ',
#  '초코칩 생크림스콘 만들기 노버터 베이킹 에어프라이어 홈베이킹',
#  '[베이킹] 위즈웰gl42 - 갈레트 브루통',
#  '[홈베이킹] 노밀가루 쌀 빼빼로 만들기🍫',
#  '홈베이킹, 겉바속촉 초콜릿 쿠키, 아메리칸 쿠키 만들기 ♬',
#  '[공지] [22년 1월 평일/주말] [공지] 채식요리지도사(비건베이킹 포함)2급 자격증 @로비건채식요리학원',
#  '[프리오더] 12월 #안서리베이킹랩 #파블로바 #마쿠아즈 #달고나 #프리오더',
#  '플레인 스콘만들기 이 맛은 못참지! 커피 부르는 홈베이킹~',
#  '초코칩쿠키 만들기 아이들 간식 추천 홈베이킹 레시피',
#  '바질 스콘 만들기 향긋함이 입안에 가득한 홈베이킹 ',
#  '마들렌 만들기 간단한 홈베이킹',
#  '초코 머핀만들기 아이간식 홈베이킹 에어프라이어 ',
#  '백종원 사과파이 에어프라이어 식빵 요리 홈베이킹 애플파이 만들기',
#  '바스크 치즈케이크 만들기 홈베이킹 ',
#  '그릭요거트 팬케이크 만들기 어남선생 홈베이킹 레시피',
#  '마들렌 만들기 홈베이킹 상콤상콤함이 듬뿍 청귤마들렌',
#  '[홈베이킹] 쌀 브라우니 쿠키 만들기🍫',
#  '유기농 블루베리, 간단하게 홈베이킹 블루베리머핀 만들기 ♪',
#  '비앤씨마켓 할로윈 베이킹 펌킨파이 만들기',
#  '간단 홈베이킹요리 시리얼바 만들기 발로나 지바라 초콜릿 ',
#  '[비건베이킹전문가 1급] 3회차 주중반 수업후기 (치아바타, 앙버터, GF 스노우볼쿠키)',
#  '스콘만들기  홈베이킹 오븐 생크림 요리 만드는법 ',
#  '생크림 스콘만들기 겉바속촉 홀딱 반하는 노버터 홈베이킹! 초간단 베이킹 재료 ',
#  '홈베이킹 얼그레이 파운드케이크 만들기',
#  '[비건베이킹전문가 1급] 1회차 주중반 수업후기 (커스터드 슈, 야채크래커)',
#  '노버터 생크림 스콘만들기 햄치즈 스콘 레시피 홈베이킹',
#  '초보 홈베이킹 초코 머핀 만들기',
#  '[올해 마지막]신청 가능 클래스 안내 (비건,베이킹,주스)',
#  '홈베이킹 만들기 쉽지만 고퀄의 브라우니 ',
#  '홈베이킹 유행따라 대파치즈스콘 만들기 ',
#  '리얼 홈베이킹 클래스 토요반 3주차-베이글 4종과 스콘',
#  '홈베이킹 크랜베리마카다미아스콘 만들기!',
#  '리얼 홈베이킹 클래스 토요반 5주차-할라 브레드와 호두 파이, 아몬드 타르트',
#  '[비건베이킹전문가 1급] 4회차 주중반 수업후기 (글루텐프리 시나몬롤스콘&다쿠아즈)',
#  '모엘로 쇼콜라, 판드젠 케이크 / 개인 수업, 베이킹 클래스',
#  '초콜릿 케이크 만들기 쌀베이킹',
#  '쉬운 할로윈베이킹,디저트/미라 마들렌만들기',
#  '르뱅쿠키 만들기 쿠키만들기 촉촉한 에어프라이어베이킹',
#  '부드러운 달콤함♥ 딸기연유케이크 만들기 원데이클래스 후기 [크리스마스 베이킹] 수원,동탄,영통,광교,용인,분당 로엔느',
#  '베이킹 핸드믹서기 휘핑기 드레텍 HM-706',
#  '나주시 쌀베이킹 자격증반 세번째시간🙌🏻',
#  '쌀베이킹자격증반 네번째시간 글루텐프리 쌀디저트 만들기🙌🏻',
#  '리얼 홈베이킹 클래스 목요반 7주차-크로아상과 비스퀴 롤 케이크',
#  '리얼 홈베이킹 클래스 목요반 4주차-핫도그 번과 리얼 퍼지 브라우니와 블론디',
#  '리얼 홈베이킹 클래스 목요반 5주차-할라 브레드와 호두 파이와 아몬드 타르트',
#  '홈베이킹 원데이 클래스-핫도그번과 비스켓과 스콘',
#  '리얼 홈베이킹 클래스 목요반 6주차-모닝번즈와 시나몬 롤, 소세지빵, 클래식 파운드 케이크',
#  '[비건베이킹전문가 1급] 2회차 주중반 수업후기 (밤만주, 상투과자)',
#  '#비건갸또 #비건베이킹클래스 #비건케이크클래스',
#  '#백화점출강 #비건베이킹클래스',
#  '[12월 3주차]비건베이킹/요리 원데이클래스(콘치즈쿠키,캐비지롤)',
#  '리얼 홈베이킹 클래스 목요반 3주차-베이글 4종과 스콘',
#  '#비건베이킹클래스 #비건케이크클래스 #비건갸또 #비건베이킹출강',
#  '리얼 홈베이킹 클래스 토요반 4주차-핫도그번과 퍼지 브라우니와 블론디',
#  '[베이킹수업후기]2021.11.24(수) 딸기프레지에/휘낭시에',
#  '천연발효빵 만들기 - 단호박 식빵 <베이킹스타트- 천연발효빵을만들다>',
#  '#비건베이킹클래스',
#  '초간단 홈베이킹 다이어트 빵 만들기! 다이어트 음식으로 좋은 견과류 키토빵',
#  '막걸리 술빵 만들기 노오븐 홈베이킹 막걸리빵 레시피',
#  '홈베이킹, 에어프라이어 비스킷 만들기 KFC 추억의 맛',
#  '베이킹 초보를 위한 버터크림 플라워케이크 기초과정',
#  '홈베이킹_잼 쿠키 만들기(쨈쿠키)',
#  '[12월1주차 비건베이킹 원데이클래스] 레밍턴케이크,고구마빵',
#  '리얼 홈베이킹 클래스 토요반 2주차-포카치아 2종과 드롭 쿠키 4종',
#  '비건베이킹 비건 초코 가나슈 케이크 레시피 :)',
#  '홈베이킹 위즈웰 제빵기 파운드케이크 만들기',
#  '책으로 배우는 홈베이킹 <동명양과자점의 아메리칸쿠키 레시피>, 영진닷컴 ',
#  '위즈웰제빵기 홈베이킹 우유식빵 만들기',
#  '홈베이킹, 동명양과자점 아메리칸쿠키레시피, 쿠키만들기 ♬',
#  '베이킹 초보의 도전~ 버터크림 플라워케이크 자격증과정',
#  '[공지] 12월 원데이 베이킹 수업 공지 + 크리스마스 케이크 만들기 + 한민이의 마크로비오틱 + 부산 광안리 비건 베이킹 클래스 ',
#  '홈베이킹 기록 오발틀 휘낭시에 만들기',
#  '건포도 식빵 만들기 발효빵 홈베이킹 식빵간식',
#  '에어프라이어 스콘만들기 결이 다른 대파치즈 스콘 홈베이킹',
#  '리얼 홈베이킹 클래스 토요반 1주차-식빵 2종과 마들렌 4종',
#  '리얼 홈베이킹 클래스 목요반 2주차-포카치아 2종과 드롭 쿠키 4종',
#  '초콜릿 케이크 만들기 발로나 초콜릿 활용 홈베이킹 초코케이크',
#  '달고나 만드는법 꿀팁 암앤해머 베이킹소다 ',
#  '초간단 홈베이킹 달콤한 사과조림이 가득 크럼블 애플파이 ',
#  '[부산] 비건베이킹전문가 3~4주차 review, 식사빵도 어렵지 않아요!',
#  '홈베이킹_ 초코 막대과자 만들기(빼빼로 만들기)',
#  '인핏 주방저울, 홈카페, 홈베이킹 & 요리 필수템',
#  '홈베이킹 키친에이드 푸프로 생크림 스콘 만들기 ',
#  '#비건베이킹클래스',
#  '리얼 홈베이킹 클래스 목요반 1주차-식빵 2종과 마들렌 4종',
#  '홈베이킹 밤스콘 만들기Chestnut scone!',
#  '[홈베이킹] 얼그레이 쌀카스테라 만들기🧡',
#  '쌀다쿠아즈 다쿠아즈 창업 베이킹 클래스! 제주도에서 찾아주신 수강생분과 함께:)',
#  '빛가람동 쌀베이킹 자격증반 두번째 수업 후기',
#  '[찹쌀 빼빼로] 농민의 날에 먹는 빼빼로 만들기 feat. 베이킹 몬스터즈 5기',
#  '#비건베이킹클래스',
#  '머핀만들기  어린이 간식 컵케이크  키즈 베이킹 즐거워!',
#  '당근으로 하는 베이킹 , 당근요리, 당근맛있게 먹는법',
#  '[수업후기] 기본쿠키3종 :: 중학생과 함께하는 베이킹~',
#  '[공지] ♥킵미스위트♥ 2021년 12월 키즈베이킹 안내',
#  '초코머핀 만들기 홈베이킹 바나나초코머핀 간단한 디저트 만들기',
#  '[비건베이킹전문가 1급] 2회차 주중반 수업후기 (밤만주, 상투과자)',
#  '#비건베이킹클래스',
#  '단호박갸또 만들기 할로윈베이킹',
#  '호두파이 만들기 호두타르트 홈베이킹 오븐 구움과자',
#  '• 베이킹책추천, 정직한 제빵소 윤연중 쉐프의 [어니스트브레드]로 홈베이킹, 팔미에만들기 •',
#  '[비건베이킹전문가 1급] 4회차 주중반 수업후기 (글루텐프리 시나몬롤스콘&다쿠아즈)',
#  '홈베이킹 녹차크랜베리주름식빵만들기!',
#  '스메그 반죽기로 홈베이킹 파운드케이크 만들기',
#  '로헨 에어프라이어로 베이킹 스콘 만들기',
#  '아이들간식 친구들 선물 열심히 베이킹하고 혼밥하고 장보고 세로토닌 만끽하고 저녁으로 참치전 돼지고기고추장구이 만보걷기 키토제닉 즐거운 주말되세요~♡',
#  '[비건베이킹전문가 1급] 3회차 주중반 수업후기 (치아바타, 앙버터, GF 스노우볼쿠키)',
#  '나주직장인 쌀베이킹자격증반 귀한 일요일 수업 후기 :-)',
#  '[비건베이킹전문가 2급] 4회차 주중반 수업후기 (비건티라미수, 맥주빵)',
#  '[부산] 11월 비건베이킹전문가 주말반 개강안내 (마감)',
#  '홈베이킹 에어프라이어 무화과 쿠키만들기(냉동쿠키)',
#  '쌀베이킹클래스   『쌀휘낭시에만들기』',
#  '새로피엔엘ㅡ크리스마스 베이킹포장소품들',
#  '쌀베이킹정규 4회',
#  '[비건베이킹전문가 1급] 5회차 수업후기 (파이 마스터)',
#  '[부산] 비건베이킹 1주차 review, 글루텐프리 비건빵 이렇게 맛있었다니!',
#  '홈베이킹_고구마 휘낭시에(피낭시에) 만들기',
#  '코코아와 아몬드 넣은 쌀베이킹 쿠키 만들기',
#  '미니오븐 홈베이킹 입문자가 쓰기좋은 드롱기 아이코나빈티지오븐',
#  '[베이킹] 위즈웰gl42 - 도토리마들렌',
#  '마들렌 만드는법! 스메그 오븐으로 (그릴스팀 컨벡션) 베이킹하기',
#  '[비건베이킹전문가 2급] 6회차 주중반 수업후기 (얼그레이 사브레, 호두타르트)',
#  '인천 베이킹재료 파는곳 관교동 렛츠베이킹 ',
#  '그릭요거트 브라우니 만들기 쉽고 맛있는 홈베이킹',
#  '간단한 홈베이킹 쇼트브레드 쿠키',
#  '#비건베이킹클래스',
#  '#비건베이킹클래스 #비건케이크',
#  '#비건베이킹클래스',
#  '황치즈 파운드케이크 만들기 :: 홈베이킹',
#  '[비건베이킹전문가 2급] 5회차 주말반 수업후기 (비건치즈케이크, 블루베리크럼블)',
#  '구움과자 수업 카페 디저트 마들렌 6종 클래스! 남양주시, 서울 베이킹 원데이 클래스',
#  '드롱기 아이코나 미니오븐 주말 홈베이킹! 계란빵 만들기',
#  '[케이크대회대상]월드쉐프컬리너리컵코리아,케이크심사위원,카페디저트마스터심사위원,한국조리문화협회,이엘베이킹대상,대전케이크,이엘베이킹,이엘베이킹스튜디오☆',
#  '베이킹스타트 - 천연발효빵 치즈 감자 치아바타 & 사과 햄 샌드위치',
#  '[홈베이킹] 쌀 체크쿠키 만들기🏁',
#  '에어프라이어 요리, 수플레 팬케이크 쉽게 만들기!(노오븐베이킹)',
#  '출강 단체 베이킹수업',
#  '베이킹 클래스_마들렌 + 아메리칸 쿠키 4종 / 구움과자 창업, 카페 디저트 클래스',
#  '쉬운 베이킹 코코넛로쉐 레시피',
#  '비건베이킹 2급 스케치...',
#  '사과 팬케이크 만들기 🍎 사과 디저트, 저탄고지 베이킹',
#  '[라라맘앤김쌤 공방] 라라맘앤김쌤 베이킹 클래스 / 사워도우 (천연발효빵)',
#  '홈베이킹 레몬 제스트 & 파운드 케이크 만들기  아이싱 + 구겔호프틀',
#  '#비건베이킹클래스',
#  '[비건베이킹전문가 2급] 5회차 주중반 수업후기 (비건치즈케이크, 블루베리크럼블)',
#  '사워도우 초코칩 쿠키 만들기 :: 버리는 발효종 베이킹',
#  '에어프라이어베이킹 육쪽 마늘빵 만들기 크림치즈빵 소스 간단한 에어프라이어 요리',
#  '[홈베이킹] 쿠크다스 식감! 쌀 랑그드샤 만들기',
#  '프러포즈 케이크 직접 만드시는 수강생님의 수업사진! 일산 디자인케이크 원데이클래스 [항아케이크 베이킹공방]',
#  '[수업후기] 모카번과 우유식빵 만들기 :) -마전동 마산동 베이킹클래스-',
#  '로푸드 지도자 과정 중 비건베이킹 메뉴@',
#  '베이킹 초보 창업클래스, 버터크림 플라워클래스',
#  '[베이킹] 위즈웰gl42 - 베이킹박스(알밤케이크,도토리마들렌,고르곤졸라휘낭시에,올리브앤초비휘낭시에,건과일파운드,얼그레이파운드,코코넛초코칩쿠키)',
#  '홍합밥 만드는 법 12월 제철음식 홍합살 요리',
#  '귤잼 만들기 새콤달콤한 귤요리',
#  '홍합탕 만드는 법 홍합요리 집에서 소주안주 추천 ',
#  '홍합탕 만드는 법 시원한 국물 팁은 이것~홍합 손질 요리 ',
#  '소고기 안심 스테이크 요리 건강하고 맛있게 굽는법 ',
#  '톳밥 만들기, 톳나물밥 맛과 영양을 다잡은 톳요리!',
#  '굴전만들기 눅눅하지 않게 굴전만드는법 제철 굴요리 굴씻기',
#  '사태 김치찜 맛있게 만드는 법 : 돼지고기사태요리 / 묵은지요리 /김치요리',
#  '모과차 만들기 따뜻한 차 로 드시기에 좋은 모과 요리 ',
#  '꽁치통조림 조림 요리 꽁치 무조림 만드는 법',
#  '알탕 끓이는법 명란 요리 얼큰한 국물요리',
#  '오늘의요리] 반건조오징어 & 미나리무침',
#  '백종원 순두부찌개 끓이는법 간단 순두부찌개 양념장 요리',
#  '베이컨 버섯 크림 리조또 만들기 부드러운 이탈리아 요리',
#  '계란죽 끓이는법 야채 참치죽 끓이는법 고소한 계란요리',
#  '백종원 두부조림 양념장 만들기 정말 간단한 두부요리 팁 밑반찬 딱이죠~',
#  '맛있는 당근 요리 당근라페 만들기 ! ',
#  '백종원 두부조림 양념장 만들기 손쉬운 자취생 간단요리',
#  '참치 김치찌개 맛있게 끓이는법 참치캔 요리',
#  '어묵탕 오뎅탕 끓이는법 리얼 캠핑요리 간식 꼬치어묵탕 레시피 육수 간장소스',
#  '굴무침 만들기 겨울 제철 반찬 굴요리! 무요리?',
#  '백종원 순두부찌개 끓이는법 양념 순삭하는 순두부 요리 ',
#  '간장무조림 만드는 법, 손이 가는 무요리',
#  '배추된장국 바지락을 넣어 감칠맛나는 된장국 배추요리',
#  '명란젓 무침 손쉬운 명란젓 요리 명란젓 먹는법',
#  '김치 만두전골 레시피 냉동만두 요리 얼큰한 김치전골 끓이는법',
#  '간장 어묵볶음 레시피 오뎅볶음 아이들 반찬 요리',
#  '부추무침 만드는법 백종원 부추겉절이 레시피 부추요리',
#  '폭탄 계란찜 만들기 실패없이 촉촉 부드러운 계란찜 뚝배기 레시피! 간단한 계란요리 팁 ',
#  '쪽파무침 고추장 양념 새콤달콤 쪽파 요리 데치기',
#  '12월 제철 농산물 양배추요리로 양배추롤 만들기~ ',
#  '무청시래기나물볶음 만드는법 시래기 된장지짐 이 겨울 좋은요리입니다. ',
#  '초간단 계란국 끓이는법 달걀국 레시피로 간단한 아침국 요리',
#  '전복죽 끓이는법 겨울 보양 전복요리 전복내장죽',
#  '맑은 감자국 끓이는법 포근하고 맛있는 계란감자국 감자요리',
#  '명란 계란탕 만들기 계란국 끓이는법 아침식사대용 명란요리',
#  '굴물회 굴초무침 쉬운 굴요리',
#  '고사리나물볶음 부드러운 고사리볶음 고사리요리',
#  '초간단 어묵국 끓이는법 뜨끈한 국물요리 오뎅국 레시피',
#  '백종원 감자짜글이 고추장찌개 캔참치 요리 ',
#  '무 요리 색다르게 즐기는 무전 만들기',
#  '고추장 감자조림 만드는 법 엄지척 매운감자조림 정석 감자 요리 이겁니다. ',
#  '맑은 순두부찌개 끓이는법 국물이 예술 명란순두부찌개 요리',
#  '표고버섯볶음 만드는법 파프리카 넣고 맛있게 표고버섯요리',
#  '고구마스프 만들기 달콤한 고구마수프 만드는 법 삶은 고구마 요리',
#  '자취생 요리 3분짜장 초간단 짜장면 만들기',
#  '백종원 두부조림 양념장 만들기 끝내주는 간단한 두부요리',
#  '굴전 만들기 감칠맛 뿜뿜 꿀맛나는 굴요리',
#  '연두부 샐러드 먹는법 다이어트 요리 오리엔탈드레싱 만들기 ',
#  '시래기나물볶음 맛있는 시래기요리',
#  '들깨 버섯 순두부찌개 끓이는 법 / 버섯요리 /들깨가루요리 /순두부요리',
#  '두부탕수육 만드는 법 탕수육소스만들기 간단한 에어프라이어 두부요리',
#  '스테이크 맛있게 굽는법 질 좋은 소고기 요리 ',
#  '맑은 오징어무국 요리 깔끔하게 맛있는 아기 오징어국 만드는 법 ',
#  '집에서 낙지탕탕이 연포탕 산낙지 요리 칼국수 낙지죽',
#  '마 넣은 명란젓 무침 만드는법 명란젓 양념 명란요리',
#  '배추전 만드는법 리얼 경상도 토박이의 알배기배추전 요리',
#  '돼지고기전 돼지고기 육전 만드는법 남은 수육 요리',
#  '전자레인지 깻잎지 찜 깻잎 양념장 팁 간단 요리 ',
#  '굴국 끓이는법 무굴국 만들기 육수 없이도 최고! 굴요리 해장 음식 추천',
#  '백종원 오징어볶음 레시피 요리 불맛 나는 오징어볶음 양념 ',
#  '봄동 겉절이 고소한 봄동무침 요리 봄 배추겉절이 만드는 법 ',
#  '표고버섯볶음 간단하게 만드는 반찬 표고버섯요리',
#  '새송이버섯볶음 굴소스 간장만! 새송이버섯요리 버섯종류 반찬메뉴',
#  '바지락술찜 바지락 요리 해감부터 보관법 집에서 소주안주 추천',
#  '백종원 두부조림 양념장 만들기 밥도둑 두부요리 엄지척~!',
#  '백종원 김치볶음밥 레시피 무조건 맛있는 참치 김치볶음밥 만들기 집에서 간단한 캔참치 요리 ',
#  '봄동 겉절이 만드는 법 맛있다고 난리난 봄동무침 요리! 배추겉절이 만드는 법 5분컷 ',
#  '고구마라떼 만들기 쉽게 고구마 찌는법 고구마 요리',
#  '시금치 된장국 끓이는법 만드는법 제철 시금치요리로 시금치국 시금치 데치기',
#  '고구마샐러드 만드는 법 치즈 넣어 맛있는 고구마요리',
#  '황태 콩나물국 끓이는법 국물이 진짜 끝내주는 해장 음식 콩나물국 레시피 요리',
#  '시금치무침 나물 달큰한 국민반찬 제대로 시금치 데치기 요리 팁(비빔밥재료) ',
#  '배추전 만드는법 고소하고 맛있는 알배기배추전 요리',
#  '양배추 새송이버섯 볶음 요리 레시피 깔끔한 양배추볶음 ',
#  '팽이버섯 베이컨말이 팽이버섯 요리 간단한 반찬',
#  '들기름 김치볶음 묵은지들기름볶음 요리 구수한 볶음김치 만드는법',
#  '바삭바삭 황태채볶음 만드는 법 : 황태채요리 /밑반찬',
#  '지금은 솥밥시대, 만능요리 가마솥으로!',
#  '김전 만들기 쉬운 묵은김요리',
#  '고구마라떼 만들기 고구마 찌는법 전자레인지로! 삶은 고구마 요리',
#  '아보카도 요리모음, 아보카도 맛있게 먹는법!!!',
#  '세발나물 무침 만드는 법 세발나물요리',
#  '훈제오리 부추무침 레시피 오리훈제 요리',
#  '계란 두부부침 양념장 만드는 법 세상 맛있고 간단한 두부전 요리 팁 ',
#  '일본식 고등어구이 산뜻한 고등어 요리',
#  '소불고기 황금레시피 국물 자작 소고기전골 요리 납작당면 추가 ~!',
#  '삼겹살조림 에어프라이어 구운 통삼겹살요리',
#  '부추겉절이 만드는법 5분컷 부추무침 레시피 부추요리!',
#  '아삭하고 달달한 무 요리 모음, 한창 맛있는 무~~!',
#  '황태국 북어국 끓이는법 국물 션한 콩나물황태해장국 요리 북어계란국',
#  '당근덮밥 당근 요리 추천 한 그릇 덮밥',
#  '빨간 콩나물무침 레시피 콩나물반찬 중에 제일 좋아하는 콩나물요리',
#  '두부짜글이 쉽고 맛있게 만드는법 얼큰칼칼  부드러운 두부요리',
#  '스팸마요덮밥 간단한 점심메뉴 추천 스팸요리',
#  '돼지고기동그랑땡 매콤하게 만들어요 돼지고기 요리',
#  '간단한 한끼~또띠아 토스트 만드는법 또띠아요리',
#  '스팸요리 스팸 약고추장 애호박비빔밥 간단한 점심메뉴',
#  '간단한 에어프라이어 식빵피자 만들기 식빵 요리 홈브런치',
#  '12월 제철 팥 요리, 팥삶는법 & 찐빵 만들기',
#  '꼬막무침 매콤 꼬막양념장 요리 꼬막 삶는법과 해감까지',
#  '냉동 자숙 문어요리 초간단 문어버터구이',
#  '새송이버섯볶음 만드는 법 간단한 새송이버섯요리 버섯종류',
#  '파래무침 만드는 법 파래요리 무우파래무침',
#  '배추 넣은 당근샐러드 당근 요리',
#  '백종원 제육볶음 레시피 실패없는 쌈도둑 고추장 대패 제육볶음 양념장! 인기만점 대패삼겹살 요리 ',
#  '굴무침만들기 초간단 굴무생채 만드는법 굴 세척부터 굴요리 밥반찬 레시피!',
#  '에어프라이어 군고구마 시간 꿀뚝뚝 비법은? 에어프라이어 고구마 요리 고구마 보관방법',
#  '팽이버섯전 만드는법, 팽이버섯 세척 손질은 이렇게! 다이어트요리',
#  '몬테크리스토 샌드위치 만들기 ! 에어프라이어 요리~ ',
#  '미역줄기볶음 만드는 법 간단한 밑반찬 만들기 종류 미역줄거리볶음 요리 비법!',
#  '연어 파피요트 분위기 나는 홈파티 음식 생연어 연어요리',
#  '무청시래기 나물 볶음 부드럽고 구수한 나물반찬 무청시래기요리',
#  '베이컨숙주볶음 숙주 요리',
#  '단호박 찌는법 달콤 맛있는 단호박 샐러드 요리 까지~',
#  ' 초간단 순두부계란찜 만드는법 국대신 찌개대신 먹기 좋은 레시피  순두부요리 계란요리',
#  '옥수수범벅 만들기 쫀득하고 달콤한 건강간식 찰옥수수요리',
#  '치즈계란찜 만들기 전자렌지로 만드는 초간단 자취 요리',
#  '늙은호박죽 만들기 호박죽 늙은호박요리 꿀팁 더해 더 맛있게',
#  '식빵 요리 크루통 만들기 두가지 방법으로',
#  '크로크무슈 만들기 홈 브런치 메뉴 모짜렐라치즈 요리',
#  '백종원 무우파래무침 만드는법 파래요리 초무침',
#  '소세지야채볶음 굴소스 맛보장 아기 비엔나 소세지 볶음 요리 팁 쏘야볶음 레시피 ',
#  '토마토 계란볶음 요리 간단하고 든든한 저탄고지 식단 토달볶',
#  '알배기 배추전 만드는법 엄마 꿀팁 제대로 부친 레시피 배추 요리 이겁니다.',
#  '순두부 열라면 요리 라면 맛있게 끓이는법 얼큰 칼칼한 맛!',
#  '꼬치 어묵탕 끓이는법  오뎅국 레시피 따끈한 국물요리',
#  '시금치된장국 만드는 법 달큰 세상 맛있는 아기 시금치국 요리 된장국 끓이는법 ',
#  '중화풍 양배추 샐러드 12월 제철 농산물로 만든 요리 ',
#  '참나물무침 겉절이양념으로 즐기는 단감요리',
#  '고등어무조림 양념 매콤하게 고등어 조림 요리 오늘 저녁메뉴 추천',
#  '참치 비빔밥 만드는법 도시락의 추억 레시피 참치캔요리',
#  ' 톳나물무침 톳두부무침! 톳요리 이렇게 해드세요 ',
#  '새우감바스 만들기 감바스 알 아히요 두부면 파스타 요리 먹는법',
#  '시금치된장국 만드는 법 시금치국 시금치요리 ',
#  '김무침 만드는법~ 묵은김요리',
#  '간장 두부조림 만드는법 아이들반찬 으로 좋은 밑반찬 두부요리 ',
#  '팽이버섯전 크래미 넣고 더 맛있게 팽이 크래미전 팽이버섯요리',
#  '김치콩나물국 끓이는법 겨울 국 요리 개운하고 시원해~ ',
#  '파계란볶음밥 만들기 초간단 간장 계란 볶음밥 자취생요리',
#  '고추참치 비빔밥 덮밥 만드는법 자취생 혼밥 요리',
#  '백종원 콩불 레시피 콩나물불고기 대패삼겹살 요리',
#  '쫀득한 연근조림 만드는 법 끝까지 쫀득쫀득 팁 맛있는 일주일 밑반찬 연근요리 ',
#  '순두부 그라탕 만들기 치즈 듬뿍 순두부 요리',
#  '탱글탱글 맛있는 굴전 만들기 포기할수 없는 맛~ 제철 굴요리',
#  '뱅쇼 만드는법 환절기 감기 잡는 뱅쇼 재료 레드와인 요리 ',
#  '꽈리고추조림 만드는 법 /꽈리고추요리',
#  '시금치된장국 달달하고 구수한 국 요리 시금치 요리 ',
#  '에어프라이어 고구마굽기 사르르 녹는 허니버터고구마 요리',
#  '명란 두부찌개 끓이는법 속이 시원한 맑은찌개 명란요리 두부요리 국물요리',
#  '깻잎 두부전 두부부침 간단한 두부요리 깻잎전',
#  '고소하고 깔끔한 초간단요리 새우 오일파스타 만드는법',
#  '쫀득한 우엉조림 만드는법 팁은 이것 맛보장 김밥재료 우엉조림 우엉채조림 요리 팁 ',
#  '냉동 닭가슴살 요리! 다이어트 식단, 맛있는 완자탕 만드는 법 ~ ',
#  '바지락 칼국수 레시피 탱글하고 쫄깃한 손칼국수 반죽 만드는법 면요리 바지락요리',
#  '부라타치즈 단감샐러드 with 참간초드레싱 / 단감요리',
#  '배추덮밥에 잘 어울리는 배추 볶음 요리 ',
#  '쿠참 스팀 에어프라이어  웨지감자 에어프라이어 감자요리 간단한간식 만드는법으로 좋아요. ',
#  '고민 필요 없는 일주일 다이어트 식단! 훈제오리 요리 다이어트 도시락 만들기',
#  '새콤달콤 오이무침 황금레시피 아삭 입맛 확 살려주는 5분컷 즉석 오이무침 요리 팁 ',
#  '양파무침 아삭매콤새콤 생채 양파 요리',
#  '굴전 만들기 만드는법 탱글함이 좋은 굴요리 겨울 별미~ 막걸리 안주 ',
#  '시금치된장국 만드는 법 아침국물요리 만들기 ',
#  '백종원 길거리토스트 만들기 햄치즈토스트 든든한 식빵요리',
#  '굴밥 만드는법  굴 요리 버섯 무 밥 양념장 만들기 12월 제철 음식',
#  '감자스프 만들기 감자 요리 부드러운 브런치 만들기',
#  '순두부 요리 순두부찌개 끓이는법 양념도 간단해요',
#  '고구마 샐러드 만들기, 찐 고구마 요리',
#  '에어프라이어 요리 황태채 황태구이 핵맛 맥주안주 인정!',
#  '도토리묵무침, 몸속에 쌓인 중금속 해독과 배출에 좋은 도토리묵요리!',
#  '허닭 닭가슴살 어묵 핫바를 활용한 어묵탕 요리',
#  '돼지고기 삼겹살 김치찜 씻은 묵은지찜 요리',
#  '갓김치담그는법 제철에 담아먹는 갓 요리 갓김치',
#  '숙주나물무침 요리 향긋함 더해 두배로 맛있는 숙주나물데치기 팁 초간단 반찬거리 ',
#  '숙주나물무침 요리 아삭하게 숙주나물 데치기 나물반찬 만들기',
#  '참나물무침 만드는 법 겉절이 양념으로 생생하게 참나물 요리',
#  '파김치 담그는법 양념 10분컷 맛있다고 난리난 나만의 쪽파김치 담그는법 요리 ',
#  '백종원 대패삼겹살 덮밥 대패삼겹살 요리 간단! 한그릇 요리',
#  '애호박요리 간단한 밑반찬 만들기 애호박구이',
#  '순두부 양념장 만들기 고소하고 부드러운 순두부 요리',
#  '콩나물볶음 만드는 법 무침보다 간단한 맛있는 콩나물 요리',
#  '간단한 베이컨 샌드위치 만들기 아침식사 메뉴 베이컨요리',
#  '가지요리 비엔나 소세지 돌돌 오늘 저녁메뉴 추천하는 홈파티 음식',
#  '백종원 굴전 홍콩식 굴전만들기 맛있는 굴요리 ',
#  '초간단 백종원 라볶이 만들기, 라면요리',
#  '베이컨 숙주볶음 숙주요리 간단한 밑반찬 만들기 ',
#  '대패삼겹살요리 김치랑 볶았어요~원팬요리',
#  '진미채버터구이 만들기. 혼술안주로 좋은 진미채요리.',
#  '감자조림 만드는 법 밥도둑 감자요리 매운 고추장 감자조림 ',
#  '느타리버섯요리 느타리버섯무침 간단 흑임자 드레싱 만들기',
#  '닭가슴살 요리 인도커리 버터치킨 카레 맛있게 만드는법',
#  '라이스페이퍼 튀김 요리 김말이 만들기 아이들간식',
#  '고구마맛탕 만들기 / 고구마요리 /고구마빠스',
#  '홍시스무디 만들기 달콤한 홍시요리',
#  '막걸리 안주 참나물요리 고소한 참나물전 만들기',
#  '팥밥 만드는 법 팥요리12월 제철음식 농산물 대표곡식',
#  '스팸마요덮밥 만들기 맛있는 스팸요리 소스 레시피 간단한 저녁메뉴',
#  '고구마샐러드 만드는 법 고구마 전자레인지 꿀맛 고구마요리 ',
#  '아보카도 샐러드 홈 파티 요리 샐러드소스 만드는 법',
#  '숙주나물무침 크래미 숙주 요리 쉽게 만드는 반찬',
#  '삼겹살 요리 간단버젼 동파육 만들기 레시피',
#  '알배추 샐러드 아삭아삭 겉절이 보다 쉬운 배추 요리',
#  '토마토 카프레제 샐러드 요리 카프리제 발사믹식초 소스 만들기',
#  '묵은지찜 씻은 묵은지지짐 간단한 요리',
#  '마카로니 샐러드 만들기 마카로니 요리 삶기 삶는법',
#  '무 굴국 만드는 법 굴국 끓이는법 굴 요리',
#  '전기밥솥 굴밥 만드는법 무 굴밥 겨울 굴 요리',
#  '감자전 만들기 쫀득쫀득 반죽 1분컷 팁 감자전 믹서기 레시피! 간단한 감자 요리 ',
#  '샐러드같은 쌈채겉절이  산뜻하고 고소한맛까지 좋은 쌈채요리',
#  '닭갈비 만들기  레시피 양념장 만드는법 까지! 손님초대요리',
#  '국간장 두부조림 만드는 법 / 두부요리 ',
#  '에어프라이어 고구마 말랭이 만드는법 고구마요리 간식',
#  '[채식요리지도사 2급] 2회차 수업후기(코티지파이, 참치맛샐러드, 초코칩쿠키 등)',
#  '캔참치 요리 참치전 만드는법 깻잎 추가~ 막걸리 안주',
#  '에어프라이어 라면땅 만들기 간단한 라면요리',
#  '참치김치찌개 맛있게 끓이는법 캔참치 요리',
#  '전기압력밥솥 굴밥 만드는법 제철 굴요리 ',
#  '11월 제철음식 굴국 끓이는법 시원한 맛이 좋은 굴요리',
#  '콘옥수수전 요리 _ 비 오는 날 음식으로 달콤한 옥수수전 부치기',
#  '점심메뉴 추천 한그릇요리 소세지 볶음밥',
#  '굴전 만들기 탱글탱글 고소한 굴 요리 세척 씻는법 꿀팁~',
#  '무우 파래무침 만드는 법 비린내 제로 팁 새콤달콤 반찬만들기 파래요리 ',
#  '초간단 계란국 끓이는법 따뜻한 아침국 계란 요리',
#  '드로잉 액정타블렛 장은테크로 그림그리기 취미 스타트',
#  '[Fun! Fun! 펀딩] 전통의 아름다움이 그대로! 비단부채 드로잉 키트',
#  '북한산 카페 선운각 어반스케치 (펜 드로잉 일러스트 마카 스케치 그림)',
#  '대구디지털드로잉학원 취업 향한 발판!',
#  '[스페인맥주] 마오우 세션 아이피에이, 캔맥주 드로잉',
#  'Oil Pastel로 노릇노릇 토스트 굽기 [오일 파스텔로 그리는 카페 드로잉]',
#  '[디지털드로잉] 프로크리에이트 수채화 화분 속 식물 그리기',
#  '화실그리다 드로잉 클래스-수강생 작품',
#  '창의수업/실드로잉/일산아동미술학원/대화동미술학원/일산미술학원/풍동미술학원/',
#  '[부산인물드로잉]부산펜드로잉클래스, 부산일러스트클래스 _부산취미미술,부산직장인미술',
#  '디지털 드로잉과 피아노',
#  '요즘 그림고 있는 것들 / 펜드로잉, 외주작업, 수채화 일러스트 ⛄️✨🌿',
#  '펜 드로잉으로 표현한 덴마크의 가구 디자인',
#  '펜 드로잉 - 창틀 위에 앉은 고양이 일러스트',
#  '오랜만에 아이패드로 디지털 드로잉 연습',
#  '[집그리기/수채일러스트] 펜드로잉, 다니엘스미스물감, 캔손폰테네',
#  '오일 파스텔로 그리는 카페 드로잉_보니룸의 오일 파스텔 클래스',
#  '[디지털드로잉] 프로크리에이트 드로잉 책 보며 이것저것 그려보기2',
#  '프리즈마 색연필 드로잉',
#  '《갤러리아×쾨닉 서울》드로잉 워크샵을 진행했어요.-소통하는 그림연구소',
#  '[라이프가드닝위크-드로잉기록] 김계선밴드',
#  '펜드로잉 - 캐나다 옐로나이프 감성숙소를 그리다 ',
#  '홍제동 카페 아이텐티티커피랩 일러스트 펜 드로잉 & 마카 채색 과정 ',
#  '생활스케치 펜그림/기초 드로잉',
#  '빼빼로데이 일러스트 그리기 디지털드로잉 음식그림 11월 아트웍 만들기',
#  '[매일그림한장] 주말일상, 인물드로잉, 손오공, 유동골뱅이 밀키트',
#  "즐거웠던 '배성규 작가님의 아이패드 드로잉 원데이 클래스'",
#  '<오일 파스텔로 그리는 카페 드로잉> 출간 기념 작가 인터뷰 & 드로잉 시연',
#  '[디지털드로잉] 온라인 수업 듣고 따라 그려보는 아이패드 드로잉',
#  '한국근대문학관_드로잉뉴딜프로젝트(~10/9)',
#  '마포구 당인리발전소 (서울화력발전소) 펜 드로잉 손그림 일러스트 ',
#  '[공지] 크리스마스 미니 드로잉 이벤트! ',
#  '이색데이트 소마 드로잉카페 세종새롬점 액션페인팅 신나요!',
#  '[라인드로잉] 색연필로 얼굴 그리기, 양손드로잉',
#  '드로잉 펜그림/김선이그림방',
#  '오일 파스텔로 빈티지 카페 소품 그리기 [오일 파스텔로 그리는 카페 드로잉]',
#  '[디지털드로잉] 아티스트 Oamul Lu의 그림 모작 _ Lantern Festival',
#  '강남역 펜 드로잉 수업 23기 모집 (5주 과정)',
#  '[캔맥주/맥주그림] 마오우 클래시카 캔맥주 드로잉, (+ 일상드로잉)',
#  '펜 드로잉 X 마카 스케치 일러스트 - 쏘리에스프레소바 광화문 서촌 카페',
#  '[디지털드로잉] 남편의 여행 그림선물 _ 남사로 습지',
#  '[수채일러스트] 인물드로잉, 매일 그림 그리기',
#  '코픽 마카 드로잉 연습 (일러스트 채색 인테리어 스케치)',
#  '[독일맥주/세계맥주] 길데 필스너 캔맥주 드로잉',
#  '[아이패드드로잉] 클래스유의 디지털드로잉 인강',
#  '[캠핑맥주/캔맥주] 노르디스크 캠핑맥주, 캔맥주 드로잉',
#  '손쉽게 색칠해보는 마카 드로잉 스케치 일러스트 (코픽 마커 발색 기본구성)',
#  '[일상드로잉] 수채일러스트, 캔트지에 쉬민케 고체물감',
#  '[디지털드로잉] 정물 그리기 4 _ 전화기',
#  '서울 취미 미술 그림 동호회 아트노마드 종로 을지로 모임 후기 (아이패드 디지털 드로잉 일러스트)',
#  '동네 마실 카페 드로잉 어반스케치 (코픽 일러스트 마카 스케치)',
#  '[인물크로키] 색연필드로잉, 얼굴그리기, 인물화',
#  '펜 드로잉 & 마카 스케치 일러스트 - 북한산 419 카페거리 몽브루에서 ',
#  '[인물드로잉] 어렵다 얼굴 그리기, 인물크로키',
#  '펜화 & 마카 드로잉으로 담은 광주 남한산성 카페 들 (일러스트 스케치 과정)',
#  '[펜드로잉] 잡화점',
#  '[얼굴그리기] 매일 한장, 색연필 인물 드로잉',
#  '[인물그리기] 색연필드로잉, 인물크로키',
#  '[디지털드로잉] 아티스트 Oamul Lu의 그림 모작 _ January',
#  '[그림기록/인물] 얼굴그리기, 인물드로잉, 크로키',
#  '[디지털드로잉] 가을풍경',
#  '[디지털드로잉] 프로크리에이트 레트로웨이브 풍경',
#  '[인물드로잉] 인물크로키, 코이노어 매직 색연필 드로잉',
#  '펜 드로잉 & 마카 스케치 채색 과정 (이태원 더 버뮤다 일러스트 기초 손그림)',
#  '[크로키/인물화] 라인드로잉, 얼굴그리기',
#  '아트노마드 을지로 모임 후기 (서울 드로잉 일러스트 그림 동호회 취미미술) ',
#  '[크로키/인물화] 색연필로 얼굴 그리기, 라인드로잉',
#  '[디지털 드로잉] 프로크리에이트 할로윈 잭오랜턴 호박등',
#  '[취미/그림그리기] 코이노어 매직 색연필 인물드로잉',
#  '[디지털드로잉] 프로크리에이트 _ 호수 위 나무 풍경',
#  '[편의점맥주] 스퀴즈브루어리 말표 청포도에일, 캔맥주드로잉',
#  '[선물/드로잉북] 아르쉬 양장북, 수제양장북',
#  '[인물크로키] 양손드로잉, 얼굴그리기, 색연필 인물화',
#  '[디지털드로잉] 정물 그리기 3 _ 음료수잔',
#  '[자화상] 연필드로잉, 왼손드로잉, 인물그리기',
#  '[디지털드로잉] 꽃을 든 소녀',
#  '[주말/일상] 매일그리기, 왼손드로잉, 크로키',
#  '[연필인물화] 라인드로잉, 인물크로키',
#  '10,11월 아이패드드로잉 수강생작품',
#  '트리방울 디지털드로잉 일러스트 그리기로 12월 공부주간계획표 양식 편집디자인 2021',
#  '일요일의 색연필 드로잉',
#  '[디지털 드로잉] 장미',
#  '[양손드로잉] 왼손으로 그림 그리기, 인물드로잉',
#  '[디지털드로잉] 어반스케치 _ 서촌재',
#  '[디지털드로잉] 탁자위 소품',
#  '[도서출판 이종 X 카카오 메이커스] 드로잉 취미 키트 OPEN!!!',
#  '잉크드로잉- 에코라인 잉크',
#  '액정타블렛 추천 와콤 신티크프로16 디지털 드로잉 후기',
#  '러빙핸즈에서 재능나눔 패턴아트와 디지털드로잉까지 ',
#  '색연필 인물드로잉',
#  '합정 드로잉카페 이색데이트 하기 좋은 보이드블랭킷 ',
#  '[수채일러스트]불타는 하늘, 일몰 풍경 드로잉',
#  '[디지털드로잉] 정물 그리기 2 _ 식물그리기',
#  '[일상드로잉] 대학로 연극, 협상 1948 관람 후',
#  '[수채일러스트] 가을하늘, 동네풍경 드로잉',
#  '[인물크로키] 매일 인물 드로잉, 색연필드로잉',
#  '화분그리기 / 색연필/ 색연필드로잉',
#  '[거제속눈썹펌] 드로잉튜드(Drawingtude);고현속눈썹펌',
#  '[얼굴그리기] 인물드로잉, 색연필드로잉, 매일그리기',
#  '인체드로잉',
#  '오일 파스텔 그림 그릴 때 필요한 재료와 특징, 사용법 알아보기 [ 오일 파스텔로 그리는 카페 드로잉]',
#  '21년 12월호 드로잉 어텐션이 발간 되었습니다',
#  '색연필 드로잉 두번째',
#  '[펜드로잉] 오늘도 나무를 그리다 _ 41~45',
#  '2022. FAS 겨울 특강- 인체드로잉 - 강산하 강사',
#  '무선 펜타블렛 와콤 인튜어스 프로로 디지털드로잉 일러스트 그리기',
#  '교회 성탄 행사  / 라인드로잉 & 캘리그라피 ',
#  '미대입시 Q&A1편 - 드로잉기본재료와 디자인입시 채색기본재료 소개!',
#  '이지드로잉노트 드로잉패드 1060plus 수업용판서패드로 사용할때 좋다좋아',
#  '1일1드로잉_날다_질문그림_생각그림',
#  '노란 은행잎 일러스트 그리기 디지털드로잉 10월 가을 아트웍 만들기',
#  '아이패드 드로잉으로 스티커와 엽서 굿즈만들기 with 쿨쿨스튜디오',
#  '간만에 그려보는 펜 드로잉 - 엄마의 여행 사진 그려보기',
#  '[펜드로잉] 목포 얼음창고',
#  '크리스마스장난감 추천 : 핑크퐁 아기상어 드로잉패드 ',
#  "[공지] 도서출판 이종 X 카카오 메이커스 '앤드류 루미스의 빈티지 드로잉 취미 키트'",
#  '웹툰학과 캐릭터 디지털 드로잉 특강수업 진행',
#  '색연필드로잉 인물화 손그림그리기',
#  '아이패드 드로잉 ) 불광동커피공방 그리고 요가젠은평',
#  '크리스마스장난감추천 아기상어올리와 윌리엄 드로잉패드 !',
#  '건대 맛집 | 피자가 맛있는 드로잉레시피(메뉴, 피자추천)',
#  '읏, ,츄워 , , (셀프사진관, 인물 드로잉, 살모닝) ',
#  '부평 이색 데이트 즐기기 좋은 드로잉카페, <NRFP>',
#  '핑크퐁 아기상어 스마트 드로잉패드 크리스마스장난감추천!',
#  '목화 포레스트 오일파스텔 드로잉 ♡제이갤러리 겨울 취미미술 원데이클래스 ',
#  '1일1드로잉 _아이돛_따뜻한 포옹그림_항해',
#  '[공지] [we draw 11월 그린님 모집] 오일 파스텔로 그리는 카페 드로잉',
#  '[드로잉] 펜드로잉, 마카드로잉, 오일파스텔 일러스트, 아이패드 드로잉 ✍🏻',
#  '여행드로잉 엽서 아트인라이프, 으린이의 색칠놀이, 정대리의 취미생활',
#  '11월의 색연필 드로잉',
#  '스튜디오8 디자인문구 드로잉노트로 컬러테라피',
#  '[부산/체험] 드로잉카페 - 오늘, 그림 한장',
#  '가을 멜로 인생영화추천 그녀her 호아킨피닉스 명작 띵작그림 드로잉후기',
#  '1일1드로잉 _이벤트준비_만화카페',
#  '[매일드로잉] 21.11.13 가을타입 ',
#  '<일산만화학원/일산미술학원> 얼굴 드로잉 - 기초편',
#  '해바라기 그림그리기 : 순서만 알면 쉬운 꽃 드로잉',
#  '[디지털드로잉]토분 속 아름다운 꽃 2',
#  '[디지털 드로잉] 수채화 가을 나뭇잎외',
#  '[오일파스텔 드로잉] 작가 그림 따라그리기 _ 풍경화',
#  '스튜디오8 컬러테라피 드로잉노트 추천!',
#  '[오일파스텔 드로잉] 아몬드와 서양배',
#  '스튜디오8 컬러테라피 디자인문구 / 프리미엄 드로잉노트',
#  '프로크리에이트 드로잉 _ 등대 Red Light house',
#  '펜 드로잉 - 아버지와 고양이 (일러스트 펜화 손그림 인물화 스케치) ',
#  '취미미술 (기초 여행스케치, 어반스케치,일상드로잉, 펜드로잉) 신청해요🎨🖌🖋',
#  '화려한 샹들리에와 함께 분당 브런치를 정자역 카페드로잉에서 먹었어요',
#  '[디지털드로잉] 미완성 겨울 풍경',
#  '크리스마스장난감추천 핑크퐁 아기상어 스마트 드로잉패드',
#  '겨울엔 이만한 취미생활이 또 없지🤭 인체드로잉의 시간 + Line of Action',
#  '12월 <시네마드로잉클래스> 모집합니다 ',
#  '<1일 1드로잉> 10쇄 기념, 스테들러와 콜라보 이벤트!!! ',
#  '세종시 일상 | 소마드로잉 카페 새롬점에서 나만의 액자 만들기 체험',
#  '크리스마스장난감추천 핑크퐁 아기상어 스마트 드로잉패드',
#  '[노트폴리오 이야기] 아이패드 드로잉 2기 어떠셨어요?(+수업모습/후기/수강생 작품)',
#  '펜드로잉 나무와 집 풍경드로잉 어반스케치',
#  '크리스마스 조카장난감선물로 핑크퐁 아기상어 스마트 드로잉패드 추천해요!',
#  '가수  헨리 팬아트 그려보기 / 아이패드 드로잉 / 색연필질감내기',
#  '[아이패드드로잉] 아방의 그림수업 _ 1. 지하철 앞에서',
#  '[인물화/드로잉] 색연필 드로잉, 인물크로키',
#  '스튜디오8 디자인문구 드로잉노트 민트',
#  ' 여행스케치 / 여행드로잉 엽서 아트인라이프로 즐거운 취미생활~~',
#  '매력터지는 펜화드로잉',
#  '[크로키] 색연필드로잉, 인물 그리기',
#  '벨벳표지 힐링템! 스튜디오8 디자인문구 드로잉노트',
#  '[아이패드드로잉] 감상주점 김작가의 이중생활 _ 이작가',
#  '드로잉 풍경수채화 돌담이 있는 정문 마을 대문',
#  '[인물크로키]연필드로잉, 얼굴그리기',
#  '[공지] [현대백화점 문화센터] 아이패드 드로잉 강의합니다! :)',
#  '[공지] [강의모집] 아이패드 프로크리에이트 라인드로잉 특강 5기 모집합니다♡',
#  '세종 드로잉카페에서 아이들과 미술체험_소마드로잉 새롬점',
#  '실크스크린 첫 시간, 멋진 드로잉을 프린팅!',
#  '[아이패드드로잉] 아방의 그림수업 _ 9. 피렌체를 걷다가 외...책 완료',
#  'KNDA대한천연디자인협회 비누자격증반 ; 투톤마블비누,삼색드로잉비누',
#  '[세종] 드로잉카페 소마드로잉카페 세종새롬점 이색 데이트 완전 추천!!',
#  '일러스트학원 드로잉 기초부터 응용까지!',
#  '[왼손드로잉] 얼굴그리기, 인물크로키',
#  '드로잉)13기 - 19 오토바이',
#  '디지털드로잉학원 초보자도 쉽게 배워요',
#  '액정타블렛 추천 와콤 신티크프로16 디지털 드로잉 후기',
#  '액정타블렛 와콤 신티크프로 16 사용기 - 필기부터 디지털드로잉까지 자유롭게',
#  '디지털드로잉 지원 펜타블렛 추천, 와콤 인튜어스 CTL-6100WL 사용기',
#  '대구디지털드로잉학원 취업 향한 발판!',
#  '무선 펜타블렛 와콤 인튜어스 프로로 디지털드로잉 일러스트 그리기',
#  '펜 타블렛 와콤 인튜어스 프로로 디지털 드로잉 해보자.',
#  '액정타블렛 와콤 신티크 프로 16 리뷰 및 디지털드로잉 후기',
#  '[공지] 와콤 태블릿 CTL-6100WL 디지털 드로잉 입문자 필수템',
#  '파블로 아트센터 디지털 드로잉클래스, 온라인 미술 미술 교육 봉봉.',
#  '[디지털드로잉] 정물 그리기 2 _ 식물그리기',
#  '디지털 드로잉 5세 온라인 아동 미술 교육 파블로아트센터',
#  '분당아트웍학원 디지털드로잉으로 입시미술 준비하기',
#  '디지털드로잉 펜 타블렛 추천 와콤 인튜어스 CTL-6100WL 후기',
#  '파블로아트센터; 디지털드로잉 원데이클래스 후기',
#  '그림그리기 어플 추천: 클립 스튜디오 EX로 디지털드로잉',
#  '온라인 아동 미술교육 봉봉 앨리스달튼 디지털 드로잉 원데이 클래스 @파블로아트센터 ',
#  '와콤 인튜어스 프로 : 디지털드로잉을 위한 펜타블렛',
#  '부드러운 느낌의 그림 그리기 /수채화 그림 / 여자사람그리기 /아이패드 /드로잉 / 디지털드로잉',
#  '파블로아트센터 "앨리스 달튼브라운 - 빛이 머무는 자리" 디지털 드로잉 수업 후기',
#  '액정타블렛 추천, 와콤 신티크22 디지털 드로잉부터 사진 편집까지 가능한 입문용 타블렛',
#  '이하미술공방 디지털 드로잉 초급자 클래스',
#  '[디지털드로잉] 프로크리에이트 수채화 화분 속 식물 그리기',
#  '디지털드로잉 전성시대, 그림그리기 어플은 <클립스튜디오페인트>로!',
#  '온라인 아동 미술 교육 파블로아트센터 앨리스 달튼 디지털 드로잉 원데이 클래스',
#  '오랜만에 아이패드로 디지털 드로잉 연습',
#  '서울 취미 미술 그림 동호회 아트노마드 종로 을지로 모임 후기 (아이패드 디지털 드로잉 일러스트)',
#  '디지털 드로잉과 피아노',
#  '파블로아트센터 디지털드로잉 원데이클래스 체험으로 아이와 유화 페인팅',
#  '부산디지털드로잉학원 ! 손끝에서부터 시작하기 !',
#  '빼빼로데이 일러스트 그리기 디지털드로잉 음식그림 11월 아트웍 만들기',
#  '파블로아트센터 디지털드로잉 미술도 첨단세상',
#  '러빙핸즈에서 재능나눔 패턴아트와 디지털드로잉까지 ',
#  ...]

# %%
import re
import requests
from bs4 import BeautifulSoup


from konlpy.tag import Okt 
okt = Okt()

# %%
# http로 시작되는 url제거
remove_url = [re.sub(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", " ", str(content)) for content in docs]

# 숫자 제거
remove_num = [re.sub(r'\d+',' ', str(content)) for content in remove_url]

# 영어 제거 
remove_alpha = [re.sub('[a-zA-Z]' , ' ', str(content)) for content in remove_num]

# Hashtag 제거
remove_tag = [re.sub('[#]+[0-9a-zA-Z_]+', ' ', str(content)) for content in remove_alpha]

# 특수문자 제거
remove_special = [re.sub('[^0-9a-zA-Zㄱ-ㅎ가-힣]', ' ', str(content)) for content in remove_tag]

#정규식(Regular Expression)이용해서 정규화
lawdata = [re.sub(r"[^가-힣A-Za-z0-9]", " ", str(content)) for content in remove_special]


   # 쓰레기 단어 제거
   #text = re.sub('[&]+[a-z]+', ' ', text)

   # 특정 문자 제거
   #for i in ['!','@','#','*'] :
       #new_id = new_id.replace(i, "")

   # 띄어쓰기 제거
   #text = text.replace('\n',' ')

# %%
lawdata[:20]
# Out:
# ['적재 정재원              음악 노래 추천 공유 ',
#  '음악작업용 외장하드  테라  내장   랑 속도 차이 거의 없을 무',
#  '미디작곡학원 나만의 음악을 만들고 싶다면',
#  '실용음악 선택이 미래를 좌우 ',
#  ' 음악교육신문  피아니스트 이정아',
#  '캐릭터라이선싱페어 에서 만난 음악교육 애니메이션 고둥둥심포니',
#  ' 책  상페의 음악   당신은 무엇을 동경하십니까 ',
#  ' 유아음악  세계적인 유아음악 프로그램  킨더뮤직               ',
#  '        재즈 역사상 가장 뛰어난 보컬 빌리 홀리데이의 음악 ',
#  '실용음악학과 서울권 진학을 알아본다면',
#  '   레코드로 한국대중음악을 즐기기',
#  '소란          내꺼라면  음악 노래 추천 공유 ',
#  ' 음악장비 묵직한 세츄레이션의                                                 ',
#  '실용음악학과 현실적인 활동과 취업방향 잡고싶다면 ',
#  '    시네마 클래식   영화로 즐기는 클래식 음악',
#  ' 음악교육신문   피아노 석세스 올인원  출간  예솔출판사 ',
#  '   살롱드파주 그레이스제이피아노  음악캠프  플룻 피아노 성악 ',
#  '보컬레슨 추천   음악 전문 온라인 교육 플레이샵 ',
#  '실용음악 비전공자로 성공하는 방법',
#  ' 킨더뮤직  영유아에게 백색소음보다 음악이 더 좋은 이유 ']

# %% [markdown]
# # 형태소 분석 관련 코드(여기서는 okt.nouns 이용해서, 토크나이즈 후 명사만 골라냄)

# %%
#morphs는 형태소 단위로 구문을 분석(형태소 단위로 토크나이즈)

lawdata_tokened_morphs = []

for doc in lawdata:
    newdoc = okt.morphs(doc)
    lawdata_tokened_morphs.append(newdoc)

# %%
lawdata_tokened_morphs[:2]
# Out:
# [['적재', '정재원', '음악', '노래', '추천', '공유'],
#  ['음악', '작업', '용', '외장하드', '테라', '내장', '랑', '속도', '차이', '거의', '없을', '무']]

# %%
#명사만 추출해줌(토크나이즈해서 리스트 형태로 명사만 추출)

lawdata_tokened_nouns = []

for doc in lawdata:
    newdoc = okt.nouns(doc)
    lawdata_tokened_nouns.append(newdoc)

# %%
lawdata_tokened_nouns[:2]
# Out:
# [['적재', '정재원', '음악', '노래', '추천', '공유'],
#  ['음악', '작업', '용', '외장하드', '테라', '내장', '속도', '차이', '거의', '무']]

# %%
#각 품사를 태깅하는 역할. 
#품사를 태깅한다는 것은 주어진 텍스트를 형태소 단위로 나누고, 나눠진 각 형태소를 그에 해당하는 품사와 함께 리스트화 하는 것을 의미한다. 
#형태소 분석으로, 형태소 단위 토크나이징
#pos = lambda d: ['/'.join(p) for p in okt.pos(d, stem=True, norm=True)]


pos = lambda d: ['/'.join(p) for p in okt.pos(d, stem=True, norm=True) 
                 if ('Noun' in p or 'Adjective' in p or 'Verb' in p or 'Adverb' in p) 
                 and '보다' not in p and '하다' not in p]
lawdata_tokened = [pos(doc) for doc in lawdata]

# %%
lawdata_tokened[:2]
# Out:
# [['적재/Noun', '정재원/Noun', '음악/Noun', '노래/Noun', '추천/Noun', '공유/Noun'],
#  ['음악/Noun',
#   '작업/Noun',
#   '용/Noun',
#   '외장하드/Noun',
#   '테라/Noun',
#   '내장/Noun',
#   '속도/Noun',
#   '차이/Noun',
#   '거의/Noun',
#   '없다/Adjective',
#   '무/Noun']]

# %%
print(lawdata_tokened[1])
lawdata_tokened[1][0].split('/')
# Out:
# ['음악/Noun', '작업/Noun', '용/Noun', '외장하드/Noun', '테라/Noun', '내장/Noun', '속도/Noun', '차이/Noun', '거의/Noun', '없다/Adjective', '무/Noun']
# ['음악', 'Noun']

# %%
lawdata_tokened_filtered = []

for doc in lawdata_tokened:
    newdoc = [d for d in doc if d.split('/')[1] == 'Noun' or d.split('/')[1] == 'Adjective' or d.split('/')[1] == 'Adverb']
    lawdata_tokened_filtered.append(newdoc)

# %%
lawdata_tokened_filtered[:2]
# Out:
# [['적재/Noun', '정재원/Noun', '음악/Noun', '노래/Noun', '추천/Noun', '공유/Noun'],
#  ['음악/Noun',
#   '작업/Noun',
#   '용/Noun',
#   '외장하드/Noun',
#   '테라/Noun',
#   '내장/Noun',
#   '속도/Noun',
#   '차이/Noun',
#   '거의/Noun',
#   '없다/Adjective',
#   '무/Noun']]

# %%
#명사만 추출하는 함수 정의(토크나이즈해서 명사만 추출)

import string
def noun_process(text):
    nouns = okt.nouns(text)
    #nouns = [word for word in nouns if len(word) > 1]
    return nouns

# %%
print(lawdata[0])
print(noun_process(lawdata[0]))
# Out:
# 적재 정재원              음악 노래 추천 공유
# ['적재', '정재원', '음악', '노래', '추천', '공유']

# %% [markdown]
# # CountVectorizer해서 word of bags 만듦 -> 문서전체를 doc-term matrix로 변환

# %%
#CountVectorizer: 토큰이 문서별로 몇 번 등장했는지 행렬로 정리해주는 모듈
#CountVectorizer해서 word of bags만들어주는 'bow_transformer' 함수 정의

bow_transformer = CountVectorizer(analyzer=noun_process).fit(lawdata)

# %%
#총 단어갯수

len(bow_transformer.vocabulary_)
# Out:
# 3492

# %%
# 0번째줄 문장의 단어는 어느 위치의 벡터인가?, 몇 번 나오는가?

bow_0 = bow_transformer.transform([lawdata[0]])
print(bow_0)
# Out:
#   (0, 204)	1
#   (0, 467)	1
#   (0, 2227)	1
#   (0, 2432)	1
#   (0, 2499)	1
#   (0, 2766)	1

# %%
# 이제 모든 lawdata를 변형

cv_lawdata= bow_transformer.transform(lawdata)

# %%
# CountVectorizer 적용한 lawdata 확인

print('Shape of Sparse Matrix: ', cv_lawdata.shape)
print('Amount of Non-Zero occurrences: ', cv_lawdata.nnz)
# Out:
# Shape of Sparse Matrix:  (8370, 3492)
# Amount of Non-Zero occurrences:  63825

# %%
# 그런데 여기서 주의해야할 것 하나.
# docs는 현재 document-term matrix 로 구성됨
# NMF를 적용하기 위해서는 term-document matrix가 필요하다.
# 즉, 현재의 Matrix를 transposed matrix(전치행렬)로 바꿔줘야 함.

type(cv_lawdata)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
# compressed sparse(희소행렬: 행렬의 값이 대부분 0일때) row matrix인 docs를 transpose 한다. (행열바꾸기)

cv_lawdata_trans = cv_lawdata.transpose()
type(cv_lawdata_trans) 

print('Shape of Sparse Matrix: ', cv_lawdata_trans.shape)
print('Amount of Non-Zero occurrences: ', cv_lawdata_trans.nnz)
# Out:
# Shape of Sparse Matrix:  (3492, 8370)
# Amount of Non-Zero occurrences:  63825

# %% [markdown]
# # NMF 모델 객체 생성

# %%
# NMF 모델 객체 생성
# n_topics: 매칭해줄 분류객체(베이킹, 요리..)

from sklearn.decomposition import NMF

n_topics = 25
model = NMF(n_components=n_topics)

# %%
# NMF 모델 학습
W = model.fit_transform(cv_lawdata_trans)

# %%
H = model.components_

# %%
H.shape
# Out:
# (25, 8370)

# %%
# index 0번 문서의 클러스터링 결과 점수

print(H[:,0])
# Out:
# [0.         0.         0.         0.         0.         0.14603818
#  0.         0.         0.         0.         0.         0.
#  0.         0.39387113 0.         0.         0.         0.
#  0.         0.         0.         0.         0.03475687 0.
#  0.        ]

# %%
# 전체 글 별로 best점수에 해당하는 클러스터 label결정

pred_labels = H.argmax(axis=0)

# %%
# label예측한 글 개수 = 원래 글 개수

len(pred_labels)
# Out:
# 8370

# %%
#10번째글까지 예측한 각 글에 대한 label 번호

pred_labels[:10]
# Out:
# array([13,  5,  5, 11,  5,  5,  5,  5,  5, 20])

# %%
#1번째글은 15번째(0.00913391), 2번째글은 23번째(0.15965101), 3번째글은 16번째(0.13495328) 값인 것 확인!

H[:,:3]
# Out:
# array([[0.00000000e+00, 2.87070815e-03, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.80713567e-03, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 3.98344378e-03],
#        [1.46038177e-01, 1.54481727e-01, 1.55751986e-01],
#        [0.00000000e+00, 1.84920401e-05, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 4.12500045e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.08813622e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.93871132e-01, 1.69922919e-02, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.48793686e-03, 3.93987139e-03],
#        [0.00000000e+00, 4.24834904e-04, 9.70810040e-03],
#        [0.00000000e+00, 1.15677614e-03, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.47568721e-02, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
# 원래데이터('data')에서 'keywords'열만 뽑아서 'target'에 저장
target = list(dataCombine1["keyword"])

newlist = [x for x in target if pd.isnull(x) == False]
print(newlist)
# Out:
# ['음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '음악', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '운동', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '베이킹', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', '요리', ' ...

# %%
# 'target'값(문자열)을 순서대로 '0 ~ 24'와 같은 숫자형으로 변환

num_target = []

for i in target:
    temp = i.replace('음악','0').replace('운동','1').replace('베이킹','2').replace('요리','3').replace('드로잉','4').replace('디지털드로잉','5').replace('라이프','6').replace('공예','7').replace('외국어','8')
    num_target.append(int(temp))
    
print(num_target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-27f8792b73cd> in <module>
#       5 for i in target:
#       6     temp = i.replace('음악','0').replace('운동','1').replace('베이킹','2').replace('요리','3').replace('드로잉','4').replace('디지털드로잉','5').replace('라이프','6').replace('공예','7').replace('외국어','8')
# ----> 7     num_target.append(int(temp))
#       8
#       9 print(num_target)
#
# ValueError: invalid literal for int() with base 10: '디지털4'

# %%
len(num_target)
# Out:
# 967

# %%
from sklearn.metrics import confusion_matrix

#가로: 예측 클러스터 / 세로: 실제 클래스
pd.DataFrame(confusion_matrix(num_target, pred_labels))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-b5ed430cb5c7> in <module>
#       2
#       3 #가로: 예측 클러스터 / 세로: 실제 클래스
# ----> 4 pd.DataFrame(confusion_matrix(num_target, pred_labels))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     274
#     275     """
# --> 276     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     277     if y_type not in ("binary", "multiclass"):
#     278         raise ValueError("%s is not supported" % y_type)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [967, 8370]

# %%
cmatrix = confusion_matrix(num_target, pred_labels)

#10번째열 까지만 출력
cmatrix[:,:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-214-712fc46803b0> in <module>
# ----> 1 cmatrix = confusion_matrix(num_target, pred_labels)
#       2
#       3 #10번째열 까지만 출력
#       4 cmatrix[:,:10]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     274
#     275     """
# --> 276     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     277     if y_type not in ("binary", "multiclass"):
#     278         raise ValueError("%s is not supported" % y_type)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [967, 8370]

# %%
# 25개
labels_25 = list(cmatrix.argmax(axis=0))
print(labels_25)
# Out:
# [9, 16, 20, 20, 21, 8, 11, 21, 18, 21, 16, 21, 10, 17, 21, 22, 4, 14, 19, 7, 13, 6, 7, 4, 9]

# %%
#labels_25로 매칭했을 때, 전체 클러스터링 정확도 계산 과정(성능확인 위해서)

i = 0
sum_result = 0
for c in cmatrix.transpose():
    print(c)
    print('label:', labels_25[i])
    print('value:', c[labels_25[i]])
    i += 1
    sum_result += c[labels_25[i]]
# Out:
# [  0  17  49 155 136  67 102 197  84 225 205 205 152 114 107  36  67 155
#   77 101  73 144 109  24  11]
# label: 9
# value: 225
# [ 1  7  8  9  9  6  8  6  4 14 10 27 11  6  7  0 89 15  8  5 15 11  4  0
#   1]
# label: 16
# value: 89
# [ 0  2  7  5 11  9  9 14  7 48 10 25 41 50 31 33 25 14 31 49 70 42 17 11
#  10]
# label: 20
# value: 70
# [  0   2   4   8  16   4  18   9   9  34   4  21  22  20  21   1   5   5
#    4  59 453  39 103  25   1]
# label: 20
# value: 453
# [  1  66  16  28  77  17  29  55  35  67  28 119 112  51  69  18  40  32
#   24  26  23 121  62   6   2]
# label: 21
# value: 121
# [  0   3  13  39  52  29  19  53 612  51  53  43  19  15   7   0   6  11
#   32  16   4   8  20   2   0]
# label: 8
# value: 612
# [ 0 10 12 25 15 12 24 38 18 40 16 48 18 24 24  2 16 33 31  8 13 48 21 10
#   0]
# label: 11
# value: 48
# [ 3 14 19 19 22 24 18 18 12 26 18 31 24 20 26 14 14 35 30 19 21 55 41  5
#   2]
# label: 21
# value: 55
# [  0   2   4   5  16   5   6  12   1  12   0  19   9  40  38   9   9 307
#  465  25  55  16  20   3   1]
# label: 18
# value: 465
# [ 0  3  7  5 10  6  6  8  5 43  2 33 74 52 21 27 20 17 32 34 15 93 76 10
#   1]
# label: 21
# value: 93
# [  0   3   3  10  23   5  10  12   3  18   5  15  14   5   8   3 133   8
#    3   9   4  16   9   2   1]
# label: 16
# value: 133
# [  0   1  14  24  25  16  18  20   8  32  16  34  35  22  12   7   8  24
#   29  34  15 139  32   8   1]
# label: 21
# value: 139
# [  0   9   6  13  19  16  18  13  16   5 396  30  30   4  14   0   7   8
#    2   9   3   5   7   1   0]
# label: 10
# value: 396
# [ 0  6  8 44 69 25 19 58 22 38 22 57 40 36 26 16 18 80 59 36 14 34 29  7
#  13]
# label: 17
# value: 80
# [ 1  4  4  7 11 11 10  2 11 10  7  8 21 26 30  8  8 18 17 21 42 44 42  2
#   2]
# label: 21
# value: 44
# [ 0  6  7 11 31  5 10 30 13 30 11 27 23 24 34 11  9 22 21 16  6 36 50  1
#   1]
# label: 22
# value: 50
# [  1   4   8  30 104  17  28  39  14  38  16  40  45  21  22   6  10  36
#   23  13   5  17  23   1   5]
# label: 4
# value: 104
# [  0   0   1   4   6   0   0   3   3   3   1   5   3   7 328   1   1  13
#    0   3   1   5   2   0   0]
# label: 14
# value: 328
# [  0   1   1   3   4   2   1   4   1  19   7  10  10   9   9   1   2   6
#    1 396   7  13   6   1   0]
# label: 19
# value: 396
# [ 1  8  6 25 48 20 23 57 23 30 20 50 34 18 24  2 13 48 33  7 18 20 16  2
#   0]
# label: 7
# value: 57
# [  0   2   4  10  18   0  15   8   6  34  10  16 105 293  31 116   6  18
#   24  38   4  37  23   1   8]
# label: 13
# value: 293
# [  0  20  26 336  65 281 345  21  18  52  41  34  24   7   8   0   2  18
#    7   8   3  25  14   0   0]
# label: 6
# value: 345
# [  1  10  23  53  88  19 107 204  23  40  20  29  69  28  39   5  17  37
#   20  19  37  30  55   1   0]
# label: 7
# value: 204
# [ 2  8 11 48 72 20 52 39 17 47  8 26 47 25 15  4 14 28 43 10 22 22 71  0
#   2]
# label: 4
# value: 72
# [ 0  2  3 14 23 12 15 30  5 34 24 18 28 13 19  1  4 22 14  9  7 10 18  2
#   0]
# label: 9
# value: 34
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-653b498d453f> in <module>
#       8     print('value:', c[labels_25[i]])
#       9     i += 1
# ---> 10     sum_result += c[labels_25[i]]
#      11
#
# IndexError: list index out of range

# %%
# 맞은데이터 개수

print(sum_result)
# Out:
# 748

# %%
# 맞은 비율

sum_result/len(num_target)
# Out:
# 0.0403147569257303
